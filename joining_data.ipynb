# %% [markdown]
# # Joining the Data
#
# It is now time for the scary part. But we never back away from a challenge! Let's say a prayer and get ready to join the data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Merge 1

# %% [markdown]
# ### Loading in Utility Scale Net Generation Data and Reliability of Distribution Systems Date

# %%
net_gen = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Utility_Scale_Net_Generation.csv', index_col=0)

net_gen.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    CT              Moderate                      Low
# 2    MA                   Low                      Low
# 4    RI                   Low                      Low
# 5    VT                   Low                      Low
# 6    NJ              Moderate                      Low
#
#   Commercial_Generation_Rank Capacity_Growth_Status
# 0                   Moderate                Growing
# 2                       High                Growing
# 4                        Low              Shrinking
# 5                        Low              Shrinking
# 6                       High              Shrinking

# %%
net_gen['State'].value_counts().sum()
# Out:
# 39

# %%
reliability = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Reliability_Distribution.csv', index_col=0)

reliability.head()
# Out:
#   Census Division State  Percent of Customers Reported w/ Major Events  \
# 0     New England    CT                                          100.6
# 1     New England    ME                                          100.8
# 2     New England    MA                                           88.2
# 3     New England    NH                                           99.3
# 4     New England    RI                                           98.3
#
#    SAIDI w/ Major Events  SAIFI w/ Major Events  CAIDI w/ Major Events  \
# 0                  164.6                    0.9                  188.8
# 1                 1863.0                    3.3                  562.2
# 2                  259.4                    1.1                  245.4
# 3                  645.8                    1.8                  368.5
# 4                  104.6                    0.8                  133.7
#
#    SAIDI w/o Major Events  SAIFI w/o Major Events  CAIDI w/o Major Events
# 0                    70.3                     0.7                   107.3
# 1                   247.4                     2.0                   125.0
# 2                    82.2                     0.8                   105.4
# 3                   124.6                     1.0                   126.1
# 4                    52.2                     0.7                    78.3

# %%
reliability.corr(numeric_only=True)
# Out:
#                                                Percent of Customers Reported w/ Major Events  \
# Percent of Customers Reported w/ Major Events                                       1.000000
# SAIDI w/ Major Events                                                               0.155055
# SAIFI w/ Major Events                                                              -0.011626
# CAIDI w/ Major Events                                                               0.245667
# SAIDI w/o Major Events                                                              0.005549
# SAIFI w/o Major Events                                                             -0.077099
# CAIDI w/o Major Events                                                              0.106543
#
#                                                SAIDI w/ Major Events  \
# Percent of Customers Reported w/ Major Events               0.155055
# SAIDI w/ Major Events                                       1.000000
# SAIFI w/ Major Events                                       0.832496
# CAIDI w/ Major Events                                       0.887799
# SAIDI w/o Major Events                                      0.652470
# SAIFI w/o Major Events                                      0.644317
# CAIDI w/o Major Events                                      0.427449
#
#                                                SAIFI w/ Major Events  \
# Percent of Customers Reported w/ Major Events              -0.011626
# SAIDI w/ Major Events                                       0.832496
# SAIFI w/ Major Events                                       1.000000
# CAIDI w/ Major Events                                       0.573910
# SAIDI w/o Major Events                                      0.859044
# SAIFI w/o Major Events                                      0.939123
# CAIDI w/o Major Events                                      0.365608
#
#                                                CAIDI w/ Major Events  \
# Percent of Customers Reported w/ Major Events               0.245667
# SAIDI w/ Major Events                                       0.887799
# SAIFI w/ Major Events                                       0.573910
# CAIDI w/ Major Events                                       1.000000
# SAIDI w/o Major Events                                      0.438757
# SAIFI w/o Major Events                                      0.340570
# CAIDI w/o Major Events                                      0.490745
#
#                                                SAIDI w/o Major Events  \
# Percent of Customers Reported w/ Major Events                0.005549
# SAIDI w/ Major Events                                        0.652470
# SAIFI w/ Major Events                                        0.859044
# CAIDI w/ Major Events                                        0.438757
# SAIDI w/o Major Events                                       1.000000
# SAIFI w/o Major Events                                       0.911040
# CAIDI w/o Major Events                                       0.678920
#
#                                                SAIFI w/o Major Events  \
# Percent of Customers Reported w/ Major Events               -0.077099
# SAIDI w/ Major Events                                        0.644317
# SAIFI w/ Major Events                                        0.939123
# CAIDI w/ Major Events                                        0.340570
# SAIDI w/o Major Events                                       0.911040
# SAIFI w/o Major Events                                       1.000000
# CAIDI w/o Major Events                                       0.357660
#
#                                                CAIDI w/o Major Events
# Percent of Customers Reported w/ Major Events                0.106543
# SAIDI w/ Major Events                                        0.427449
# SAIFI w/ Major Events                                        0.365608
# CAIDI w/ Major Events                                        0.490745
# SAIDI w/o Major Events                                       0.678920
# SAIFI w/o Major Events                                       0.357660
# CAIDI w/o Major Events                                       1.000000

# %%
# Drop highly correlated metrics
reliability = reliability.drop(columns=['SAIDI w/ Major Events', 'SAIDI w/o Major Events', 'SAIFI w/o Major Events', 'Percent of Customers Reported w/ Major Events', 'Census Division'])
reliability.head()
# Out:
#   State  SAIFI w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events
# 0    CT                    0.9                  188.8                   107.3
# 1    ME                    3.3                  562.2                   125.0
# 2    MA                    1.1                  245.4                   105.4
# 3    NH                    1.8                  368.5                   126.1
# 4    RI                    0.8                  133.7                    78.3

# %%
reliability.describe()
# Out:
#        SAIFI w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events
# count              51.000000              51.000000               51.000000
# mean                1.386275             226.466667              116.519608
# std                 0.636873             127.799489               23.595296
# min                 0.400000              76.200000               70.800000
# 25%                 0.900000             134.850000              101.350000
# 50%                 1.100000             186.900000              118.000000
# 75%                 1.800000             282.200000              124.950000
# max                 3.300000             723.500000              206.200000

# %%
# Bin SAIFI (Average Interruption Frequency Index) w/ Major Events
conditions_saifi = [
    reliability['SAIFI w/ Major Events'] > 1.8,  # 75th percentile
    (reliability['SAIFI w/ Major Events'] >= 1.1) & (reliability['SAIFI w/ Major Events'] <= 1.8),  # 50th-75th
    reliability['SAIFI w/ Major Events'] < 1.1  # Below median
]
choices_saifi = ['High', 'Moderate', 'Low']
reliability['SAIFI Major Events'] = np.select(conditions_saifi, choices_saifi, default='Unknown')

# %%
reliability.head()
# Out:
#   State  SAIFI w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events  \
# 0    CT                    0.9                  188.8                   107.3
# 1    ME                    3.3                  562.2                   125.0
# 2    MA                    1.1                  245.4                   105.4
# 3    NH                    1.8                  368.5                   126.1
# 4    RI                    0.8                  133.7                    78.3
#
#   SAIFI Major Events
# 0                Low
# 1               High
# 2           Moderate
# 3           Moderate
# 4                Low

# %%
reliability = reliability.drop(columns=['SAIFI w/ Major Events'])
reliability.head()
# Out:
#   State  CAIDI w/ Major Events  CAIDI w/o Major Events SAIFI Major Events
# 0    CT                  188.8                   107.3                Low
# 1    ME                  562.2                   125.0               High
# 2    MA                  245.4                   105.4           Moderate
# 3    NH                  368.5                   126.1           Moderate
# 4    RI                  133.7                    78.3                Low

# %%
# Count duplicates of State
reliability['State'].value_counts().sum()
# Out:
# 51

# %%
# Conduct an outer join on the State column
net_gen_reliability = pd.merge(net_gen, reliability, on='State', how='outer')

net_gen_reliability.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AR                   NaN                      NaN
# 3    AZ                  High                     High
# 4    CA                  High                     High
#
#   Commercial_Generation_Rank Capacity_Growth_Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                        NaN                    NaN                  433.4
# 3                   Moderate                Growing                  108.6
# 4                       High              Shrinking                  248.1
#
#    CAIDI w/o Major Events SAIFI Major Events
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   144.0               High
# 3                    84.8                Low
# 4                   140.0           Moderate

# %%
net_gen_reliability.isna().value_counts()
# Out:
# State  Total_Generation_Rank  Electric_Generation_Rank  Commercial_Generation_Rank  Capacity_Growth_Status  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIFI Major Events
# False  False                  False                     False                       False                   False                  False                   False                 39
#        True                   True                      True                        True                    False                  False                   False                 12
# Name: count, dtype: int64

# %%
net_gen_reliability.fillna('Unknown', inplace=True)
net_gen_reliability.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AR               Unknown                  Unknown
# 3    AZ                  High                     High
# 4    CA                  High                     High
#
#   Commercial_Generation_Rank Capacity_Growth_Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                    Unknown                Unknown                  433.4
# 3                   Moderate                Growing                  108.6
# 4                       High              Shrinking                  248.1
#
#    CAIDI w/o Major Events SAIFI Major Events
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   144.0               High
# 3                    84.8                Low
# 4                   140.0           Moderate

# %% [markdown]
# ## Load in the Energy Efficiency data

# %%
energy_efficiency = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Efficiency.csv', index_col=0)

energy_efficiency.head()
# Out:
#    Utility Number               Utility Name State BA Code  \
# 2             195           Alabama Power Co    AL    SOCO
# 3             207    Alameda Municipal Power    CA    CISO
# 4             295  City of Alexandria - (MN)    MN    MISO
# 5             554        City of Ames - (IA)    IA    MISO
# 6             590     City of Anaheim - (CA)    CA    CISO
#
#    Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# 2                      5767.0                                   11.9
# 3                       146.0                                    0.1
# 4                      3306.0                                    0.7
# 5                       189.0                                    0.1
# 6                      7242.0                                    1.5
#
#    Total Annual Incent Cost (Thousand $)  \
# 2                                 1225.0
# 3                                   70.0
# 4                                  187.0
# 5                                  197.0
# 6                                 3338.0
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
# 5                                           54.0
# 6                                          804.0
#
#    Commercial Weighted Avg Life (Yrs)
# 2                               5.000
# 3                              13.269
# 4                              12.727
# 5                              10.000
# 6                              11.437

# %%
energy_efficiency.columns
# Out:
# Index(['Utility Number', 'Utility Name', 'State', 'BA Code',
#        'Total Annual Savings (MWh)', 'Total Peak Demand Annual Savings (MW)',
#        'Total Annual Incent Cost (Thousand $)',
#        'Total Non-Incentive Annual Costs (Thousand $)',
#        'Commercial Weighted Avg Life (Yrs)'],
#       dtype='object')

# %%
energy_efficiency.corr(numeric_only=True)
# Out:
#                                                Utility Number  \
# Utility Number                                       1.000000
# Total Annual Savings (MWh)                           0.021878
# Total Peak Demand Annual Savings (MW)                0.025283
# Total Annual Incent Cost (Thousand $)                0.148453
# Total Non-Incentive Annual Costs (Thousand $)        0.083285
# Commercial Weighted Avg Life (Yrs)                   0.001019
#
#                                                Total Annual Savings (MWh)  \
# Utility Number                                                   0.021878
# Total Annual Savings (MWh)                                       1.000000
# Total Peak Demand Annual Savings (MW)                            0.473292
# Total Annual Incent Cost (Thousand $)                            0.639695
# Total Non-Incentive Annual Costs (Thousand $)                    0.812012
# Commercial Weighted Avg Life (Yrs)                               0.112121
#
#                                                Total Peak Demand Annual Savings (MW)  \
# Utility Number                                                              0.025283
# Total Annual Savings (MWh)                                                  0.473292
# Total Peak Demand Annual Savings (MW)                                       1.000000
# Total Annual Incent Cost (Thousand $)                                       0.278101
# Total Non-Incentive Annual Costs (Thousand $)                               0.402326
# Commercial Weighted Avg Life (Yrs)                                          0.037236
#
#                                                Total Annual Incent Cost (Thousand $)  \
# Utility Number                                                              0.148453
# Total Annual Savings (MWh)                                                  0.639695
# Total Peak Demand Annual Savings (MW)                                       0.278101
# Total Annual Incent Cost (Thousand $)                                       1.000000
# Total Non-Incentive Annual Costs (Thousand $)                               0.600819
# Commercial Weighted Avg Life (Yrs)                                          0.024366
#
#                                                Total Non-Incentive Annual Costs (Thousand $)  \
# Utility Number                                                                      0.083285
# Total Annual Savings (MWh)                                                          0.812012
# Total Peak Demand Annual Savings (MW)                                               0.402326
# Total Annual Incent Cost (Thousand $)                                               0.600819
# Total Non-Incentive Annual Costs (Thousand $)                                       1.000000
# Commercial Weighted Avg Life (Yrs)                                                  0.018572
#
#                                                Commercial Weighted Avg Life (Yrs)
# Utility Number                                                           0.001019
# Total Annual Savings (MWh)                                               0.112121
# Total Peak Demand Annual Savings (MW)                                    0.037236
# Total Annual Incent Cost (Thousand $)                                    0.024366
# Total Non-Incentive Annual Costs (Thousand $)                            0.018572
# Commercial Weighted Avg Life (Yrs)                                       1.000000

# %%
# Drop the year and Utility number columns
energy_efficiency = energy_efficiency.drop(columns=['Utility Number', 'Utility Name','Total Non-Incentive Annual Costs (Thousand $)'])

energy_efficiency.head()
# Out:
#   State BA Code  Total Annual Savings (MWh)  \
# 2    AL    SOCO                      5767.0
# 3    CA    CISO                       146.0
# 4    MN    MISO                      3306.0
# 5    IA    MISO                       189.0
# 6    CA    CISO                      7242.0
#
#    Total Peak Demand Annual Savings (MW)  \
# 2                                   11.9
# 3                                    0.1
# 4                                    0.7
# 5                                    0.1
# 6                                    1.5
#
#    Total Annual Incent Cost (Thousand $)  Commercial Weighted Avg Life (Yrs)
# 2                                 1225.0                               5.000
# 3                                   70.0                              13.269
# 4                                  187.0                              12.727
# 5                                  197.0                              10.000
# 6                                 3338.0                              11.437

# %%
energy_efficiency.describe()
# Out:
#        Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# count                3.280000e+02                             328.000000
# mean                 7.298820e+04                              17.305183
# std                  1.879049e+05                              62.953090
# min                  1.200000e+01                               0.000000
# 25%                  1.214500e+03                               0.200000
# 50%                  5.769500e+03                               1.500000
# 75%                  5.768900e+04                              11.450000
# max                  1.718664e+06                             945.000000
#
#        Total Annual Incent Cost (Thousand $)  \
# count                             328.000000
# mean                            11393.076220
# std                             32636.461121
# min                                 0.000000
# 25%                               190.250000
# 50%                              1109.000000
# 75%                              7041.750000
# max                            372401.000000
#
#        Commercial Weighted Avg Life (Yrs)
# count                          328.000000
# mean                            12.505122
# std                              4.285681
# min                              0.000000
# 25%                             11.000000
# 50%                             12.700000
# 75%                             14.312500
# max                             27.525000

# %% [markdown]
# ** Note that MW measures power capacity while MWh measures the amount of electricity delivered overtime

# %%
# Bin Total Annual Savings (MWh)
conditions_savings = [
    energy_efficiency['Total Annual Savings (MWh)'] >= energy_efficiency['Total Annual Savings (MWh)'].quantile(0.75),
    (energy_efficiency['Total Annual Savings (MWh)'] >= energy_efficiency['Total Annual Savings (MWh)'].quantile(0.25)) & 
    (energy_efficiency['Total Annual Savings (MWh)'] < energy_efficiency['Total Annual Savings (MWh)'].quantile(0.75)),
    energy_efficiency['Total Annual Savings (MWh)'] < energy_efficiency['Total Annual Savings (MWh)'].quantile(0.25)
]
choices_savings = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Annual Energy Savings (MWh)'] = np.select(conditions_savings, choices_savings, default='Unknown')

# Bin Peak Demand Savings
conditions_peak = [
    energy_efficiency['Total Peak Demand Annual Savings (MW)'] >= energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.75),
    (energy_efficiency['Total Peak Demand Annual Savings (MW)'] >= energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.25)) & 
    (energy_efficiency['Total Peak Demand Annual Savings (MW)'] < energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.75)),
    energy_efficiency['Total Peak Demand Annual Savings (MW)'] < energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.25)
]
choices_peak = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Peak Demand Savings (MW)'] = np.select(conditions_peak, choices_peak, default='Unknown')

# %%
# Bin Total Annual Incent Cost
conditions_incent = [
    energy_efficiency['Total Annual Incent Cost (Thousand $)'] >= energy_efficiency['Total Annual Incent Cost (Thousand $)'].quantile(0.75),
    (energy_efficiency['Total Annual Incent Cost (Thousand $)'] >= energy_efficiency['Total Annual Incent Cost (Thousand $)'].quantile(0.25)) & 
    (energy_efficiency['Total Annual Incent Cost (Thousand $)'] < energy_efficiency['Total Annual Incent Cost (Thousand $)'].quantile(0.75)),
    energy_efficiency['Total Annual Incent Cost (Thousand $)'] < energy_efficiency['Total Annual Incent Cost (Thousand $)'].quantile(0.25)
]
choices_incent = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Annual Incentive Cost'] = np.select(conditions_incent, choices_incent, default='Unknown')

# Bin Commercial Weighted Avg Life
conditions_life = [
    energy_efficiency['Commercial Weighted Avg Life (Yrs)'] >= energy_efficiency['Commercial Weighted Avg Life (Yrs)'].quantile(0.75),
    (energy_efficiency['Commercial Weighted Avg Life (Yrs)'] >= energy_efficiency['Commercial Weighted Avg Life (Yrs)'].quantile(0.25)) & 
    (energy_efficiency['Commercial Weighted Avg Life (Yrs)'] < energy_efficiency['Commercial Weighted Avg Life (Yrs)'].quantile(0.75)),
    energy_efficiency['Commercial Weighted Avg Life (Yrs)'] < energy_efficiency['Commercial Weighted Avg Life (Yrs)'].quantile(0.25)
]
choices_life = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Commercial Avg Life (Yrs)'] = np.select(conditions_life, choices_life, default='Unknown')

# %%
energy_efficiency.head()
# Out:
#   State BA Code  Total Annual Savings (MWh)  \
# 2    AL    SOCO                      5767.0
# 3    CA    CISO                       146.0
# 4    MN    MISO                      3306.0
# 5    IA    MISO                       189.0
# 6    CA    CISO                      7242.0
#
#    Total Peak Demand Annual Savings (MW)  \
# 2                                   11.9
# 3                                    0.1
# 4                                    0.7
# 5                                    0.1
# 6                                    1.5
#
#    Total Annual Incent Cost (Thousand $)  Commercial Weighted Avg Life (Yrs)  \
# 2                                 1225.0                               5.000
# 3                                   70.0                              13.269
# 4                                  187.0                              12.727
# 5                                  197.0                              10.000
# 6                                 3338.0                              11.437
#
#   Overall Annual Energy Savings (MWh) Overall Peak Demand Savings (MW)  \
# 2                            Moderate                             High
# 3                                 Low                              Low
# 4                            Moderate                         Moderate
# 5                                 Low                              Low
# 6                            Moderate                         Moderate
#
#   Overall Annual Incentive Cost Overall Commercial Avg Life (Yrs)
# 2                      Moderate                               Low
# 3                           Low                          Moderate
# 4                           Low                          Moderate
# 5                      Moderate                               Low
# 6                      Moderate                          Moderate

# %% [markdown]
# Let's aggregate some features to simplify the dataframe

# %%
# Keep only relevant columns
energy_efficiency_clean = energy_efficiency[['State', 'BA Code', 'Overall Annual Energy Savings (MWh)',
                                            'Overall Peak Demand Savings (MW)', 'Overall Annual Incentive Cost', 'Overall Commercial Avg Life (Yrs)']]

energy_efficiency_clean.head()
# Out:
#   State BA Code Overall Annual Energy Savings (MWh)  \
# 2    AL    SOCO                            Moderate
# 3    CA    CISO                                 Low
# 4    MN    MISO                            Moderate
# 5    IA    MISO                                 Low
# 6    CA    CISO                            Moderate
#
#   Overall Peak Demand Savings (MW) Overall Annual Incentive Cost  \
# 2                             High                      Moderate
# 3                              Low                           Low
# 4                         Moderate                           Low
# 5                              Low                      Moderate
# 6                         Moderate                      Moderate
#
#   Overall Commercial Avg Life (Yrs)
# 2                               Low
# 3                          Moderate
# 4                          Moderate
# 5                               Low
# 6                          Moderate

# %%
# Rename columns for more clarity
energy_efficiency_clean = energy_efficiency_clean.rename(columns={'Overall Annual Energy Savings (MWh)': 'Utility Annual Energy Savings (MWh)',
                                                                  'Overall Peak Demand Savings (MW)':'Utility Peak Demand Savings (MW)',
                                                                  'Overall Annual Incentive Cost': 'Utility Annual Incentive Cost ($)',
                                                                  'Overall Commercial Avg Life (Yrs)': 'Utility Commercial Avg Life (Yrs)'})
energy_efficiency_clean.head()
# Out:
#   State BA Code Utility Annual Energy Savings (MWh)  \
# 2    AL    SOCO                            Moderate
# 3    CA    CISO                                 Low
# 4    MN    MISO                            Moderate
# 5    IA    MISO                                 Low
# 6    CA    CISO                            Moderate
#
#   Utility Peak Demand Savings (MW) Utility Annual Incentive Cost ($)  \
# 2                             High                          Moderate
# 3                              Low                               Low
# 4                         Moderate                               Low
# 5                              Low                          Moderate
# 6                         Moderate                          Moderate
#
#   Utility Commercial Avg Life (Yrs)
# 2                               Low
# 3                          Moderate
# 4                          Moderate
# 5                               Low
# 6                          Moderate

# %%
energy_efficiency_clean.isna().value_counts()
# Out:
# State  BA Code  Utility Annual Energy Savings (MWh)  Utility Peak Demand Savings (MW)  Utility Annual Incentive Cost ($)  Utility Commercial Avg Life (Yrs)
# False  False    False                                False                             False                              False                                328
# Name: count, dtype: int64

# %%
len(energy_efficiency_clean['State'].value_counts())
# Out:
# 48

# %%
# Merge net_gen_reliability and energy_efficiency on the State column
merged_2 = pd.merge(net_gen_reliability, energy_efficiency_clean, on='State', how='outer')

merged_2.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AL                  High                     High
# 3    AR               Unknown                  Unknown
# 4    AR               Unknown                  Unknown
#
#   Commercial_Generation_Rank Capacity_Growth_Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                        Low                Growing                  186.9
# 3                    Unknown                Unknown                  433.4
# 4                    Unknown                Unknown                  433.4
#
#    CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 0                   137.6               High     NaN
# 1                   122.8           Moderate    SOCO
# 2                   122.8           Moderate     TVA
# 3                   144.0               High    MISO
# 4                   144.0               High    SWPP
#
#   Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                                 NaN                              NaN
# 1                            Moderate                             High
# 2                            Moderate                         Moderate
# 3                                High                             High
# 4                            Moderate                         Moderate
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)
# 0                               NaN                               NaN
# 1                          Moderate                               Low
# 2                          Moderate                          Moderate
# 3                              High                              High
# 4                          Moderate                          Moderate

# %%
merged_2.rename(columns={'Total_Generation_Rank': 'Total Generation Rank', 'Electric_Generation_Rank': 'Electric Generation Rank', 
                         'Commercial_Generation_Rank': 'Commercial Generation Rank','Capacity_Growth_Status': 'Capacity Growth Status'}, inplace=True)

# %%
merged_2 = merged_2.dropna(subset=['BA Code'])

# %%
merged_2.isna().value_counts()
# Out:
# State  Total Generation Rank  Electric Generation Rank  Commercial Generation Rank  Capacity Growth Status  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIFI Major Events  BA Code  Utility Annual Energy Savings (MWh)  Utility Peak Demand Savings (MW)  Utility Annual Incentive Cost ($)  Utility Commercial Avg Life (Yrs)
# False  False                  False                     False                       False                   False                  False                   False               False    False                                False                             False                              False                                328
# Name: count, dtype: int64

# %%
merged_2.isin(['Unknown']).sum()
# Out:
# State                                   0
# Total Generation Rank                  51
# Electric Generation Rank               51
# Commercial Generation Rank             51
# Capacity Growth Status                 51
# CAIDI w/ Major Events                   0
# CAIDI w/o Major Events                  0
# SAIFI Major Events                      0
# BA Code                                 3
# Utility Annual Energy Savings (MWh)     0
# Utility Peak Demand Savings (MW)        0
# Utility Annual Incentive Cost ($)       0
# Utility Commercial Avg Life (Yrs)       0
# dtype: int64

# %% [markdown]
# ### Loading in the regional Demand data for joining

# %%
demand = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Regional_Demand_2023.csv', index_col=0)
demand.head()
# Out:
#   Region State  Annual_Region_Demand_MWh
# 0    CAL    CA             726482.230137
# 1    CAL    CA             726482.230137
# 2    CAL    CA             726482.230137
# 3    CAL    CA             726482.230137
# 4    CAL    CA             726482.230137

# %%
demand.describe()
# Out:
#        Annual_Region_Demand_MWh
# count              1.679000e+04
# mean               1.029680e+06
# std                6.637723e+05
# min                3.068565e+05
# 25%                5.984282e+05
# 50%                7.698936e+05
# 75%                1.920122e+06
# max                2.150311e+06

# %%
# Bin Annual Region Demand
conditions_demand = [
    demand['Annual_Region_Demand_MWh'] >= demand['Annual_Region_Demand_MWh'].quantile(0.75),
    (demand['Annual_Region_Demand_MWh'] >= demand['Annual_Region_Demand_MWh'].quantile(0.25)) & 
    (demand['Annual_Region_Demand_MWh'] < demand['Annual_Region_Demand_MWh'].quantile(0.75)),
    demand['Annual_Region_Demand_MWh'] < demand['Annual_Region_Demand_MWh'].quantile(0.25)
]
choices_demand = ['High', 'Moderate', 'Low']
demand['Regional Electricity Demand'] = np.select(conditions_demand, choices_demand, default='Unknown')
demand.head()
# Out:
#   Region State  Annual_Region_Demand_MWh Regional Electricity Demand
# 0    CAL    CA             726482.230137                    Moderate
# 1    CAL    CA             726482.230137                    Moderate
# 2    CAL    CA             726482.230137                    Moderate
# 3    CAL    CA             726482.230137                    Moderate
# 4    CAL    CA             726482.230137                    Moderate

# %%
demand = demand.drop(columns=['Annual_Region_Demand_MWh'])

# %%
demand.shape
# Out:
# (16790, 3)

# %%
demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16790 entries, 0 to 16789
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       16790 non-null  object
#  1   State                        16790 non-null  object
#  2   Regional Electricity Demand  16790 non-null  object
# dtypes: object(3)
# memory usage: 524.7+ KB

# %%
# Drop duplicates of region and state
demand = demand.drop_duplicates(subset=['Region', 'State'])

# Verify the result
print(demand.shape)
demand.info()
# Out:
# (46, 3)
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 16425
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       46 non-null     object
#  1   State                        46 non-null     object
#  2   Regional Electricity Demand  46 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %%
# Merge demand with merged 2

merged_3 = pd.merge(merged_2, demand, on='State', how='outer')
merged_3.head()
# Out:
#   State Total Generation Rank Electric Generation Rank  \
# 0    AK                   NaN                      NaN
# 1    AL                  High                     High
# 2    AL                  High                     High
# 3    AR               Unknown                  Unknown
# 4    AR               Unknown                  Unknown
#
#   Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                        NaN                    NaN                    NaN
# 1                        Low                Growing                  186.9
# 2                        Low                Growing                  186.9
# 3                    Unknown                Unknown                  433.4
# 4                    Unknown                Unknown                  433.4
#
#    CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 0                     NaN                NaN     NaN
# 1                   122.8           Moderate    SOCO
# 2                   122.8           Moderate     TVA
# 3                   144.0               High    MISO
# 4                   144.0               High    SWPP
#
#   Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                                 NaN                              NaN
# 1                            Moderate                             High
# 2                            Moderate                         Moderate
# 3                                High                             High
# 4                            Moderate                         Moderate
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs) Region  \
# 0                               NaN                               NaN     NW
# 1                          Moderate                               Low     SE
# 2                          Moderate                          Moderate     SE
# 3                              High                              High     SE
# 4                          Moderate                          Moderate     SE
#
#   Regional Electricity Demand
# 0                    Moderate
# 1                    Moderate
# 2                    Moderate
# 3                    Moderate
# 4                    Moderate

# %%
merged_3[merged_3['Regional Electricity Demand'].isna()]
# Out:
#     State Total Generation Rank Electric Generation Rank  \
# 37     CO              Moderate                 Moderate
# 38     CO              Moderate                 Moderate
# 39     CO              Moderate                 Moderate
# 40     CO              Moderate                 Moderate
# 41     CO              Moderate                 Moderate
# 42     CO              Moderate                 Moderate
# 43     CO              Moderate                 Moderate
# 44     CO              Moderate                 Moderate
# 45     CO              Moderate                 Moderate
# 46     CO              Moderate                 Moderate
# 47     CO              Moderate                 Moderate
# 48     CO              Moderate                 Moderate
# 49     CO              Moderate                 Moderate
# 77     HI                   Low                      Low
# 78     HI                   Low                      Low
# 111    KY               Unknown                  Unknown
# 112    KY               Unknown                  Unknown
# 113    KY               Unknown                  Unknown
# 114    KY               Unknown                  Unknown
# 115    KY               Unknown                  Unknown
# 194    MT               Unknown                  Unknown
# 195    MT               Unknown                  Unknown
# 288    TN              Moderate                 Moderate
#
#     Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 37                         Low              Shrinking                  108.3
# 38                         Low              Shrinking                  108.3
# 39                         Low              Shrinking                  108.3
# 40                         Low              Shrinking                  108.3
# 41                         Low              Shrinking                  108.3
# 42                         Low              Shrinking                  108.3
# 43                         Low              Shrinking                  108.3
# 44                         Low              Shrinking                  108.3
# 45                         Low              Shrinking                  108.3
# 46                         Low              Shrinking                  108.3
# 47                         Low              Shrinking                  108.3
# 48                         Low              Shrinking                  108.3
# 49                         Low              Shrinking                  108.3
# 77                        High                Growing                  275.1
# 78                        High                Growing                  275.1
# 111                    Unknown                Unknown                  456.3
# 112                    Unknown                Unknown                  456.3
# 113                    Unknown                Unknown                  456.3
# 114                    Unknown                Unknown                  456.3
# 115                    Unknown                Unknown                  456.3
# 194                    Unknown                Unknown                  111.1
# 195                    Unknown                Unknown                  111.1
# 288                   Moderate              Shrinking                  305.1
#
#      CAIDI w/o Major Events SAIFI Major Events  BA Code  \
# 37                    102.2                Low     WACM
# 38                    102.2                Low     WACM
# 39                    102.2                Low     PSCO
# 40                    102.2                Low     PSCO
# 41                    102.2                Low     WACM
# 42                    102.2                Low     PSCO
# 43                    102.2                Low     PSCO
# 44                    102.2                Low     WACM
# 45                    102.2                Low     WACM
# 46                    102.2                Low     WACM
# 47                    102.2                Low     PSCO
# 48                    102.2                Low     WACM
# 49                    102.2                Low     PSCO
# 77                    106.3           Moderate  Unknown
# 78                    106.3           Moderate  Unknown
# 111                   122.9               High     MISO
# 112                   122.9               High     LGEE
# 113                   122.9               High     LGEE
# 114                   122.9               High      TVA
# 115                   122.9               High      PJM
# 194                   111.0           Moderate     BPAT
# 195                   111.0           Moderate     NWMT
# 288                    98.1               High      TVA
#
#     Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 37                                  Low                         Moderate
# 38                             Moderate                         Moderate
# 39                             Moderate                         Moderate
# 40                             Moderate                         Moderate
# 41                             Moderate                         Moderate
# 42                             Moderate                         Moderate
# 43                             Moderate                         Moderate
# 44                                  Low                              Low
# 45                             Moderate                         Moderate
# 46                             Moderate                         Moderate
# 47                                 High                             High
# 48                                  Low                         Moderate
# 49                             Moderate                         Moderate
# 77                             Moderate                         Moderate
# 78                                 High                         Moderate
# 111                                 Low                              Low
# 112                            Moderate                         Moderate
# 113                            Moderate                         Moderate
# 114                            Moderate                         Moderate
# 115                            Moderate                         Moderate
# 194                                 Low                         Moderate
# 195                            Moderate                              Low
# 288                                High                         Moderate
#
#     Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 37                           Moderate                              High
# 38                           Moderate                              High
# 39                           Moderate                               Low
# 40                           Moderate                          Moderate
# 41                           Moderate                          Moderate
# 42                           Moderate                          Moderate
# 43                           Moderate                          Moderate
# 44                                Low                          Moderate
# 45                           Moderate                          Moderate
# 46                           Moderate                              High
# 47                               High                              High
# 48                                Low                               Low
# 49                           Moderate                              High
# 77                           Moderate                          Moderate
# 78                               High                          Moderate
# 111                               Low                               Low
# 112                               Low                              High
# 113                               Low                              High
# 114                          Moderate                               Low
# 115                          Moderate                          Moderate
# 194                          Moderate                          Moderate
# 195                          Moderate                          Moderate
# 288                          Moderate                          Moderate
#
#     Region Regional Electricity Demand
# 37     NaN                         NaN
# 38     NaN                         NaN
# 39     NaN                         NaN
# 40     NaN                         NaN
# 41     NaN                         NaN
# 42     NaN                         NaN
# 43     NaN                         NaN
# 44     NaN                         NaN
# 45     NaN                         NaN
# 46     NaN                         NaN
# 47     NaN                         NaN
# 48     NaN                         NaN
# 49     NaN                         NaN
# 77     NaN                         NaN
# 78     NaN                         NaN
# 111    NaN                         NaN
# 112    NaN                         NaN
# 113    NaN                         NaN
# 114    NaN                         NaN
# 115    NaN                         NaN
# 194    NaN                         NaN
# 195    NaN                         NaN
# 288    NaN                         NaN

# %%
merged_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                338 non-null    object
#  1   Total Generation Rank                336 non-null    object
#  2   Electric Generation Rank             336 non-null    object
#  3   Commercial Generation Rank           336 non-null    object
#  4   Capacity Growth Status               336 non-null    object
#  5   CAIDI w/ Major Events                336 non-null    float64
#  6   CAIDI w/o Major Events               336 non-null    float64
#  7   SAIFI Major Events                   336 non-null    object
#  8   BA Code                              336 non-null    object
#  9   Utility Annual Energy Savings (MWh)  336 non-null    object
#  10  Utility Peak Demand Savings (MW)     336 non-null    object
#  11  Utility Annual Incentive Cost ($)    336 non-null    object
#  12  Utility Commercial Avg Life (Yrs)    336 non-null    object
#  13  Region                               315 non-null    object
#  14  Regional Electricity Demand          315 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 39.7+ KB

# %%
merged_3[merged_3['Total Generation Rank'].isna()]
# Out:
#     State Total Generation Rank Electric Generation Rank  \
# 0      AK                   NaN                      NaN
# 110    KS                   NaN                      NaN
#
#     Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                          NaN                    NaN                    NaN
# 110                        NaN                    NaN                    NaN
#
#      CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 0                       NaN                NaN     NaN
# 110                     NaN                NaN     NaN
#
#     Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                                   NaN                              NaN
# 110                                 NaN                              NaN
#
#     Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 0                                 NaN                               NaN
# 110                               NaN                               NaN
#
#     Region Regional Electricity Demand
# 0       NW                    Moderate
# 110   CENT                    Moderate

# %%
merged_3 = merged_3.dropna(subset=['Total Generation Rank'])
merged_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336 entries, 1 to 337
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                336 non-null    object
#  1   Total Generation Rank                336 non-null    object
#  2   Electric Generation Rank             336 non-null    object
#  3   Commercial Generation Rank           336 non-null    object
#  4   Capacity Growth Status               336 non-null    object
#  5   CAIDI w/ Major Events                336 non-null    float64
#  6   CAIDI w/o Major Events               336 non-null    float64
#  7   SAIFI Major Events                   336 non-null    object
#  8   BA Code                              336 non-null    object
#  9   Utility Annual Energy Savings (MWh)  336 non-null    object
#  10  Utility Peak Demand Savings (MW)     336 non-null    object
#  11  Utility Annual Incentive Cost ($)    336 non-null    object
#  12  Utility Commercial Avg Life (Yrs)    336 non-null    object
#  13  Region                               313 non-null    object
#  14  Regional Electricity Demand          313 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 42.0+ KB

# %%
merged_3['Region'].value_counts()
# Out:
# Region
# MIDW    78
# NW      49
# CENT    31
# CAL     26
# MIDA    24
# NE      21
# SE      19
# SW      14
# FLA     14
# TEX     14
# CAR     13
# NY      10
# Name: count, dtype: int64

# %%
merged_3[merged_3['Region'].isna()]
# Out:
#     State Total Generation Rank Electric Generation Rank  \
# 37     CO              Moderate                 Moderate
# 38     CO              Moderate                 Moderate
# 39     CO              Moderate                 Moderate
# 40     CO              Moderate                 Moderate
# 41     CO              Moderate                 Moderate
# 42     CO              Moderate                 Moderate
# 43     CO              Moderate                 Moderate
# 44     CO              Moderate                 Moderate
# 45     CO              Moderate                 Moderate
# 46     CO              Moderate                 Moderate
# 47     CO              Moderate                 Moderate
# 48     CO              Moderate                 Moderate
# 49     CO              Moderate                 Moderate
# 77     HI                   Low                      Low
# 78     HI                   Low                      Low
# 111    KY               Unknown                  Unknown
# 112    KY               Unknown                  Unknown
# 113    KY               Unknown                  Unknown
# 114    KY               Unknown                  Unknown
# 115    KY               Unknown                  Unknown
# 194    MT               Unknown                  Unknown
# 195    MT               Unknown                  Unknown
# 288    TN              Moderate                 Moderate
#
#     Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 37                         Low              Shrinking                  108.3
# 38                         Low              Shrinking                  108.3
# 39                         Low              Shrinking                  108.3
# 40                         Low              Shrinking                  108.3
# 41                         Low              Shrinking                  108.3
# 42                         Low              Shrinking                  108.3
# 43                         Low              Shrinking                  108.3
# 44                         Low              Shrinking                  108.3
# 45                         Low              Shrinking                  108.3
# 46                         Low              Shrinking                  108.3
# 47                         Low              Shrinking                  108.3
# 48                         Low              Shrinking                  108.3
# 49                         Low              Shrinking                  108.3
# 77                        High                Growing                  275.1
# 78                        High                Growing                  275.1
# 111                    Unknown                Unknown                  456.3
# 112                    Unknown                Unknown                  456.3
# 113                    Unknown                Unknown                  456.3
# 114                    Unknown                Unknown                  456.3
# 115                    Unknown                Unknown                  456.3
# 194                    Unknown                Unknown                  111.1
# 195                    Unknown                Unknown                  111.1
# 288                   Moderate              Shrinking                  305.1
#
#      CAIDI w/o Major Events SAIFI Major Events  BA Code  \
# 37                    102.2                Low     WACM
# 38                    102.2                Low     WACM
# 39                    102.2                Low     PSCO
# 40                    102.2                Low     PSCO
# 41                    102.2                Low     WACM
# 42                    102.2                Low     PSCO
# 43                    102.2                Low     PSCO
# 44                    102.2                Low     WACM
# 45                    102.2                Low     WACM
# 46                    102.2                Low     WACM
# 47                    102.2                Low     PSCO
# 48                    102.2                Low     WACM
# 49                    102.2                Low     PSCO
# 77                    106.3           Moderate  Unknown
# 78                    106.3           Moderate  Unknown
# 111                   122.9               High     MISO
# 112                   122.9               High     LGEE
# 113                   122.9               High     LGEE
# 114                   122.9               High      TVA
# 115                   122.9               High      PJM
# 194                   111.0           Moderate     BPAT
# 195                   111.0           Moderate     NWMT
# 288                    98.1               High      TVA
#
#     Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 37                                  Low                         Moderate
# 38                             Moderate                         Moderate
# 39                             Moderate                         Moderate
# 40                             Moderate                         Moderate
# 41                             Moderate                         Moderate
# 42                             Moderate                         Moderate
# 43                             Moderate                         Moderate
# 44                                  Low                              Low
# 45                             Moderate                         Moderate
# 46                             Moderate                         Moderate
# 47                                 High                             High
# 48                                  Low                         Moderate
# 49                             Moderate                         Moderate
# 77                             Moderate                         Moderate
# 78                                 High                         Moderate
# 111                                 Low                              Low
# 112                            Moderate                         Moderate
# 113                            Moderate                         Moderate
# 114                            Moderate                         Moderate
# 115                            Moderate                         Moderate
# 194                                 Low                         Moderate
# 195                            Moderate                              Low
# 288                                High                         Moderate
#
#     Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 37                           Moderate                              High
# 38                           Moderate                              High
# 39                           Moderate                               Low
# 40                           Moderate                          Moderate
# 41                           Moderate                          Moderate
# 42                           Moderate                          Moderate
# 43                           Moderate                          Moderate
# 44                                Low                          Moderate
# 45                           Moderate                          Moderate
# 46                           Moderate                              High
# 47                               High                              High
# 48                                Low                               Low
# 49                           Moderate                              High
# 77                           Moderate                          Moderate
# 78                               High                          Moderate
# 111                               Low                               Low
# 112                               Low                              High
# 113                               Low                              High
# 114                          Moderate                               Low
# 115                          Moderate                          Moderate
# 194                          Moderate                          Moderate
# 195                          Moderate                          Moderate
# 288                          Moderate                          Moderate
#
#     Region Regional Electricity Demand
# 37     NaN                         NaN
# 38     NaN                         NaN
# 39     NaN                         NaN
# 40     NaN                         NaN
# 41     NaN                         NaN
# 42     NaN                         NaN
# 43     NaN                         NaN
# 44     NaN                         NaN
# 45     NaN                         NaN
# 46     NaN                         NaN
# 47     NaN                         NaN
# 48     NaN                         NaN
# 49     NaN                         NaN
# 77     NaN                         NaN
# 78     NaN                         NaN
# 111    NaN                         NaN
# 112    NaN                         NaN
# 113    NaN                         NaN
# 114    NaN                         NaN
# 115    NaN                         NaN
# 194    NaN                         NaN
# 195    NaN                         NaN
# 288    NaN                         NaN

# %%
# If State is CO or MT then Region is NW
merged_3.loc[(merged_3['State'] == 'CO') | (merged_3['State'] == 'MT'), 'Region'] = 'NW'

# If State is KY then region is CENT
merged_3.loc[merged_3['State'] == 'KY', 'Region'] = 'CENT'

# If State is TN then region is SE
merged_3.loc[merged_3['State'] == 'TN', 'Region'] = 'SE'

# %%
merged_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336 entries, 1 to 337
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                336 non-null    object
#  1   Total Generation Rank                336 non-null    object
#  2   Electric Generation Rank             336 non-null    object
#  3   Commercial Generation Rank           336 non-null    object
#  4   Capacity Growth Status               336 non-null    object
#  5   CAIDI w/ Major Events                336 non-null    float64
#  6   CAIDI w/o Major Events               336 non-null    float64
#  7   SAIFI Major Events                   336 non-null    object
#  8   BA Code                              336 non-null    object
#  9   Utility Annual Energy Savings (MWh)  336 non-null    object
#  10  Utility Peak Demand Savings (MW)     336 non-null    object
#  11  Utility Annual Incentive Cost ($)    336 non-null    object
#  12  Utility Commercial Avg Life (Yrs)    336 non-null    object
#  13  Region                               334 non-null    object
#  14  Regional Electricity Demand          313 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 42.0+ KB

# %%
ixp = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_IXP.csv', index_col=0)
ixp.head()
# Out:
#                                  IXP Name         City State
# 0                                   48 IX      Phoenix    AZ
# 1                                   ABQIX  Albuquerque    NM
# 2                                AlaskaIX    Anchorage    AK
# 3  Amateur Radio Internet Exchange - ARIX      Fremont    CA
# 4  Amateur Radio Internet Exchange - ARIX     Portland    OR

# %%
ixp.isna().value_counts()
# Out:
# IXP Name  City   State
# False     False  False    196
#                  True       3
# Name: count, dtype: int64

# %%
ixp[ixp['State'].isna()]
# Out:
#                                              IXP Name           City State
# 21  BroadBand Internet Exchange US-West - BBIX US-...     West Coast   NaN
# 32                                CoreSite - Any2East  Washington DC   NaN
# 74  Equinix Internet Exchange Seattle - Equinix Se...        Seattle   NaN

# %%
ixp.loc[(ixp['City'] == 'Seattle') & (ixp['State'] == 'Washington'), 'City'] = 'Washington'

# %%
# Fix Seattle, Washington data
ixp.loc[ixp['City'] == 'Seattle', 'State'] = 'WA'

# Fix Washington DC data
ixp.loc[ixp['City'] == 'Washington DC', ['City', 'State']] = ['Washington', 'DC']

#Drop rows where City is West Coast
ixp = ixp[ixp['City'] != 'West Coast']

# %%
ixp[ixp['City'] == 'Seattle']
# Out:
#                                               IXP Name     City State
# 74   Equinix Internet Exchange Seattle - Equinix Se...  Seattle    WA
# 123                            Megaport MegaIX Seattle  Seattle    WA
# 132        Moe Internet Exchange - Seattle - MoeIX SEA  Seattle    WA
# 160                        Pacific Wave Exchange in LA  Seattle    WA
# 171  Seattle Internet Exchange (MTU 1500) - SIX Sea...  Seattle    WA
# 172  Seattle Internet Exchange (MTU 9000) - SIX Sea...  Seattle    WA

# %%
ixp[ixp['City'] == 'Washington']
# Out:
#                 IXP Name        City State
# 32   CoreSite - Any2East  Washington    DC
# 85  Global Peer Exchange  Washington    DC

# %%
len(ixp['State'].value_counts())
# Out:
# 42

# %%
len(ixp['City'].value_counts())
# Out:
# 92

# %%
ixp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198 entries, 0 to 198
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IXP Name  198 non-null    object
#  1   City      198 non-null    object
#  2   State     198 non-null    object
# dtypes: object(3)
# memory usage: 6.2+ KB

# %%
# Merge ixp data
merged_4 = pd.merge(merged_3, ixp, on='State', how='outer')

merged_4.isna().value_counts()
# Out:
# State  Total Generation Rank  Electric Generation Rank  Commercial Generation Rank  Capacity Growth Status  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIFI Major Events  BA Code  Utility Annual Energy Savings (MWh)  Utility Peak Demand Savings (MW)  Utility Annual Incentive Cost ($)  Utility Commercial Avg Life (Yrs)  Region  Regional Electricity Demand  IXP Name  City
# False  False                  False                     False                       False                   False                  False                   False               False    False                                False                             False                              False                              False   False                        False     False    2169
#                                                                                                                                                                                                                                                                                                                                              True                         False     False      73
#                                                                                                                                                                                                                                                                                                                                              False                        True      True       39
#                                                                                                                                                                                                                                                                                                                                      True    True                         False     False       6
#        True                   True                      True                        True                    True                   True                    True                True     True                                 True                              True                               True                               True    True                         False     False       4
# Name: count, dtype: int64

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2291 non-null   object
#  1   Total Generation Rank                2287 non-null   object
#  2   Electric Generation Rank             2287 non-null   object
#  3   Commercial Generation Rank           2287 non-null   object
#  4   Capacity Growth Status               2287 non-null   object
#  5   CAIDI w/ Major Events                2287 non-null   float64
#  6   CAIDI w/o Major Events               2287 non-null   float64
#  7   SAIFI Major Events                   2287 non-null   object
#  8   BA Code                              2287 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2287 non-null   object
#  10  Utility Peak Demand Savings (MW)     2287 non-null   object
#  11  Utility Annual Incentive Cost ($)    2287 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2287 non-null   object
#  13  Region                               2281 non-null   object
#  14  Regional Electricity Demand          2208 non-null   object
#  15  IXP Name                             2252 non-null   object
#  16  City                                 2252 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 304.4+ KB

# %%
merged_4[merged_4['City'].isna()]
# Out:
#      State Total Generation Rank Electric Generation Rank  \
# 5       AR               Unknown                  Unknown
# 6       AR               Unknown                  Unknown
# 7       AR               Unknown                  Unknown
# 903     DE               Unknown                  Unknown
# 904     DE               Unknown                  Unknown
# 1129    ID                   Low                 Moderate
# 1130    ID                   Low                 Moderate
# 1131    ID                   Low                 Moderate
# 1132    ID                   Low                 Moderate
# 1133    ID                   Low                 Moderate
# 1134    ID                   Low                 Moderate
# 1204    LA               Unknown                  Unknown
# 1205    LA               Unknown                  Unknown
# 1206    LA               Unknown                  Unknown
# 1207    LA               Unknown                  Unknown
# 1446    MS              Moderate                     High
# 1447    MS              Moderate                     High
# 1448    MS              Moderate                     High
# 1449    MS              Moderate                     High
# 1499    NH               Unknown                  Unknown
# 1500    NH               Unknown                  Unknown
# 1501    NH               Unknown                  Unknown
# 1502    NH               Unknown                  Unknown
# 1791    RI                   Low                      Low
# 1792    RI                   Low                      Low
# 1793    SC              Moderate                     High
# 1794    SC              Moderate                     High
# 1795    SC              Moderate                     High
# 1796    SC              Moderate                     High
# 1797    SC              Moderate                     High
# 1798    SD               Unknown                  Unknown
# 1799    SD               Unknown                  Unknown
# 1800    SD               Unknown                  Unknown
# 1801    SD               Unknown                  Unknown
# 1802    SD               Unknown                  Unknown
# 1803    SD               Unknown                  Unknown
# 2288    WY                   Low                 Moderate
# 2289    WY                   Low                 Moderate
# 2290    WY                   Low                 Moderate
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 5                       Unknown                Unknown                  433.4
# 6                       Unknown                Unknown                  433.4
# 7                       Unknown                Unknown                  433.4
# 903                     Unknown                Unknown                  130.3
# 904                     Unknown                Unknown                  130.3
# 1129                        Low              Shrinking                  128.4
# 1130                        Low              Shrinking                  128.4
# 1131                        Low              Shrinking                  128.4
# 1132                        Low              Shrinking                  128.4
# 1133                        Low              Shrinking                  128.4
# 1134                        Low              Shrinking                  128.4
# 1204                    Unknown                Unknown                  275.1
# 1205                    Unknown                Unknown                  275.1
# 1206                    Unknown                Unknown                  275.1
# 1207                    Unknown                Unknown                  275.1
# 1446                        Low              Shrinking                  295.2
# 1447                        Low              Shrinking                  295.2
# 1448                        Low              Shrinking                  295.2
# 1449                        Low              Shrinking                  295.2
# 1499                    Unknown                Unknown                  368.5
# 1500                    Unknown                Unknown                  368.5
# 1501                    Unknown                Unknown                  368.5
# 1502                    Unknown                Unknown                  368.5
# 1791                        Low              Shrinking                  133.7
# 1792                        Low              Shrinking                  133.7
# 1793                        Low              Shrinking                  110.9
# 1794                        Low              Shrinking                  110.9
# 1795                        Low              Shrinking                  110.9
# 1796                        Low              Shrinking                  110.9
# 1797                        Low              Shrinking                  110.9
# 1798                    Unknown                Unknown                   76.2
# 1799                    Unknown                Unknown                   76.2
# 1800                    Unknown                Unknown                   76.2
# 1801                    Unknown                Unknown                   76.2
# 1802                    Unknown                Unknown                   76.2
# 1803                    Unknown                Unknown                   76.2
# 2288                        Low              Shrinking                  127.8
# 2289                        Low              Shrinking                  127.8
# 2290                        Low              Shrinking                  127.8
#
#       CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 5                      144.0               High    MISO
# 6                      144.0               High    SWPP
# 7                      144.0               High    SWPP
# 903                     87.3                Low     PJM
# 904                     87.3                Low     PJM
# 1129                   121.2           Moderate    BPAT
# 1130                   121.2           Moderate    PACE
# 1131                   121.2           Moderate    IPCO
# 1132                   121.2           Moderate     AVA
# 1133                   121.2           Moderate    PACE
# 1134                   121.2           Moderate     AVA
# 1204                   118.8               High    MISO
# 1205                   118.8               High    MISO
# 1206                   118.8               High    MISO
# 1207                   118.8               High    SWPP
# 1446                   118.0               High    SOCO
# 1447                   118.0               High    MISO
# 1448                   118.0               High    SOCO
# 1449                   118.0               High     TVA
# 1499                   126.1           Moderate    ISNE
# 1500                   126.1           Moderate    ISNE
# 1501                   126.1           Moderate    ISNE
# 1502                   126.1           Moderate    ISNE
# 1791                    78.3                Low    ISNE
# 1792                    78.3                Low    ISNE
# 1793                    97.7           Moderate      SC
# 1794                    97.7           Moderate    CPLE
# 1795                    97.7           Moderate     DUK
# 1796                    97.7           Moderate    SCEG
# 1797                    97.7           Moderate      SC
# 1798                    70.8                Low    WACM
# 1799                    70.8                Low    MISO
# 1800                    70.8                Low    MISO
# 1801                    70.8                Low    SWPP
# 1802                    70.8                Low    WACM
# 1803                    70.8                Low    SWPP
# 2288                   124.7                Low    WACM
# 2289                   124.7                Low    WACM
# 2290                   124.7                Low    PACE
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 5                                   High                             High
# 6                               Moderate                         Moderate
# 7                               Moderate                             High
# 903                                  Low                             High
# 904                                  Low                              Low
# 1129                                 Low                              Low
# 1130                            Moderate                         Moderate
# 1131                                High                             High
# 1132                                 Low                              Low
# 1133                            Moderate                         Moderate
# 1134                            Moderate                             High
# 1204                            Moderate                         Moderate
# 1205                                High                         Moderate
# 1206                                High                             High
# 1207                            Moderate                         Moderate
# 1446                            Moderate                         Moderate
# 1447                                High                         Moderate
# 1448                            Moderate                         Moderate
# 1449                            Moderate                         Moderate
# 1499                            Moderate                         Moderate
# 1500                                High                         Moderate
# 1501                            Moderate                         Moderate
# 1502                            Moderate                         Moderate
# 1791                                High                             High
# 1792                                 Low                              Low
# 1793                                 Low                         Moderate
# 1794                            Moderate                         Moderate
# 1795                                High                             High
# 1796                                High                             High
# 1797                            Moderate                         Moderate
# 1798                                 Low                              Low
# 1799                            Moderate                         Moderate
# 1800                            Moderate                         Moderate
# 1801                            Moderate                              Low
# 1802                                 Low                              Low
# 1803                                 Low                              Low
# 2288                            Moderate                         Moderate
# 2289                                 Low                              Low
# 2290                            Moderate                         Moderate
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 5                                 High                              High
# 6                             Moderate                          Moderate
# 7                             Moderate                              High
# 903                           Moderate                               Low
# 904                                Low                              High
# 1129                               Low                               Low
# 1130                          Moderate                          Moderate
# 1131                              High                          Moderate
# 1132                               Low                          Moderate
# 1133                          Moderate                          Moderate
# 1134                          Moderate                          Moderate
# 1204                          Moderate                          Moderate
# 1205                              High                          Moderate
# 1206                              High                          Moderate
# 1207                          Moderate                              High
# 1446                          Moderate                              High
# 1447                              High                          Moderate
# 1448                          Moderate                               Low
# 1449                          Moderate                          Moderate
# 1499                          Moderate                          Moderate
# 1500                              High                               Low
# 1501                          Moderate                          Moderate
# 1502                          Moderate                               Low
# 1791                              High                               Low
# 1792                               Low                              High
# 1793                               Low                               Low
# 1794                          Moderate                          Moderate
# 1795                              High                               Low
# 1796                              High                          Moderate
# 1797                          Moderate                          Moderate
# 1798                               Low                          Moderate
# 1799                          Moderate                          Moderate
# 1800                          Moderate                              High
# 1801                          Moderate                              High
# 1802                               Low                          Moderate
# 1803                               Low                          Moderate
# 2288                          Moderate                              High
# 2289                               Low                          Moderate
# 2290                          Moderate                          Moderate
#
#      Region Regional Electricity Demand IXP Name City
# 5        SE                    Moderate      NaN  NaN
# 6        SE                    Moderate      NaN  NaN
# 7        SE                    Moderate      NaN  NaN
# 903    MIDA                        High      NaN  NaN
# 904    MIDA                        High      NaN  NaN
# 1129     NW                    Moderate      NaN  NaN
# 1130     NW                    Moderate      NaN  NaN
# 1131     NW                    Moderate      NaN  NaN
# 1132     NW                    Moderate      NaN  NaN
# 1133     NW                    Moderate      NaN  NaN
# 1134     NW                    Moderate      NaN  NaN
# 1204     SE                    Moderate      NaN  NaN
# 1205     SE                    Moderate      NaN  NaN
# 1206     SE                    Moderate      NaN  NaN
# 1207     SE                    Moderate      NaN  NaN
# 1446     SE                    Moderate      NaN  NaN
# 1447     SE                    Moderate      NaN  NaN
# 1448     SE                    Moderate      NaN  NaN
# 1449     SE                    Moderate      NaN  NaN
# 1499     NE                         Low      NaN  NaN
# 1500     NE                         Low      NaN  NaN
# 1501     NE                         Low      NaN  NaN
# 1502     NE                         Low      NaN  NaN
# 1791     NE                         Low      NaN  NaN
# 1792     NE                         Low      NaN  NaN
# 1793    CAR                    Moderate      NaN  NaN
# 1794    CAR                    Moderate      NaN  NaN
# 1795    CAR                    Moderate      NaN  NaN
# 1796    CAR                    Moderate      NaN  NaN
# 1797    CAR                    Moderate      NaN  NaN
# 1798   CENT                    Moderate      NaN  NaN
# 1799   CENT                    Moderate      NaN  NaN
# 1800   CENT                    Moderate      NaN  NaN
# 1801   CENT                    Moderate      NaN  NaN
# 1802   CENT                    Moderate      NaN  NaN
# 1803   CENT                    Moderate      NaN  NaN
# 2288     NW                    Moderate      NaN  NaN
# 2289     NW                    Moderate      NaN  NaN
# 2290     NW                    Moderate      NaN  NaN

# %%
merged_4['IXP Name'] = merged_4['IXP Name'].fillna('No IXP')

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2291 non-null   object
#  1   Total Generation Rank                2287 non-null   object
#  2   Electric Generation Rank             2287 non-null   object
#  3   Commercial Generation Rank           2287 non-null   object
#  4   Capacity Growth Status               2287 non-null   object
#  5   CAIDI w/ Major Events                2287 non-null   float64
#  6   CAIDI w/o Major Events               2287 non-null   float64
#  7   SAIFI Major Events                   2287 non-null   object
#  8   BA Code                              2287 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2287 non-null   object
#  10  Utility Peak Demand Savings (MW)     2287 non-null   object
#  11  Utility Annual Incentive Cost ($)    2287 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2287 non-null   object
#  13  Region                               2281 non-null   object
#  14  Regional Electricity Demand          2208 non-null   object
#  15  IXP Name                             2291 non-null   object
#  16  City                                 2252 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 304.4+ KB

# %%
merged_4[merged_4['Total Generation Rank'].isna()]
# Out:
#       State Total Generation Rank Electric Generation Rank  \
# 0        AK                   NaN                      NaN
# 1198     KS                   NaN                      NaN
# 2099  Texas                   NaN                      NaN
# 2287     WV                   NaN                      NaN
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                           NaN                    NaN                    NaN
# 1198                        NaN                    NaN                    NaN
# 2099                        NaN                    NaN                    NaN
# 2287                        NaN                    NaN                    NaN
#
#       CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 0                        NaN                NaN     NaN
# 1198                     NaN                NaN     NaN
# 2099                     NaN                NaN     NaN
# 2287                     NaN                NaN     NaN
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                                    NaN                              NaN
# 1198                                 NaN                              NaN
# 2099                                 NaN                              NaN
# 2287                                 NaN                              NaN
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 0                                  NaN                               NaN
# 1198                               NaN                               NaN
# 2099                               NaN                               NaN
# 2287                               NaN                               NaN
#
#      Region Regional Electricity Demand  \
# 0       NaN                         NaN
# 1198    NaN                         NaN
# 2099    NaN                         NaN
# 2287    NaN                         NaN
#
#                                    IXP Name              City
# 0                                  AlaskaIX         Anchorage
# 1198                  BGP.Exchange - Kansas       Kansas City
# 2099  DartNode IXP - DartNode IXP - Houston           Houston
# 2287        West Virginia Internet Exchange  South Charleston

# %%
# Drop rows where Total Generation Rank is NaN
merged_4 = merged_4.dropna(subset=['Total Generation Rank'])
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2287 entries, 1 to 2290
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2287 non-null   object
#  1   Total Generation Rank                2287 non-null   object
#  2   Electric Generation Rank             2287 non-null   object
#  3   Commercial Generation Rank           2287 non-null   object
#  4   Capacity Growth Status               2287 non-null   object
#  5   CAIDI w/ Major Events                2287 non-null   float64
#  6   CAIDI w/o Major Events               2287 non-null   float64
#  7   SAIFI Major Events                   2287 non-null   object
#  8   BA Code                              2287 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2287 non-null   object
#  10  Utility Peak Demand Savings (MW)     2287 non-null   object
#  11  Utility Annual Incentive Cost ($)    2287 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2287 non-null   object
#  13  Region                               2281 non-null   object
#  14  Regional Electricity Demand          2208 non-null   object
#  15  IXP Name                             2287 non-null   object
#  16  City                                 2248 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 321.6+ KB

# %%
merged_4.loc[merged_4['State'] == 'Texas', 'State'] = 'TX'

merged_4['State'].value_counts()
# Out:
# State
# CA    780
# TX    294
# FL    140
# WA    119
# NY    110
# OR    105
# CO     65
# MO     64
# MA     64
# MI     57
# IL     55
# IA     48
# MN     42
# AZ     40
# VA     39
# NC     32
# GA     30
# OH     30
# PA     24
# NE     14
# WI     14
# MD     10
# UT      9
# NV      8
# IN      8
# CT      8
# VT      6
# SD      6
# ID      6
# HI      6
# NJ      5
# SC      5
# KY      5
# NH      4
# NM      4
# MS      4
# LA      4
# AL      4
# WY      3
# AR      3
# RI      2
# OK      2
# DE      2
# DC      2
# MT      2
# TN      1
# ND      1
# ME      1
# Name: count, dtype: int64

# %%
merged_4[merged_4['City'].isna()]
# Out:
#      State Total Generation Rank Electric Generation Rank  \
# 5       AR               Unknown                  Unknown
# 6       AR               Unknown                  Unknown
# 7       AR               Unknown                  Unknown
# 903     DE               Unknown                  Unknown
# 904     DE               Unknown                  Unknown
# 1129    ID                   Low                 Moderate
# 1130    ID                   Low                 Moderate
# 1131    ID                   Low                 Moderate
# 1132    ID                   Low                 Moderate
# 1133    ID                   Low                 Moderate
# 1134    ID                   Low                 Moderate
# 1204    LA               Unknown                  Unknown
# 1205    LA               Unknown                  Unknown
# 1206    LA               Unknown                  Unknown
# 1207    LA               Unknown                  Unknown
# 1446    MS              Moderate                     High
# 1447    MS              Moderate                     High
# 1448    MS              Moderate                     High
# 1449    MS              Moderate                     High
# 1499    NH               Unknown                  Unknown
# 1500    NH               Unknown                  Unknown
# 1501    NH               Unknown                  Unknown
# 1502    NH               Unknown                  Unknown
# 1791    RI                   Low                      Low
# 1792    RI                   Low                      Low
# 1793    SC              Moderate                     High
# 1794    SC              Moderate                     High
# 1795    SC              Moderate                     High
# 1796    SC              Moderate                     High
# 1797    SC              Moderate                     High
# 1798    SD               Unknown                  Unknown
# 1799    SD               Unknown                  Unknown
# 1800    SD               Unknown                  Unknown
# 1801    SD               Unknown                  Unknown
# 1802    SD               Unknown                  Unknown
# 1803    SD               Unknown                  Unknown
# 2288    WY                   Low                 Moderate
# 2289    WY                   Low                 Moderate
# 2290    WY                   Low                 Moderate
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 5                       Unknown                Unknown                  433.4
# 6                       Unknown                Unknown                  433.4
# 7                       Unknown                Unknown                  433.4
# 903                     Unknown                Unknown                  130.3
# 904                     Unknown                Unknown                  130.3
# 1129                        Low              Shrinking                  128.4
# 1130                        Low              Shrinking                  128.4
# 1131                        Low              Shrinking                  128.4
# 1132                        Low              Shrinking                  128.4
# 1133                        Low              Shrinking                  128.4
# 1134                        Low              Shrinking                  128.4
# 1204                    Unknown                Unknown                  275.1
# 1205                    Unknown                Unknown                  275.1
# 1206                    Unknown                Unknown                  275.1
# 1207                    Unknown                Unknown                  275.1
# 1446                        Low              Shrinking                  295.2
# 1447                        Low              Shrinking                  295.2
# 1448                        Low              Shrinking                  295.2
# 1449                        Low              Shrinking                  295.2
# 1499                    Unknown                Unknown                  368.5
# 1500                    Unknown                Unknown                  368.5
# 1501                    Unknown                Unknown                  368.5
# 1502                    Unknown                Unknown                  368.5
# 1791                        Low              Shrinking                  133.7
# 1792                        Low              Shrinking                  133.7
# 1793                        Low              Shrinking                  110.9
# 1794                        Low              Shrinking                  110.9
# 1795                        Low              Shrinking                  110.9
# 1796                        Low              Shrinking                  110.9
# 1797                        Low              Shrinking                  110.9
# 1798                    Unknown                Unknown                   76.2
# 1799                    Unknown                Unknown                   76.2
# 1800                    Unknown                Unknown                   76.2
# 1801                    Unknown                Unknown                   76.2
# 1802                    Unknown                Unknown                   76.2
# 1803                    Unknown                Unknown                   76.2
# 2288                        Low              Shrinking                  127.8
# 2289                        Low              Shrinking                  127.8
# 2290                        Low              Shrinking                  127.8
#
#       CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 5                      144.0               High    MISO
# 6                      144.0               High    SWPP
# 7                      144.0               High    SWPP
# 903                     87.3                Low     PJM
# 904                     87.3                Low     PJM
# 1129                   121.2           Moderate    BPAT
# 1130                   121.2           Moderate    PACE
# 1131                   121.2           Moderate    IPCO
# 1132                   121.2           Moderate     AVA
# 1133                   121.2           Moderate    PACE
# 1134                   121.2           Moderate     AVA
# 1204                   118.8               High    MISO
# 1205                   118.8               High    MISO
# 1206                   118.8               High    MISO
# 1207                   118.8               High    SWPP
# 1446                   118.0               High    SOCO
# 1447                   118.0               High    MISO
# 1448                   118.0               High    SOCO
# 1449                   118.0               High     TVA
# 1499                   126.1           Moderate    ISNE
# 1500                   126.1           Moderate    ISNE
# 1501                   126.1           Moderate    ISNE
# 1502                   126.1           Moderate    ISNE
# 1791                    78.3                Low    ISNE
# 1792                    78.3                Low    ISNE
# 1793                    97.7           Moderate      SC
# 1794                    97.7           Moderate    CPLE
# 1795                    97.7           Moderate     DUK
# 1796                    97.7           Moderate    SCEG
# 1797                    97.7           Moderate      SC
# 1798                    70.8                Low    WACM
# 1799                    70.8                Low    MISO
# 1800                    70.8                Low    MISO
# 1801                    70.8                Low    SWPP
# 1802                    70.8                Low    WACM
# 1803                    70.8                Low    SWPP
# 2288                   124.7                Low    WACM
# 2289                   124.7                Low    WACM
# 2290                   124.7                Low    PACE
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 5                                   High                             High
# 6                               Moderate                         Moderate
# 7                               Moderate                             High
# 903                                  Low                             High
# 904                                  Low                              Low
# 1129                                 Low                              Low
# 1130                            Moderate                         Moderate
# 1131                                High                             High
# 1132                                 Low                              Low
# 1133                            Moderate                         Moderate
# 1134                            Moderate                             High
# 1204                            Moderate                         Moderate
# 1205                                High                         Moderate
# 1206                                High                             High
# 1207                            Moderate                         Moderate
# 1446                            Moderate                         Moderate
# 1447                                High                         Moderate
# 1448                            Moderate                         Moderate
# 1449                            Moderate                         Moderate
# 1499                            Moderate                         Moderate
# 1500                                High                         Moderate
# 1501                            Moderate                         Moderate
# 1502                            Moderate                         Moderate
# 1791                                High                             High
# 1792                                 Low                              Low
# 1793                                 Low                         Moderate
# 1794                            Moderate                         Moderate
# 1795                                High                             High
# 1796                                High                             High
# 1797                            Moderate                         Moderate
# 1798                                 Low                              Low
# 1799                            Moderate                         Moderate
# 1800                            Moderate                         Moderate
# 1801                            Moderate                              Low
# 1802                                 Low                              Low
# 1803                                 Low                              Low
# 2288                            Moderate                         Moderate
# 2289                                 Low                              Low
# 2290                            Moderate                         Moderate
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 5                                 High                              High
# 6                             Moderate                          Moderate
# 7                             Moderate                              High
# 903                           Moderate                               Low
# 904                                Low                              High
# 1129                               Low                               Low
# 1130                          Moderate                          Moderate
# 1131                              High                          Moderate
# 1132                               Low                          Moderate
# 1133                          Moderate                          Moderate
# 1134                          Moderate                          Moderate
# 1204                          Moderate                          Moderate
# 1205                              High                          Moderate
# 1206                              High                          Moderate
# 1207                          Moderate                              High
# 1446                          Moderate                              High
# 1447                              High                          Moderate
# 1448                          Moderate                               Low
# 1449                          Moderate                          Moderate
# 1499                          Moderate                          Moderate
# 1500                              High                               Low
# 1501                          Moderate                          Moderate
# 1502                          Moderate                               Low
# 1791                              High                               Low
# 1792                               Low                              High
# 1793                               Low                               Low
# 1794                          Moderate                          Moderate
# 1795                              High                               Low
# 1796                              High                          Moderate
# 1797                          Moderate                          Moderate
# 1798                               Low                          Moderate
# 1799                          Moderate                          Moderate
# 1800                          Moderate                              High
# 1801                          Moderate                              High
# 1802                               Low                          Moderate
# 1803                               Low                          Moderate
# 2288                          Moderate                              High
# 2289                               Low                          Moderate
# 2290                          Moderate                          Moderate
#
#      Region Regional Electricity Demand IXP Name City
# 5        SE                    Moderate   No IXP  NaN
# 6        SE                    Moderate   No IXP  NaN
# 7        SE                    Moderate   No IXP  NaN
# 903    MIDA                        High   No IXP  NaN
# 904    MIDA                        High   No IXP  NaN
# 1129     NW                    Moderate   No IXP  NaN
# 1130     NW                    Moderate   No IXP  NaN
# 1131     NW                    Moderate   No IXP  NaN
# 1132     NW                    Moderate   No IXP  NaN
# 1133     NW                    Moderate   No IXP  NaN
# 1134     NW                    Moderate   No IXP  NaN
# 1204     SE                    Moderate   No IXP  NaN
# 1205     SE                    Moderate   No IXP  NaN
# 1206     SE                    Moderate   No IXP  NaN
# 1207     SE                    Moderate   No IXP  NaN
# 1446     SE                    Moderate   No IXP  NaN
# 1447     SE                    Moderate   No IXP  NaN
# 1448     SE                    Moderate   No IXP  NaN
# 1449     SE                    Moderate   No IXP  NaN
# 1499     NE                         Low   No IXP  NaN
# 1500     NE                         Low   No IXP  NaN
# 1501     NE                         Low   No IXP  NaN
# 1502     NE                         Low   No IXP  NaN
# 1791     NE                         Low   No IXP  NaN
# 1792     NE                         Low   No IXP  NaN
# 1793    CAR                    Moderate   No IXP  NaN
# 1794    CAR                    Moderate   No IXP  NaN
# 1795    CAR                    Moderate   No IXP  NaN
# 1796    CAR                    Moderate   No IXP  NaN
# 1797    CAR                    Moderate   No IXP  NaN
# 1798   CENT                    Moderate   No IXP  NaN
# 1799   CENT                    Moderate   No IXP  NaN
# 1800   CENT                    Moderate   No IXP  NaN
# 1801   CENT                    Moderate   No IXP  NaN
# 1802   CENT                    Moderate   No IXP  NaN
# 1803   CENT                    Moderate   No IXP  NaN
# 2288     NW                    Moderate   No IXP  NaN
# 2289     NW                    Moderate   No IXP  NaN
# 2290     NW                    Moderate   No IXP  NaN

# %%
len(merged_4[merged_4['City'].isna()])
# Out:
# 39

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2287 entries, 1 to 2290
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2287 non-null   object
#  1   Total Generation Rank                2287 non-null   object
#  2   Electric Generation Rank             2287 non-null   object
#  3   Commercial Generation Rank           2287 non-null   object
#  4   Capacity Growth Status               2287 non-null   object
#  5   CAIDI w/ Major Events                2287 non-null   float64
#  6   CAIDI w/o Major Events               2287 non-null   float64
#  7   SAIFI Major Events                   2287 non-null   object
#  8   BA Code                              2287 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2287 non-null   object
#  10  Utility Peak Demand Savings (MW)     2287 non-null   object
#  11  Utility Annual Incentive Cost ($)    2287 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2287 non-null   object
#  13  Region                               2281 non-null   object
#  14  Regional Electricity Demand          2208 non-null   object
#  15  IXP Name                             2287 non-null   object
#  16  City                                 2248 non-null   object
# dtypes: float64(2), object(15)
# memory usage: 321.6+ KB

# %%
# Replace 'No IXP' with NaN to exclude it from the count
merged_4['IXP Name'] = merged_4['IXP Name'].replace('No IXP', np.nan)

# Group by 'State' and count unique 'IXP Name' values, then reset index
ixp_counts = merged_4.groupby('State')['IXP Name'].nunique().reset_index()

# Rename the column to 'IXP_Count'
ixp_counts = ixp_counts.rename(columns={'IXP Name': 'IXP_Count'})

# Merge the counts back into the original DataFrame
merged_4 = merged_4.merge(ixp_counts, on='State', how='left')

# Fill NaN values in 'IXP Name' back with 'No IXP'
merged_4['IXP Name'] = merged_4['IXP Name'].fillna('No IXP')

# %%
merged_4['IXP_Count'].value_counts()
# Out:
# IXP_Count
# 27    780
# 18    294
# 7     224
# 11    204
# 4     152
# 10    140
# 5     125
# 8     104
# 3      96
# 2      72
# 1      57
# 0      39
# Name: count, dtype: int64

# %%
merged_4[merged_4['Region'].isna()]
# Out:
#      State Total Generation Rank Electric Generation Rank  \
# 1074    HI                   Low                      Low
# 1075    HI                   Low                      Low
# 1076    HI                   Low                      Low
# 1077    HI                   Low                      Low
# 1078    HI                   Low                      Low
# 1079    HI                   Low                      Low
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 1074                       High                Growing                  275.1
# 1075                       High                Growing                  275.1
# 1076                       High                Growing                  275.1
# 1077                       High                Growing                  275.1
# 1078                       High                Growing                  275.1
# 1079                       High                Growing                  275.1
#
#       CAIDI w/o Major Events SAIFI Major Events  BA Code  \
# 1074                   106.3           Moderate  Unknown
# 1075                   106.3           Moderate  Unknown
# 1076                   106.3           Moderate  Unknown
# 1077                   106.3           Moderate  Unknown
# 1078                   106.3           Moderate  Unknown
# 1079                   106.3           Moderate  Unknown
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 1074                            Moderate                         Moderate
# 1075                            Moderate                         Moderate
# 1076                            Moderate                         Moderate
# 1077                                High                         Moderate
# 1078                                High                         Moderate
# 1079                                High                         Moderate
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 1074                          Moderate                          Moderate
# 1075                          Moderate                          Moderate
# 1076                          Moderate                          Moderate
# 1077                              High                          Moderate
# 1078                              High                          Moderate
# 1079                              High                          Moderate
#
#      Region Regional Electricity Demand  \
# 1074    NaN                         NaN
# 1075    NaN                         NaN
# 1076    NaN                         NaN
# 1077    NaN                         NaN
# 1078    NaN                         NaN
# 1079    NaN                         NaN
#
#                                     IXP Name      City  IXP_Count
# 1074            DRFortress Exchange - DRF IX  Honolulu          3
# 1075         Hawai`i Internet Exchange - HIX  Honolulu          3
# 1076  Hawaii Pacific Teleport IX-1 - HPTI-IX  Honolulu          3
# 1077            DRFortress Exchange - DRF IX  Honolulu          3
# 1078         Hawai`i Internet Exchange - HIX  Honolulu          3
# 1079  Hawaii Pacific Teleport IX-1 - HPTI-IX  Honolulu          3

# %%
merged_4['Region'] = merged_4['Region'].fillna('Independent')
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2287 non-null   object
#  1   Total Generation Rank                2287 non-null   object
#  2   Electric Generation Rank             2287 non-null   object
#  3   Commercial Generation Rank           2287 non-null   object
#  4   Capacity Growth Status               2287 non-null   object
#  5   CAIDI w/ Major Events                2287 non-null   float64
#  6   CAIDI w/o Major Events               2287 non-null   float64
#  7   SAIFI Major Events                   2287 non-null   object
#  8   BA Code                              2287 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2287 non-null   object
#  10  Utility Peak Demand Savings (MW)     2287 non-null   object
#  11  Utility Annual Incentive Cost ($)    2287 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2287 non-null   object
#  13  Region                               2287 non-null   object
#  14  Regional Electricity Demand          2208 non-null   object
#  15  IXP Name                             2287 non-null   object
#  16  City                                 2248 non-null   object
#  17  IXP_Count                            2287 non-null   int64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 321.7+ KB

# %%
len(merged_4[merged_4['City'].isna() == True])
# Out:
# 39

# %% [markdown]
# ###  Leaving the missing city data for now

# %%
# Move City column to beginning of dataframe

cols = merged_4.columns.tolist()

# Remove 'City' from current position and add to beginning
cols.remove('City')
cols = ['City'] + cols

# Reorder the DataFrame
merged_4 = merged_4[cols]

# Verify the new column order
print(merged_4.columns)
# Out:
# Index(['City', 'State', 'Total Generation Rank', 'Electric Generation Rank',
#        'Commercial Generation Rank', 'Capacity Growth Status',
#        'CAIDI w/ Major Events', 'CAIDI w/o Major Events', 'SAIFI Major Events',
#        'BA Code', 'Utility Annual Energy Savings (MWh)',
#        'Utility Peak Demand Savings (MW)', 'Utility Annual Incentive Cost ($)',
#        'Utility Commercial Avg Life (Yrs)', 'Region',
#        'Regional Electricity Demand', 'IXP Name', 'IXP_Count'],
#       dtype='object')

# %% [markdown]
# ### Loading Retail Costs

# %%
retail_costs = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Retail_Costs.csv', index_col=0)
retail_costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1218 entries, 0 to 1238
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            1218 non-null   object
#  1   CITY            1218 non-null   object
#  2   STATE           1218 non-null   object
#  3   Total_MWh_Rank  1218 non-null   object
#  4   Purchased_Rank  1218 non-null   object
# dtypes: object(5)
# memory usage: 57.1+ KB

# %%
retail_costs.head()
# Out:
#                        NAME         CITY STATE Total_MWh_Rank Purchased_Rank
# 0              EVERGY METRO  KANSAS CITY    KS           High           High
# 1  EVERGY KANSAS SOUTH, INC       TOPEKA    KS           High           High
# 2  KARNES ELECTRIC COOP INC  KARNES CITY    TX           High           High
# 3         KAY ELECTRIC COOP    BLACKWELL    OK       Moderate       Moderate
# 4   FREESTATE ELECTRIC COOP      MCLOUTH    KS            Low            Low

# %%
retail_costs = retail_costs.rename(columns={'STATE': 'State', 'NAME': 'Name', 'CITY':'City',
                                'Purchased_Rank': 'Purchased Rank', 'Total_MWh_Rank': 'Total MWh Rank'})
retail_costs['City'].value_counts()
# Out:
# City
# COLUMBUS          12
# JACKSON            6
# AKRON              6
# MADISON            5
# LEBANON            5
#                   ..
# MONTE VISTA        1
# KINGSTREE          1
# SAN DIEGO          1
# MOUNT PLEASANT     1
# COLDWATER          1
# Name: count, Length: 994, dtype: int64

# %%
# Check number of states in retail
len(retail_costs['State'].value_counts())
# Out:
# 52

# %%
retail_costs['State'].value_counts()

# Drop US territories
retail_costs = retail_costs[~retail_costs['State'].isin(['PR', 'GU', 'VI', 'AS', 'CNMI'])]
retail_costs['State'].value_counts()
# Out:
# State
# TN    82
# TX    75
# WI    64
# GA    55
# NC    47
# OH    47
# AL    43
# IN    43
# MN    41
# KY    41
# MO    41
# MS    40
# FL    37
# WA    37
# CA    30
# CO    29
# OK    29
# SC    28
# MI    28
# AR    26
# IL    22
# KS    21
# LA    21
# MA    21
# IA    21
# NE    20
# OR    20
# PA    20
# AZ    17
# VA    17
# NY    16
# ND    15
# SD    15
# NM    14
# UT    12
# ID     9
# NV     9
# AK     7
# MT     7
# DE     6
# WY     6
# CT     6
# MD     5
# ME     5
# NH     5
# HI     4
# NJ     4
# VT     4
# RI     3
# DC     1
# WV     1
# Name: count, dtype: int64

# %%
len(retail_costs['State'].value_counts())
# Out:
# 51

# %%
# Check number of states in merged 4

len(merged_4['State'].value_counts())
# Out:
# 48

# %%
#Lowercase City column
retail_costs['City'] = retail_costs['City'].str.title()
retail_costs['City'].value_counts()
# Out:
# City
# Columbus          12
# Jackson            6
# Akron              6
# Madison            5
# Lebanon            5
#                   ..
# Kingstree          1
# San Diego          1
# Mount Pleasant     1
# Livingston         1
# Coldwater          1
# Name: count, Length: 993, dtype: int64

# %%
retail_costs
# Out:
#                                 Name          City State Total MWh Rank  \
# 0                       EVERGY METRO   Kansas City    KS           High
# 1           EVERGY KANSAS SOUTH, INC        Topeka    KS           High
# 2           KARNES ELECTRIC COOP INC   Karnes City    TX           High
# 3                  KAY ELECTRIC COOP     Blackwell    OK       Moderate
# 4            FREESTATE ELECTRIC COOP       Mclouth    KS            Low
# ...                              ...           ...   ...            ...
# 1234             CLYDE LIGHT & POWER         Clyde    OH            Low
# 1235             CITY OF FLORESVILLE   Floresville    TX       Moderate
# 1236            CITY OF NATCHITOCHES  Natchitoches    LA            Low
# 1237     SHAWANO MUNICIPAL UTILITIES       Shawano    WI            Low
# 1238  COLDWATER BOARD OF PUBLIC UTIL     Coldwater    MI       Moderate
#
#      Purchased Rank
# 0              High
# 1              High
# 2              High
# 3          Moderate
# 4               Low
# ...             ...
# 1234            Low
# 1235       Moderate
# 1236            Low
# 1237            Low
# 1238       Moderate
#
# [1217 rows x 5 columns]

# %%
# Merge on both State and City
merged_5 = pd.merge(
    merged_4,
    retail_costs,
    on=['State', 'City'],
    how='outer'
)

merged_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3847 entries, 0 to 3846
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 3808 non-null   object
#  1   State                                3847 non-null   object
#  2   Total Generation Rank                2709 non-null   object
#  3   Electric Generation Rank             2709 non-null   object
#  4   Commercial Generation Rank           2709 non-null   object
#  5   Capacity Growth Status               2709 non-null   object
#  6   CAIDI w/ Major Events                2709 non-null   float64
#  7   CAIDI w/o Major Events               2709 non-null   float64
#  8   SAIFI Major Events                   2709 non-null   object
#  9   BA Code                              2709 non-null   object
#  10  Utility Annual Energy Savings (MWh)  2709 non-null   object
#  11  Utility Peak Demand Savings (MW)     2709 non-null   object
#  12  Utility Annual Incentive Cost ($)    2709 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    2709 non-null   object
#  14  Region                               2709 non-null   object
#  15  Regional Electricity Demand          2630 non-null   object
#  16  IXP Name                             2709 non-null   object
#  17  IXP_Count                            2709 non-null   float64
#  18  Name                                 2854 non-null   object
#  19  Total MWh Rank                       2854 non-null   object
#  20  Purchased Rank                       2854 non-null   object
# dtypes: float64(3), object(18)
# memory usage: 631.3+ KB

# %%
merged_5 = merged_5.dropna(subset=['Total Generation Rank'])
merged_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2709 entries, 12 to 3846
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2670 non-null   object
#  1   State                                2709 non-null   object
#  2   Total Generation Rank                2709 non-null   object
#  3   Electric Generation Rank             2709 non-null   object
#  4   Commercial Generation Rank           2709 non-null   object
#  5   Capacity Growth Status               2709 non-null   object
#  6   CAIDI w/ Major Events                2709 non-null   float64
#  7   CAIDI w/o Major Events               2709 non-null   float64
#  8   SAIFI Major Events                   2709 non-null   object
#  9   BA Code                              2709 non-null   object
#  10  Utility Annual Energy Savings (MWh)  2709 non-null   object
#  11  Utility Peak Demand Savings (MW)     2709 non-null   object
#  12  Utility Annual Incentive Cost ($)    2709 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    2709 non-null   object
#  14  Region                               2709 non-null   object
#  15  Regional Electricity Demand          2630 non-null   object
#  16  IXP Name                             2709 non-null   object
#  17  IXP_Count                            2709 non-null   float64
#  18  Name                                 1716 non-null   object
#  19  Total MWh Rank                       1716 non-null   object
#  20  Purchased Rank                       1716 non-null   object
# dtypes: float64(3), object(18)
# memory usage: 465.6+ KB

# %%
merged_5 = merged_5.dropna(subset=['City'])
merged_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2670 entries, 12 to 3805
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2670 non-null   object
#  1   State                                2670 non-null   object
#  2   Total Generation Rank                2670 non-null   object
#  3   Electric Generation Rank             2670 non-null   object
#  4   Commercial Generation Rank           2670 non-null   object
#  5   Capacity Growth Status               2670 non-null   object
#  6   CAIDI w/ Major Events                2670 non-null   float64
#  7   CAIDI w/o Major Events               2670 non-null   float64
#  8   SAIFI Major Events                   2670 non-null   object
#  9   BA Code                              2670 non-null   object
#  10  Utility Annual Energy Savings (MWh)  2670 non-null   object
#  11  Utility Peak Demand Savings (MW)     2670 non-null   object
#  12  Utility Annual Incentive Cost ($)    2670 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    2670 non-null   object
#  14  Region                               2670 non-null   object
#  15  Regional Electricity Demand          2591 non-null   object
#  16  IXP Name                             2670 non-null   object
#  17  IXP_Count                            2670 non-null   float64
#  18  Name                                 1716 non-null   object
#  19  Total MWh Rank                       1716 non-null   object
#  20  Purchased Rank                       1716 non-null   object
# dtypes: float64(3), object(18)
# memory usage: 458.9+ KB

# %%
merged_5[merged_5['Total MWh Rank'].isna()]
# Out:
#                       City State Total Generation Rank  \
# 12                  Auburn    AL                  High
# 13                  Auburn    AL                  High
# 34              Montgomery    AL                  High
# 35              Montgomery    AL                  High
# 86               Flagstaff    AZ                  High
# ...                    ...   ...                   ...
# 3551                Reston    VA                  High
# 3565            Montpelier    VT                   Low
# 3566            Montpelier    VT                   Low
# 3567  White River Junction    VT                   Low
# 3568  White River Junction    VT                   Low
#
#      Electric Generation Rank Commercial Generation Rank  \
# 12                       High                        Low
# 13                       High                        Low
# 34                       High                        Low
# 35                       High                        Low
# 86                       High                   Moderate
# ...                       ...                        ...
# 3551                     High                       High
# 3565                      Low                        Low
# 3566                      Low                        Low
# 3567                      Low                        Low
# 3568                      Low                        Low
#
#      Capacity Growth Status  CAIDI w/ Major Events  CAIDI w/o Major Events  \
# 12                  Growing                  186.9                   122.8
# 13                  Growing                  186.9                   122.8
# 34                  Growing                  186.9                   122.8
# 35                  Growing                  186.9                   122.8
# 86                  Growing                  108.6                    84.8
# ...                     ...                    ...                     ...
# 3551                Growing                  151.3                   124.2
# 3565              Shrinking                  316.5                   140.0
# 3566              Shrinking                  316.5                   140.0
# 3567              Shrinking                  316.5                   140.0
# 3568              Shrinking                  316.5                   140.0
#
#      SAIFI Major Events BA Code  ... Utility Peak Demand Savings (MW)  \
# 12             Moderate    SOCO  ...                             High
# 13             Moderate     TVA  ...                         Moderate
# 34             Moderate    SOCO  ...                             High
# 35             Moderate     TVA  ...                         Moderate
# 86                  Low    AZPS  ...                             High
# ...                 ...     ...  ...                              ...
# 3551           Moderate     PJM  ...                             High
# 3565               High    ISNE  ...                         Moderate
# 3566               High    ISNE  ...                         Moderate
# 3567               High    ISNE  ...                         Moderate
# 3568               High    ISNE  ...                         Moderate
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 12                            Moderate                               Low
# 13                            Moderate                          Moderate
# 34                            Moderate                               Low
# 35                            Moderate                          Moderate
# 86                                High                          Moderate
# ...                                ...                               ...
# 3551                              High                          Moderate
# 3565                          Moderate                              High
# 3566                              High                          Moderate
# 3567                          Moderate                              High
# 3568                              High                          Moderate
#
#      Region Regional Electricity Demand  \
# 12       SE                    Moderate
# 13       SE                    Moderate
# 34       SE                    Moderate
# 35       SE                    Moderate
# 86       SW                         Low
# ...     ...                         ...
# 3551   MIDA                        High
# 3565     NE                         Low
# 3566     NE                         Low
# 3567     NE                         Low
# 3568     NE                         Low
#
#                                              IXP Name IXP_Count  Name  \
# 12                                    Ninja-IX Auburn       2.0   NaN
# 13                                    Ninja-IX Auburn       2.0   NaN
# 34    Montgomery Internet Exchange - MGMix Montgomery       2.0   NaN
# 35    Montgomery Internet Exchange - MGMix Montgomery       2.0   NaN
# 86             Amateur Radio Internet Exchange - ARIX       8.0   NaN
# ...                                               ...       ...   ...
# 3551                           LINX Northern Virginia      11.0   NaN
# 3565               Lightboard Burlington IX (Vermont)       1.0   NaN
# 3566               Lightboard Burlington IX (Vermont)       1.0   NaN
# 3567               Lightboard Burlington IX (Vermont)       1.0   NaN
# 3568               Lightboard Burlington IX (Vermont)       1.0   NaN
#
#      Total MWh Rank Purchased Rank
# 12              NaN            NaN
# 13              NaN            NaN
# 34              NaN            NaN
# 35              NaN            NaN
# 86              NaN            NaN
# ...             ...            ...
# 3551            NaN            NaN
# 3565            NaN            NaN
# 3566            NaN            NaN
# 3567            NaN            NaN
# 3568            NaN            NaN
#
# [954 rows x 21 columns]

# %%
merged_5.isna().sum()
# Out:
# City                                     0
# State                                    0
# Total Generation Rank                    0
# Electric Generation Rank                 0
# Commercial Generation Rank               0
# Capacity Growth Status                   0
# CAIDI w/ Major Events                    0
# CAIDI w/o Major Events                   0
# SAIFI Major Events                       0
# BA Code                                  0
# Utility Annual Energy Savings (MWh)      0
# Utility Peak Demand Savings (MW)         0
# Utility Annual Incentive Cost ($)        0
# Utility Commercial Avg Life (Yrs)        0
# Region                                   0
# Regional Electricity Demand             79
# IXP Name                                 0
# IXP_Count                                0
# Name                                   954
# Total MWh Rank                         954
# Purchased Rank                         954
# dtype: int64

# %% [markdown]
# ## Loading in Emissions Data

# %%
emissions = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Emissions.csv', index_col=0)

emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7511 entries, 0 to 7510
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   REPORTING YEAR                   7511 non-null   int64
#  1   FACILITY NAME                    7511 non-null   object
#  2   LATITUDE                         7511 non-null   float64
#  3   LONGITUDE                        7511 non-null   float64
#  4   CITY                             7511 non-null   object
#  5   COUNTY                           7511 non-null   object
#  6   STATE                            7511 non-null   object
#  7   ZIP CODE                         7511 non-null   int64
#  8   PARENT COMPANIES                 7511 non-null   object
#  9   GHG QUANTITY (METRIC TONS CO2e)  7511 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 645.5+ KB

# %%
emissions.head()
# Out:
#    REPORTING YEAR                                FACILITY NAME   LATITUDE  \
# 0            2023      (430) Civitas Resources - Permian Basin  39.745220
# 1            2023       (540) Civitas Resources - Denver Basin  39.744310
# 2            2023  (540) Civitas Resources - GB - Denver Basin  39.745822
# 3            2023               121 REGIONAL DISPOSAL FACILITY  33.298570
# 4            2023                            15-18565/15-18662  37.274127
#
#     LONGITUDE     CITY         COUNTY STATE  ZIP CODE  \
# 0 -104.989197   Denver        Unknown    CO     80202
# 1 -104.988580   Denver        Unknown    CO     80202
# 2 -104.989243   Denver        Unknown    CO     80202
# 3  -96.535860  MELISSA  COLLIN COUNTY    TX     75454
# 4  -83.239034   Hazard   PERRY COUNTY    KY     40701
#
#                        PARENT COMPANIES  GHG QUANTITY (METRIC TONS CO2e)
# 0                 CIVITAS RESOURCES INC                           844548
# 1                 CIVITAS RESOURCES INC                           887487
# 2                 CIVITAS RESOURCES INC                           110747
# 3  NORTH TEXAS MUNICIPAL WATER DISTRICT                           288302
# 4                     CAMBRIAN COAL LLC                           122327

# %%
# Standardize column names
emissions = emissions.rename(columns={'LATITUDE': 'Latitude',
                                      'LONGITUDE': 'Longitude',
                                      'CITY':'City',
                                      'COUNTY':'County',
                                      'STATE':'State',
                                      'ZIP CODE':'Zip Code',
                                      'GHG QUANTITY (METRIC TONS CO2e)':'GHG (MTCO2)'})


#Drop unnecessary columns
emissions =emissions.drop(columns=['REPORTING YEAR', 'FACILITY NAME', 'PARENT COMPANIES'])

# %%
emissions.head()
# Out:
#     Latitude   Longitude     City         County State  Zip Code  GHG (MTCO2)
# 0  39.745220 -104.989197   Denver        Unknown    CO     80202       844548
# 1  39.744310 -104.988580   Denver        Unknown    CO     80202       887487
# 2  39.745822 -104.989243   Denver        Unknown    CO     80202       110747
# 3  33.298570  -96.535860  MELISSA  COLLIN COUNTY    TX     75454       288302
# 4  37.274127  -83.239034   Hazard   PERRY COUNTY    KY     40701       122327

# %%
# Standardize  City and County values as title case
emissions['City'] = emissions['City'].str.title()
emissions['County'] = emissions['County'].str.title()
emissions.head()
# Out:
#     Latitude   Longitude     City         County State  Zip Code  GHG (MTCO2)
# 0  39.745220 -104.989197   Denver        Unknown    CO     80202       844548
# 1  39.744310 -104.988580   Denver        Unknown    CO     80202       887487
# 2  39.745822 -104.989243   Denver        Unknown    CO     80202       110747
# 3  33.298570  -96.535860  Melissa  Collin County    TX     75454       288302
# 4  37.274127  -83.239034   Hazard   Perry County    KY     40701       122327

# %%
emissions.isna().value_counts()
# Out:
# Latitude  Longitude  City   County  State  Zip Code  GHG (MTCO2)
# False     False      False  False   False  False     False          7511
# Name: count, dtype: int64

# %%
# Group by city and state and take the sum of GHG emissions to create a new column called City Emissions
emissions['City Emissions'] = emissions.groupby(['State', 'City'])['GHG (MTCO2)'].transform('sum')

# Group by state and take the sum of GHG emissions to create a new column called State Emissions
emissions['State Emissions'] = emissions.groupby(['State'])['GHG (MTCO2)'].transform('sum')
emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7511 entries, 0 to 7510
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Latitude         7511 non-null   float64
#  1   Longitude        7511 non-null   float64
#  2   City             7511 non-null   object
#  3   County           7511 non-null   object
#  4   State            7511 non-null   object
#  5   Zip Code         7511 non-null   int64
#  6   GHG (MTCO2)      7511 non-null   int64
#  7   City Emissions   7511 non-null   int64
#  8   State Emissions  7511 non-null   int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 586.8+ KB

# %%
# Drop Longitude and Latitude columns since we do not need facility locations
emissions = emissions.drop(columns=['Longitude', 'Latitude'])
emissions.head()
# Out:
#       City         County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 0   Denver        Unknown    CO     80202       844548        21738141
# 1   Denver        Unknown    CO     80202       887487        21738141
# 2   Denver        Unknown    CO     80202       110747        21738141
# 3  Melissa  Collin County    TX     75454       288302          288302
# 4   Hazard   Perry County    KY     40701       122327          164154
#
#    State Emissions
# 0         62456744
# 1         62456744
# 2         62456744
# 3        485547330
# 4         65132445

# %%
# Group by county and state and take the sum of GHG emissions to create a County Emissions columns
emissions['County Emissions'] = emissions.groupby(['State', 'County'])['GHG (MTCO2)'].transform('sum')
emissions.head()
# Out:
#       City         County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 0   Denver        Unknown    CO     80202       844548        21738141
# 1   Denver        Unknown    CO     80202       887487        21738141
# 2   Denver        Unknown    CO     80202       110747        21738141
# 3  Melissa  Collin County    TX     75454       288302          288302
# 4   Hazard   Perry County    KY     40701       122327          164154
#
#    State Emissions  County Emissions
# 0         62456744          12704001
# 1         62456744          12704001
# 2         62456744          12704001
# 3        485547330           1381024
# 4         65132445            164154

# %%
emissions[emissions['Zip Code'] == 0]
# Out:
#           City   County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 63    Offshore  Unknown    TX         0       180279          349404
# 504   Offshore  Unknown    LA         0       134118         5733285
# 539   Offshore  Unknown    LA         0       256468         5733285
# 623   Offshore  Unknown    CA         0        35125           35125
# 893   Offshore  Unknown    TX         0        38935          349404
# ...        ...      ...   ...       ...          ...             ...
# 7268  Offshore  Unknown    LA         0       194726         5733285
# 7269  Offshore  Unknown    LA         0        53572         5733285
# 7322  Offshore  Unknown    LA         0        12452         5733285
# 7323  Offshore  Unknown    LA         0         8883         5733285
# 7390  Offshore  Unknown    LA         0        64602         5733285
#
#       State Emissions  County Emissions
# 63          485547330          66853798
# 504         145975918           7986796
# 539         145975918           7986796
# 623          99305182           6791172
# 893         485547330          66853798
# ...               ...               ...
# 7268        145975918           7986796
# 7269        145975918           7986796
# 7322        145975918           7986796
# 7323        145975918           7986796
# 7390        145975918           7986796
#
# [102 rows x 8 columns]

# %%
# Drop rows where Zip Code is 0
emissions = emissions[emissions['Zip Code'] != 0]

# %%
emissions[emissions['County'] == 'Unknown'].head(50)
# Out:
#               City   County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 0           Denver  Unknown    CO     80202       844548        21738141
# 1           Denver  Unknown    CO     80202       887487        21738141
# 2           Denver  Unknown    CO     80202       110747        21738141
# 6           Denver  Unknown    CO     80203        27277        21738141
# 7           Denver  Unknown    CO     80203        27277        21738141
# 9    Oklahoma City  Unknown    OK     73102      1166132        13403543
# 11         Houston  Unknown    TX     77079        13382        57927547
# 16   Oklahoma City  Unknown    OK     73142       182531        13403543
# 18   Oklahoma City  Unknown    OK     73102       310278        13403543
# 19          Denver  Unknown    CO     80202       125092        21738141
# 22   Oklahoma City  Unknown    OK     73102        26472        13403543
# 33         Moncure  Unknown    NC     27559        27051          110044
# 34      Fort Worth  Unknown    TX     76106       163140         5341634
# 35      Fort Worth  Unknown    TX     76106       600459         5341634
# 37      Fort Worth  Unknown    TX     76106        27713         5341634
# 38      Bridgeport  Unknown    TX     76426       664355         1427501
# 40         Houston  Unknown    TX     77079       116847        57927547
# 41   Oklahoma City  Unknown    OK     73102       219519        13403543
# 44   Oklahoma City  Unknown    OK     73102        55787        13403543
# 47   Oklahoma City  Unknown    OK     73102       207646        13403543
# 48         Durango  Unknown    CO     81301       252801         2573657
# 49         Durango  Unknown    CO     81301       969987         2573657
# 56          Pelkie  Unknown    MI     49958       106545          106545
# 131        Wheeler  Unknown    TX     79014        38739          126807
# 157         Denver  Unknown    CO     80202        86654        21738141
# 158         Denver  Unknown    CO     80202       170182        21738141
# 248        Midland  Unknown    TX     79701        40854        19885494
# 271        Houston  Unknown    TX     77002        42517        57927547
# 280        Houston  Unknown    TX     77002        31349        57927547
# 281        Houston  Unknown    TX     77002       128789        57927547
# 311       Aberdeen  Unknown    SD     57401        22998          134093
# 314    San Antonio  Unknown    TX     78258        13060         9941065
# 327          Ceres  Unknown    CA     95307        40569           40569
# 342    Bakersfield  Unknown    CA     93311        14138         4637586
# 345         Dallas  Unknown    TX     75251       208603        18887520
# 346         Dallas  Unknown    TX     75251       306010        18887520
# 355       Robstown  Unknown    TX     78380       253109          490203
# 373       Martinez  Unknown    CA     94553       446432         4345635
# 375       Martinez  Unknown    CA     94553       322459         4345635
# 383         Akutan  Unknown    AK     99553        46061           46061
# 414       Rayville  Unknown    LA     71269        45031           45031
# 417        Midland  Unknown    TX     79705       262437        19885494
# 419         Austin  Unknown    TX     78746        38291         3679795
# 432        Houston  Unknown    TX     77002       120000        57927547
# 433        Houston  Unknown    TX     77002        14148        57927547
# 448        Houston  Unknown    TX     77002       142319        57927547
# 452         Denver  Unknown    CO     80202       334610        21738141
# 458         Denver  Unknown    CO     80202        20739        21738141
# 459         Denver  Unknown    CO     80202       200323        21738141
# 461        Houston  Unknown    TX     77056       756504        57927547
#
#      State Emissions  County Emissions
# 0           62456744          12704001
# 1           62456744          12704001
# 2           62456744          12704001
# 6           62456744          12704001
# 7           62456744          12704001
# 9           70166208          11908297
# 11         485547330          66853798
# 16          70166208          11908297
# 18          70166208          11908297
# 19          62456744          12704001
# 22          70166208          11908297
# 33          44658028             49533
# 34         485547330          66853798
# 35         485547330          66853798
# 37         485547330          66853798
# 38         485547330          66853798
# 40         485547330          66853798
# 41          70166208          11908297
# 44          70166208          11908297
# 47          70166208          11908297
# 48          62456744          12704001
# 49          62456744          12704001
# 56          69044087            957310
# 131        485547330          66853798
# 157         62456744          12704001
# 158         62456744          12704001
# 248        485547330          66853798
# 271        485547330          66853798
# 280        485547330          66853798
# 281        485547330          66853798
# 311          6299963            250931
# 314        485547330          66853798
# 327         99305182           6791172
# 342         99305182           6791172
# 345        485547330          66853798
# 346        485547330          66853798
# 355        485547330          66853798
# 373         99305182           6791172
# 375         99305182           6791172
# 383         19581674            958847
# 414        145975918           7986796
# 417        485547330          66853798
# 419        485547330          66853798
# 432        485547330          66853798
# 433        485547330          66853798
# 448        485547330          66853798
# 452         62456744          12704001
# 458         62456744          12704001
# 459         62456744          12704001
# 461        485547330          66853798

# %%
pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: requests in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pgeocode) (2.32.3)
# Requirement already satisfied: numpy in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pgeocode) (1.26.4)
# Requirement already satisfied: pandas in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pgeocode) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pandas->pgeocode) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pandas->pgeocode) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pandas->pgeocode) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pgeocode) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Map the zip codes to their counties
import pgeocode

# %%
# Convert zip codes to strings first and create the mapping
emissions['Zip Code'] = emissions['Zip Code'].astype(str)

# Create a clean mapping dictionary
zip_to_county = {}
nomi = pgeocode.Nominatim('us')

# Loop through unique zip codes only
for zip_code in emissions['Zip Code'].unique():
    try:
        location = nomi.query_postal_code(zip_code)
        if location is not None and not pd.isna(location['county_name']):
            county = location['county_name'] + ' County'
            zip_to_county[zip_code] = county
    except:
        continue

# Apply the mapping with a safe approach
emissions.loc[emissions['County'] == 'Unknown', 'County'] = \
    emissions.loc[emissions['County'] == 'Unknown', 'Zip Code'].map(zip_to_county).fillna('Unknown')

# %%
emissions[emissions['County'].isna()]
# Out:
# Empty DataFrame
# Columns: [City, County, State, Zip Code, GHG (MTCO2), City Emissions, State Emissions, County Emissions]
# Index: []

# %%
emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7409 entries, 0 to 7510
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              7409 non-null   object
#  1   County            7409 non-null   object
#  2   State             7409 non-null   object
#  3   Zip Code          7409 non-null   object
#  4   GHG (MTCO2)       7409 non-null   int64
#  5   City Emissions    7409 non-null   int64
#  6   State Emissions   7409 non-null   int64
#  7   County Emissions  7409 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 520.9+ KB

# %%
# Drop VI, Guam from dataframe
emissions = emissions[~emissions['State'].isin(['VI', 'GU'])]


emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7395 entries, 0 to 7510
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              7395 non-null   object
#  1   County            7395 non-null   object
#  2   State             7395 non-null   object
#  3   Zip Code          7395 non-null   object
#  4   GHG (MTCO2)       7395 non-null   int64
#  5   City Emissions    7395 non-null   int64
#  6   State Emissions   7395 non-null   int64
#  7   County Emissions  7395 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 520.0+ KB

# %%
# Count duplicates of City State combinations
emissions.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  City            County
# TX     Houston         Harris County              231
#        Dallas          Dallas County               87
# CO     Denver          Denver County               79
# OK     Oklahoma City   Oklahoma County             56
# TX     Midland         Midland County              39
# OK     Tulsa           Tulsa County                38
# CA     Bakersfield     Kern County                 29
# TX     Fort Worth      Tarrant County              27
#        Pasadena        Harris County               24
#        Austin          Travis County               24
# KY     Louisville      Jefferson County            20
# TX     Plano           Collin County               17
#        San Antonio     Bexar County                16
# LA     Geismar         Ascension Parish            16
# NV     Las Vegas       Clark County                15
# AK     Prudhoe Bay     North Slope Borough         14
# OK     Tulsa           Wagoner County              14
# LA     Baton Rouge     East Baton Rouge Parish     14
# TX     Corpus Christi  Nueces County               14
#        Port Arthur     Jefferson County            13
# LA     Westlake        Calcasieu Parish            13
# UT     Salt Lake City  Salt Lake County            13
# TX     The Woodlands   Montgomery County           12
# TN     Memphis         Shelby County               12
# IL     Chicago         Cook County                 11
# MI     Detroit         Wayne County                10
# TX     Coyanosa        Pecos County                10
#        Orla            Reeves County               10
# MN     Minneapolis     Hennepin County             10
# HI     Kapolei         Honolulu County             10
# dtype: int64

# %%
# Count duplicates of County State combinations
emissions.groupby(['State', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  County
# TX     Harris County            293
#        Dallas County            102
# CO     Denver County             80
# OK     Oklahoma County           67
# CA     Kern County               55
#        Los Angeles County        52
# TX     Midland County            42
# OK     Tulsa County              41
# TX     Tarrant County            32
# CO     Weld County               30
# TX     Jefferson County          29
# LA     Calcasieu Parish          27
# MI     Wayne County              26
# TX     Travis County             25
#        Collin County             25
# CA     San Bernardino County     24
# NV     Clark County              24
# PA     Allegheny County          24
# CA     Contra Costa County       23
# IL     Cook County               22
# AL     Mobile County             22
# KY     Jefferson County          20
# TX     Nueces County             20
# AZ     Maricopa County           20
# TX     Bexar County              20
#        Brazoria County           20
# LA     Ascension Parish          19
# TX     Reeves County             19
# NM     Lea County                18
#        Eddy County               18
# dtype: int64

# %%
# Function to standardize county names
def standardize_county_name(county):
    # Remove any trailing/leading whitespace
    county = county.strip()
    
    # If it already ends with 'County', return as is
    if county.endswith('County'):
        return county
    # If it ends with 'Parish', return as is (for Louisiana)
    elif county.endswith('Parish'):
        return county
    # If it's not 'Unknown', append 'County'
    elif county != 'Unknown':
        return f"{county} County"
    return county

# Apply the standardization
emissions['County'] = emissions['County'].apply(standardize_county_name)

# Verify the results
print("After standardization:")
print(emissions.groupby(['State', 'County']).size().sort_values(ascending=False).head(30))
# Out:
# After standardization:
# State  County
# TX     Harris County            302
#        Dallas County            104
# CO     Denver County             81
# OK     Oklahoma County           69
# CA     Los Angeles County        65
#        Kern County               58
# OK     Tulsa County              44
# TX     Midland County            42
# CO     Weld County               34
# TX     Tarrant County            33
# NV     Clark County              31
# TX     Jefferson County          30
# AZ     Maricopa County           30
# MI     Wayne County              30
# PA     Allegheny County          29
# TX     Travis County             27
# LA     Calcasieu Parish          27
# CA     San Bernardino County     27
# TX     Collin County             26
# CA     Contra Costa County       26
# AL     Mobile County             25
# TX     Bexar County              24
# IL     Cook County               24
# TX     Nueces County             23
# NM     Lea County                22
# CA     San Diego County          21
# TX     Brazoria County           20
# KY     Jefferson County          20
# IL     Will County               20
# LA     Ascension Parish          19
# dtype: int64

# %%
# Count duplicates of City County State combinations
emissions.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  City            County
# TX     Houston         Harris County                 234
#        Dallas          Dallas County                  88
# CO     Denver          Denver County                  80
# OK     Oklahoma City   Oklahoma County                56
# TX     Midland         Midland County                 39
# OK     Tulsa           Tulsa County                   39
# CA     Bakersfield     Kern County                    29
# TX     Fort Worth      Tarrant County                 28
#        Pasadena        Harris County                  27
#        Austin          Travis County                  26
# KY     Louisville      Jefferson County               20
# NV     Las Vegas       Clark County                   19
# TX     San Antonio     Bexar County                   19
#        Plano           Collin County                  17
#        Corpus Christi  Nueces County                  17
# LA     Geismar         Ascension Parish               16
# AK     Prudhoe Bay     North Slope Borough County     14
# OK     Tulsa           Wagoner County                 14
# TN     Memphis         Shelby County                  14
# LA     Baton Rouge     East Baton Rouge Parish        14
# UT     Salt Lake City  Salt Lake County               14
# TX     Port Arthur     Jefferson County               13
# LA     Westlake        Calcasieu Parish               13
# TX     The Woodlands   Montgomery County              12
# CA     San Diego       San Diego County               12
# IL     Chicago         Cook County                    11
# WY     Gillette        Campbell County                11
# IN     Indianapolis    Marion County                  11
# MN     Minneapolis     Hennepin County                11
# TX     La Porte        Harris County                  11
# dtype: int64

# %%
emissions.describe()
# Out:
#         GHG (MTCO2)  City Emissions  State Emissions  County Emissions
# count  7.395000e+03    7.395000e+03     7.395000e+03      7.395000e+03
# mean   3.473599e+05    3.826918e+06     1.375983e+08      6.412769e+06
# std    9.770849e+05    1.069036e+07     1.639574e+08      1.579855e+07
# min    1.000000e+00    1.000000e+00     2.793500e+05      2.000000e+00
# 25%    3.182200e+04    7.571400e+04     3.809004e+07      1.862940e+05
# 50%    6.612400e+04    2.987140e+05     6.904409e+07      6.840000e+05
# 75%    1.868185e+05    2.024348e+06     1.091249e+08      3.205540e+06
# max    1.655838e+07    5.792755e+07     4.855473e+08      6.685380e+07

# %%
# Bin GHG quantity based on distribution of city emissions
def categorize_city_ghg(value):
    if value <= 75714:                        # 0-25th percentile
        return 'Low'
    elif 75714 < value <= 298714:             # 25th-50th percentile
        return 'Moderate'
    elif 298714 < value <= 2024348:           # 50th-75th percentile
        return 'High'            
    else:                                     # Above 75th percentile
        return 'Very High'

# Bin GHG quantity based on distribution of county emissions
def categorize_county_ghg(value):
    if value <= 186294:                       # 0-25th percentile
        return 'Low'
    elif 186294 < value <= 684000:            # 25th-50th percentile
        return 'Moderate'
    elif 684000 < value <= 3205540:           # 50th-75th percentile
        return 'High'
    else:                                     # Above 75th percentile
        return 'Very High'

# Bin GHG quantity based on distribution of state emissions
def categorize_state_ghg(value):
    if value <= 38090040:                     # 0-25th percentile
        return 'Low'
    elif 38090040 < value <= 69044090:        # 25th-50th percentile
        return 'Moderate'
    elif 69044090 < value <= 109124900:       # 50th-75th percentile
        return 'High'
    else:                                     # Above 75th percentile
        return 'Very High'

# Apply the categorization
emissions['City Emissions Level'] = emissions['City Emissions'].apply(categorize_city_ghg)
emissions['County Emissions Level'] = emissions['County Emissions'].apply(categorize_county_ghg)
emissions['State Emissions Level'] = emissions['State Emissions'].apply(categorize_state_ghg)

# %%
emissions.head()
# Out:
#       City         County State Zip Code  GHG (MTCO2)  City Emissions  \
# 0   Denver  Denver County    CO    80202       844548        21738141
# 1   Denver  Denver County    CO    80202       887487        21738141
# 2   Denver  Denver County    CO    80202       110747        21738141
# 3  Melissa  Collin County    TX    75454       288302          288302
# 4   Hazard   Perry County    KY    40701       122327          164154
#
#    State Emissions  County Emissions City Emissions Level  \
# 0         62456744          12704001            Very High
# 1         62456744          12704001            Very High
# 2         62456744          12704001            Very High
# 3        485547330           1381024             Moderate
# 4         65132445            164154             Moderate
#
#   County Emissions Level State Emissions Level
# 0              Very High              Moderate
# 1              Very High              Moderate
# 2              Very High              Moderate
# 3                   High             Very High
# 4                    Low              Moderate

# %%
# Drop the original numeric columns
emissions = emissions.drop(columns=['City Emissions', 'County Emissions', 'State Emissions', 'GHG (MTCO2)'])
emissions.head()
# Out:
#       City         County State Zip Code City Emissions Level  \
# 0   Denver  Denver County    CO    80202            Very High
# 1   Denver  Denver County    CO    80202            Very High
# 2   Denver  Denver County    CO    80202            Very High
# 3  Melissa  Collin County    TX    75454             Moderate
# 4   Hazard   Perry County    KY    40701             Moderate
#
#   County Emissions Level State Emissions Level
# 0              Very High              Moderate
# 1              Very High              Moderate
# 2              Very High              Moderate
# 3                   High             Very High
# 4                    Low              Moderate

# %%
# Drop duplicates based on State, City, County while keeping the first occurrence 
emissions = emissions.drop_duplicates(subset=['State', 'City', 'County'])

# %%
# Verify the results

emissions.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  City          County
# AK     Akutan        Aleutians East County    1
# OH     Toronto       Jefferson County         1
# OK     Blackwell     Kay County               1
#        Bradley       Grady County             1
#        Broken Arrow  Wagoner County           1
#        Broken Bow    Mccurtain County         1
#        Butler        Custer County            1
#        Byars         Mcclain County           1
#        Calumet       Canadian County          1
#        Calvin        Hughes County            1
#        Canute        Washita County           1
#        Cashion       Kingfisher County        1
#                      Logan County             1
#        Chouteau      Mayes County             1
#        Claremore     Rogers County            1
#        Coalgate      Coal County              1
#        Cogar         Caddo County             1
#        Countyline    Stephens County          1
#        Crawford      Roger Mills County       1
#        Custer City   Custer County            1
#        Depew         Creek County             1
#        Dover         Kingfisher County        1
#        Drummond      Garfield County          1
#        Duke          Jackson County           1
#        Durant        Bryan County             1
#        Edmond        Logan County             1
#                      Oklahoma County          1
#        Elmwood       Beaver County            1
#        Enid          Garfield County          1
#        Fletcher      Comanche County          1
# dtype: int64

# %%
merged_5.head()
# Out:
#           City State Total Generation Rank Electric Generation Rank  \
# 12      Auburn    AL                  High                     High
# 13      Auburn    AL                  High                     High
# 34  Montgomery    AL                  High                     High
# 35  Montgomery    AL                  High                     High
# 86   Flagstaff    AZ                  High                     High
#
#    Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 12                        Low                Growing                  186.9
# 13                        Low                Growing                  186.9
# 34                        Low                Growing                  186.9
# 35                        Low                Growing                  186.9
# 86                   Moderate                Growing                  108.6
#
#     CAIDI w/o Major Events SAIFI Major Events BA Code  ...  \
# 12                   122.8           Moderate    SOCO  ...
# 13                   122.8           Moderate     TVA  ...
# 34                   122.8           Moderate    SOCO  ...
# 35                   122.8           Moderate     TVA  ...
# 86                    84.8                Low    AZPS  ...
#
#    Utility Peak Demand Savings (MW) Utility Annual Incentive Cost ($)  \
# 12                             High                          Moderate
# 13                         Moderate                          Moderate
# 34                             High                          Moderate
# 35                         Moderate                          Moderate
# 86                             High                              High
#
#    Utility Commercial Avg Life (Yrs) Region Regional Electricity Demand  \
# 12                               Low     SE                    Moderate
# 13                          Moderate     SE                    Moderate
# 34                               Low     SE                    Moderate
# 35                          Moderate     SE                    Moderate
# 86                          Moderate     SW                         Low
#
#                                            IXP Name IXP_Count  Name  \
# 12                                  Ninja-IX Auburn       2.0   NaN
# 13                                  Ninja-IX Auburn       2.0   NaN
# 34  Montgomery Internet Exchange - MGMix Montgomery       2.0   NaN
# 35  Montgomery Internet Exchange - MGMix Montgomery       2.0   NaN
# 86           Amateur Radio Internet Exchange - ARIX       8.0   NaN
#
#    Total MWh Rank Purchased Rank
# 12            NaN            NaN
# 13            NaN            NaN
# 34            NaN            NaN
# 35            NaN            NaN
# 86            NaN            NaN
#
# [5 rows x 21 columns]

# %%
# Merge emissions with merged 5
merged_6 = pd.merge(merged_5, emissions, on=['State', 'City'], how='outer')

merged_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7470 entries, 0 to 7469
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 7470 non-null   object
#  1   State                                7470 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               3447 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               7248 non-null   object
#  22  Zip Code                             7248 non-null   object
#  23  City Emissions Level                 7248 non-null   object
#  24  County Emissions Level               7248 non-null   object
#  25  State Emissions Level                7248 non-null   object
# dtypes: float64(3), object(23)
# memory usage: 1.5+ MB

# %%
merged_6.head()
# Out:
#            City State Total Generation Rank Electric Generation Rank  \
# 0        Akutan    AK                   NaN                      NaN
# 1  Anchor Point    AK                   NaN                      NaN
# 2     Anchorage    AK                   NaN                      NaN
# 3     Anchorage    AK                   NaN                      NaN
# 4     Anchorage    AK                   NaN                      NaN
#
#   Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
#
#    CAIDI w/o Major Events SAIFI Major Events BA Code  ... IXP Name IXP_Count  \
# 0                     NaN                NaN     NaN  ...      NaN       NaN
# 1                     NaN                NaN     NaN  ...      NaN       NaN
# 2                     NaN                NaN     NaN  ...      NaN       NaN
# 3                     NaN                NaN     NaN  ...      NaN       NaN
# 4                     NaN                NaN     NaN  ...      NaN       NaN
#
#   Name Total MWh Rank Purchased Rank                          County Zip Code  \
# 0  NaN            NaN            NaN           Aleutians East County    99553
# 1  NaN            NaN            NaN          Kenai Peninsula County    99556
# 2  NaN            NaN            NaN   Anchorage Municipality County    99503
# 3  NaN            NaN            NaN          Kenai Peninsula County    99503
# 4  NaN            NaN            NaN  Kenai Peninsula Borough County    99503
#
#    City Emissions Level County Emissions Level State Emissions Level
# 0                   Low                   High                   Low
# 1                   Low                   High                   Low
# 2             Very High                   High                   Low
# 3             Very High               Moderate                   Low
# 4             Very High                   High                   Low
#
# [5 rows x 26 columns]

# %%
# Emissions related data that is missing will be filled with unknown
emissions_cols = ['City Emissions Level', 'County Emissions Level', 'State Emissions Level']
merged_6[emissions_cols] = merged_6[emissions_cols].fillna('Unknown')

merged_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7470 entries, 0 to 7469
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 7470 non-null   object
#  1   State                                7470 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               3447 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               7248 non-null   object
#  22  Zip Code                             7248 non-null   object
#  23  City Emissions Level                 7470 non-null   object
#  24  County Emissions Level               7470 non-null   object
#  25  State Emissions Level                7470 non-null   object
# dtypes: float64(3), object(23)
# memory usage: 1.5+ MB

# %%
# Drop rows where essential ranking columns are missing 
merged_6 = merged_6.dropna(subset=['Total Generation Rank'])
merged_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3447 entries, 34 to 7312
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 3447 non-null   object
#  1   State                                3447 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               3447 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               3225 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3447 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                3447 non-null   object
# dtypes: float64(3), object(23)
# memory usage: 727.1+ KB

# %%
print(merged_5.shape)
print(emissions.shape)
# Out:
# (2670, 21)
# (4122, 7)

# %%
# Check duplicates in merged_6
print("\nDuplicates in merged_6:")
print(merged_6.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30))
# Out:
# Duplicates in merged_6:
# State  City           County
# CA     Fremont        Alameda County          286
#        San Francisco  San Francisco County    156
#        Los Angeles    Los Angeles County      156
# TX     Dallas         Dallas County           140
#                       Eddy County             140
#                       Montgomery County       140
# WA     Seattle        King County             102
# MA     Boston         Suffolk County           96
# NY     New York       Kings County             90
#                       New York County          90
# OR     Eugene         Lane County              90
# FL     Miami          Miami-Dade County        84
# CA     San Jose       Santa Clara County       78
# CO     Denver         Adams County             65
#                       Denver County            65
# OR     Portland       Multnomah County         60
# OH     Columbus       Washington County        60
#                       Franklin County          60
# AZ     Phoenix        Maricopa County          60
# TX     Houston        Tulsa County             56
#                       Santa Rosa County        56
#                       Harris County            56
# IL     Chicago        Cook County              55
# WA     Spokane        Spokane County           51
# MN     Minneapolis    Hennepin County          42
# OH     Akron          Summit County            30
# GA     Atlanta        Dekalb County            30
#                       Fulton County            30
# FL     Tampa          Hillsborough County      28
# TX     San Antonio    Harris County            28
# dtype: int64

# %% [markdown]
# # Loading in Broadband Data

# %%
broadband = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Broadband_Data.csv', index_col=0)

broadband.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11385 entries, 25125 to 580965
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   County                  11385 non-null  object
#  1   City                    11385 non-null  object
#  2   State                   11385 non-null  object
#  3   Geog_Area_Type          11385 non-null  object
#  4   Gigabit_Fiber_Coverage  11385 non-null  object
#  5   Business_Density        11385 non-null  object
# dtypes: object(6)
# memory usage: 622.6+ KB

# %%
broadband.head()
# Out:
#                County     City State Geog_Area_Type Gigabit_Fiber_Coverage  \
# 25125  Autauga County  Autauga    AL          Total                   Good
# 25155  Baldwin County  Baldwin    AL          Total               Moderate
# 25185  Barbour County  Barbour    AL          Total                Limited
# 25215     Bibb County     Bibb    AL          Total               Moderate
# 25245   Blount County   Blount    AL          Total                Limited
#
#       Business_Density
# 25125         Moderate
# 25155             High
# 25185         Moderate
# 25215              Low
# 25245         Moderate

# %%
broadband = broadband[broadband['Geog_Area_Type'] == 'Total']

# Drop Geog Area Type
broadband = broadband.drop(columns=['Geog_Area_Type'])

# %%
# Count duplicates of City County State
broadband.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  City                    County
# AK     Aleutians East Borough  Aleutians East Borough    1
# OH     Lake                    Lake County               1
#        Licking                 Licking County            1
#        Logan                   Logan County              1
#        Lorain                  Lorain County             1
#        Lucas                   Lucas County              1
#        Madison                 Madison County            1
#        Mahoning                Mahoning County           1
#        Marion                  Marion County             1
#        Medina                  Medina County             1
#        Meigs                   Meigs County              1
#        Mercer                  Mercer County             1
#        Miami                   Miami County              1
#        Monroe                  Monroe County             1
#        Montgomery              Montgomery County         1
#        Morgan                  Morgan County             1
#        Morrow                  Morrow County             1
#        Muskingum               Muskingum County          1
#        Noble                   Noble County              1
#        Ottawa                  Ottawa County             1
#        Paulding                Paulding County           1
#        Perry                   Perry County              1
#        Pickaway                Pickaway County           1
#        Lawrence                Lawrence County           1
#        Knox                    Knox County               1
# OK     Greer                   Greer County              1
# OH     Jefferson               Jefferson County          1
#        Defiance                Defiance County           1
#        Delaware                Delaware County           1
#        Erie                    Erie County               1
# dtype: int64

# %%
# Merge Broadband with merged_6
merged_7 = pd.merge(merged_6, broadband, on=['State', 'City', 'County'], how='outer')

merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6577 entries, 0 to 6576
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 6577 non-null   object
#  1   State                                6577 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               3447 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               6355 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3447 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                3447 non-null   object
#  26  Gigabit_Fiber_Coverage               3885 non-null   object
#  27  Business_Density                     3885 non-null   object
# dtypes: float64(3), object(25)
# memory usage: 1.4+ MB

# %%
merged_7.head()
# Out:
#                          City State Total Generation Rank  \
# 0      Aleutians East Borough    AK                   NaN
# 1  Aleutians West Census Area    AK                   NaN
# 2      Anchorage Municipality    AK                   NaN
# 3          Bethel Census Area    AK                   NaN
# 4         Bristol Bay Borough    AK                   NaN
#
#   Electric Generation Rank Commercial Generation Rank Capacity Growth Status  \
# 0                      NaN                        NaN                    NaN
# 1                      NaN                        NaN                    NaN
# 2                      NaN                        NaN                    NaN
# 3                      NaN                        NaN                    NaN
# 4                      NaN                        NaN                    NaN
#
#    CAIDI w/ Major Events  CAIDI w/o Major Events SAIFI Major Events BA Code  \
# 0                    NaN                     NaN                NaN     NaN
# 1                    NaN                     NaN                NaN     NaN
# 2                    NaN                     NaN                NaN     NaN
# 3                    NaN                     NaN                NaN     NaN
# 4                    NaN                     NaN                NaN     NaN
#
#    ... Name Total MWh Rank Purchased Rank                      County  \
# 0  ...  NaN            NaN            NaN      Aleutians East Borough
# 1  ...  NaN            NaN            NaN  Aleutians West Census Area
# 2  ...  NaN            NaN            NaN      Anchorage Municipality
# 3  ...  NaN            NaN            NaN          Bethel Census Area
# 4  ...  NaN            NaN            NaN         Bristol Bay Borough
#
#   Zip Code City Emissions Level County Emissions Level  State Emissions Level  \
# 0      NaN                  NaN                    NaN                    NaN
# 1      NaN                  NaN                    NaN                    NaN
# 2      NaN                  NaN                    NaN                    NaN
# 3      NaN                  NaN                    NaN                    NaN
# 4      NaN                  NaN                    NaN                    NaN
#
#   Gigabit_Fiber_Coverage Business_Density
# 0                Limited              Low
# 1                Limited              Low
# 2                Limited             High
# 3                Limited              Low
# 4                Limited              Low
#
# [5 rows x 28 columns]

# %%
merged_7['Region'].value_counts()
# Out:
# Region
# CAL            858
# TEX            742
# NW             536
# MIDW           426
# NY             200
# FLA            140
# MIDA           139
# CENT           124
# SW             108
# NE              71
# SE              65
# CAR             32
# Independent      6
# Name: count, dtype: int64

# %%
# Reapplying the mapping region to states

region_to_state = {
    'CAL':['CA'],
    'NW': ['WA', 'OR', 'ID', 'MT','CO','WY', 'AK'],
    'CAR': ['NC', 'SC'],
    'NY': ['NY'],
    'MIDA': ['PA', 'NJ', 'DE', 'MD', 'VA', 'DC', 'WV'],
    'SE':['GA', 'AL', 'MS', 'LA', 'AR'],
    'FLA': ['FL'],
    'SW': ['AZ', 'NM', 'NV', 'UT'],
    'TN': ['TN'],
    'MIDW': ['IL', 'IN','IA', 'MI', 'MN', 'OH','WI'],
    'TEX': ['TX'],
    'NE': ['ME', 'VT', 'NH', 'MA', 'CT', 'RI'],
    'CENT': ['KS', 'NE', 'SD', 'ND','OK', 'MO', 'KY']
}

# Create reverse mapping (state to region)
state_to_region = {state: region for region, states in region_to_state.items() for state in states}

# Apply mapping
merged_7['Region'] = merged_7['State'].map(state_to_region)
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6577 entries, 0 to 6576
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 6577 non-null   object
#  1   State                                6577 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               6564 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               6355 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3447 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                3447 non-null   object
#  26  Gigabit_Fiber_Coverage               3885 non-null   object
#  27  Business_Density                     3885 non-null   object
# dtypes: float64(3), object(25)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Loading in Disaster Risk Data

# %%
disaster = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Disaster_Risk.csv', index_col=0)

disaster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3137 entries, 0 to 3142
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        3137 non-null   object
#  1   County       3137 non-null   object
#  2   Population   3137 non-null   int64
#  3   Risk_Score   3137 non-null   float64
#  4   Risk_Rating  3137 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 147.0+ KB

# %%
disaster.head()
# Out:
#   State   County  Population  Risk_Score      Risk_Rating
# 0    AL  Autauga       58764   49.220490   Relatively Low
# 1    AL  Baldwin      231365   97.709195  Relatively High
# 2    AL  Barbour       25160   56.188355   Relatively Low
# 3    AL     Bibb       22239   32.484887         Very Low
# 4    AL   Blount       58992   65.128858   Relatively Low

# %%
disaster = disaster.drop(columns=['Population'])

disaster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3137 entries, 0 to 3142
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        3137 non-null   object
#  1   County       3137 non-null   object
#  2   Risk_Score   3137 non-null   float64
#  3   Risk_Rating  3137 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 122.5+ KB

# %%
# Merge disaster with merged_7  
merged_8 = pd.merge(merged_7, disaster, on=['State', 'County'], how='outer')

merged_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9713 entries, 0 to 9712
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 6577 non-null   object
#  1   State                                9713 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               6564 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               9491 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3447 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                3447 non-null   object
#  26  Gigabit_Fiber_Coverage               3885 non-null   object
#  27  Business_Density                     3885 non-null   object
#  28  Risk_Score                           3137 non-null   float64
#  29  Risk_Rating                          3137 non-null   object
# dtypes: float64(4), object(26)
# memory usage: 2.2+ MB

# %%
# Fill missing disaster data with Unknown
disaster_cols = ['Risk_Score', 'Risk_Rating']
merged_8[disaster_cols] = merged_8[disaster_cols].fillna('Unknown')

merged_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9713 entries, 0 to 9712
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 6577 non-null   object
#  1   State                                9713 non-null   object
#  2   Total Generation Rank                3447 non-null   object
#  3   Electric Generation Rank             3447 non-null   object
#  4   Commercial Generation Rank           3447 non-null   object
#  5   Capacity Growth Status               3447 non-null   object
#  6   CAIDI w/ Major Events                3447 non-null   float64
#  7   CAIDI w/o Major Events               3447 non-null   float64
#  8   SAIFI Major Events                   3447 non-null   object
#  9   BA Code                              3447 non-null   object
#  10  Utility Annual Energy Savings (MWh)  3447 non-null   object
#  11  Utility Peak Demand Savings (MW)     3447 non-null   object
#  12  Utility Annual Incentive Cost ($)    3447 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    3447 non-null   object
#  14  Region                               6564 non-null   object
#  15  Regional Electricity Demand          3303 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            3447 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               9491 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3447 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                3447 non-null   object
#  26  Gigabit_Fiber_Coverage               3885 non-null   object
#  27  Business_Density                     3885 non-null   object
#  28  Risk_Score                           9713 non-null   object
#  29  Risk_Rating                          9713 non-null   object
# dtypes: float64(3), object(27)
# memory usage: 2.2+ MB

# %%
len(merged_8['State'].value_counts())
# Out:
# 52

# %%
# Drop any remaining US territories if they exist
territories = ['PR', 'GU', 'VI', 'AS', 'MP', 'CNMI']
merged_8= merged_8[~merged_8['State'].isin(territories)]

len(merged_8['State'].value_counts())
# Out:
# 51

# %% [markdown]
# There are 51 states because i included District of Columbia as a state

# %%
merged_8.columns
# Out:
# Index(['City', 'State', 'Total Generation Rank', 'Electric Generation Rank',
#        'Commercial Generation Rank', 'Capacity Growth Status',
#        'CAIDI w/ Major Events', 'CAIDI w/o Major Events', 'SAIFI Major Events',
#        'BA Code', 'Utility Annual Energy Savings (MWh)',
#        'Utility Peak Demand Savings (MW)', 'Utility Annual Incentive Cost ($)',
#        'Utility Commercial Avg Life (Yrs)', 'Region',
#        'Regional Electricity Demand', 'IXP Name', 'IXP_Count', 'Name',
#        'Total MWh Rank', 'Purchased Rank', 'County', 'Zip Code',
#        'City Emissions Level', 'County Emissions Level',
#        'State Emissions Level', 'Gigabit_Fiber_Coverage', 'Business_Density',
#        'Risk_Score', 'Risk_Rating'],
#       dtype='object')

# %%
merged_8 = merged_8.replace('None', 'Unknown')

# %% [markdown]
# # Propagating State Level Data

# %%
# First, create state-level mappings for relevant columns
state_mappings = {
    'Total Generation Rank': merged_8.groupby('State')['Total Generation Rank'].first(),
    'Electric Generation Rank': merged_8.groupby('State')['Electric Generation Rank'].first(),
    'Commercial Generation Rank': merged_8.groupby('State')['Commercial Generation Rank'].first(),
    'Capacity Growth Status': merged_8.groupby('State')['Capacity Growth Status'].first(),
    'CAIDI w/ Major Events': merged_8.groupby('State')['CAIDI w/ Major Events'].first(),
    'CAIDI w/o Major Events': merged_8.groupby('State')['CAIDI w/o Major Events'].first(),
    'SAIFI Major Events': merged_8.groupby('State')['SAIFI Major Events'].first(),
    'BA Code': merged_8.groupby('State')['BA Code'].first(),
    'Utility Annual Energy Savings (MWh)': merged_8.groupby('State')['Utility Annual Energy Savings (MWh)'].first(),
    'Utility Peak Demand Savings (MW)': merged_8.groupby('State')['Utility Peak Demand Savings (MW)'].first(),
    'Utility Annual Incentive Cost ($)': merged_8.groupby('State')['Utility Annual Incentive Cost ($)'].first(),
    'Utility Commercial Avg Life (Yrs)': merged_8.groupby('State')['Utility Commercial Avg Life (Yrs)'].first(),
    'Regional Electricity Demand': merged_8.groupby('State')['Regional Electricity Demand'].first(),
    'State Emissions Level': merged_8.groupby('State')['State Emissions Level'].first(),
    'Region': merged_8.groupby('State')['Region'].first(),
    'IXP_Count': merged_8.groupby('State')['IXP_Count'].sum()
}

# Fill NaN values using state mappings
for col, mapping in state_mappings.items():
    merged_8[col] = merged_8.apply(
        lambda row: mapping[row['State']] if pd.isna(row[col]) else row[col],
        axis=1
    )
merged_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9710 entries, 0 to 9712
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 6574 non-null   object
#  1   State                                9710 non-null   object
#  2   Total Generation Rank                8494 non-null   object
#  3   Electric Generation Rank             8494 non-null   object
#  4   Commercial Generation Rank           8494 non-null   object
#  5   Capacity Growth Status               8494 non-null   object
#  6   CAIDI w/ Major Events                8494 non-null   float64
#  7   CAIDI w/o Major Events               8494 non-null   float64
#  8   SAIFI Major Events                   8494 non-null   object
#  9   BA Code                              8494 non-null   object
#  10  Utility Annual Energy Savings (MWh)  8494 non-null   object
#  11  Utility Peak Demand Savings (MW)     8494 non-null   object
#  12  Utility Annual Incentive Cost ($)    8494 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    8494 non-null   object
#  14  Region                               9695 non-null   object
#  15  Regional Electricity Demand          7672 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            9710 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2071 non-null   object
#  20  Purchased Rank                       2071 non-null   object
#  21  County                               9488 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3447 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                8494 non-null   object
#  26  Gigabit_Fiber_Coverage               3882 non-null   object
#  27  Business_Density                     3882 non-null   object
#  28  Risk_Score                           9710 non-null   object
#  29  Risk_Rating                          9710 non-null   object
# dtypes: float64(3), object(27)
# memory usage: 2.3+ MB

# %%
# Map the zip codes to their cities

#def zip_to_city(zip_code):
    
#merged_8['City'] = merged_8['Zip Code'].map(zip_to_city)
# Out:
#   Cell In[208], line 5
#     merged_8['City'] = merged_8['Zip Code'].map(zip_to_city)
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %% [markdown]
# # Propagating the city level data

# %%
# City level columns: 
# Total MWh Rank, Purchased Rank, City Emissions Level

# City-level mappings
city_mappings = {
    'City Emissions Level': merged_8.groupby(['State', 'City'])['City Emissions Level'].first(),
    'Total MWh Rank': merged_8.groupby(['State', 'City'])['Total MWh Rank'].first(),
    'Purchased Rank': merged_8.groupby(['State', 'City'])['Purchased Rank'].first()
}

# Fill NaN values using city mappings
for col, mapping in city_mappings.items():
    merged_8[col] = merged_8.apply(
        lambda row: mapping.get((row['State'], row['City'])) if pd.isna(row[col]) or row[col] == 'Unknown' else row[col],
        axis=1
    )

# Verify the results
print("Number of unique cities:", len(merged_8.groupby(['State', 'City'])))
for col in city_mappings.keys():
    print(f"{col}: {len(merged_8[merged_8[col].isna()].groupby(['State', 'City']))} city combinations with NA values")
# Out:
# Number of unique cities: 3264
# City Emissions Level: 3172 city combinations with NA values
# Total MWh Rank: 3209 city combinations with NA values
# Purchased Rank: 3209 city combinations with NA values

# %%
merged_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9710 entries, 0 to 9712
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 6574 non-null   object
#  1   State                                9710 non-null   object
#  2   Total Generation Rank                8494 non-null   object
#  3   Electric Generation Rank             8494 non-null   object
#  4   Commercial Generation Rank           8494 non-null   object
#  5   Capacity Growth Status               8494 non-null   object
#  6   CAIDI w/ Major Events                8494 non-null   float64
#  7   CAIDI w/o Major Events               8494 non-null   float64
#  8   SAIFI Major Events                   8494 non-null   object
#  9   BA Code                              8494 non-null   object
#  10  Utility Annual Energy Savings (MWh)  8494 non-null   object
#  11  Utility Peak Demand Savings (MW)     8494 non-null   object
#  12  Utility Annual Incentive Cost ($)    8494 non-null   object
#  13  Utility Commercial Avg Life (Yrs)    8494 non-null   object
#  14  Region                               9695 non-null   object
#  15  Regional Electricity Demand          7672 non-null   object
#  16  IXP Name                             3447 non-null   object
#  17  IXP_Count                            9710 non-null   float64
#  18  Name                                 2071 non-null   object
#  19  Total MWh Rank                       2076 non-null   object
#  20  Purchased Rank                       2076 non-null   object
#  21  County                               9488 non-null   object
#  22  Zip Code                             3225 non-null   object
#  23  City Emissions Level                 3453 non-null   object
#  24  County Emissions Level               3447 non-null   object
#  25  State Emissions Level                8494 non-null   object
#  26  Gigabit_Fiber_Coverage               3882 non-null   object
#  27  Business_Density                     3882 non-null   object
#  28  Risk_Score                           9710 non-null   object
#  29  Risk_Rating                          9710 non-null   object
# dtypes: float64(3), object(27)
# memory usage: 2.3+ MB

# %%
minimum_features = merged_8[['State','County', 'Risk_Score', 'Risk_Rating', 'IXP_Count','Region','Regional Electricity Demand','State Emissions Level','Utility Annual Energy Savings (MWh)','SAIFI Major Events', 'CAIDI w/o Major Events','CAIDI w/ Major Events','Commercial Generation Rank','Total Generation Rank','Purchased Rank','City Emissions Level','Total MWh Rank']]

minimum_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9710 entries, 0 to 9712
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                9710 non-null   object
#  1   County                               9488 non-null   object
#  2   Risk_Score                           9710 non-null   object
#  3   Risk_Rating                          9710 non-null   object
#  4   IXP_Count                            9710 non-null   float64
#  5   Region                               9695 non-null   object
#  6   Regional Electricity Demand          7672 non-null   object
#  7   State Emissions Level                8494 non-null   object
#  8   Utility Annual Energy Savings (MWh)  8494 non-null   object
#  9   SAIFI Major Events                   8494 non-null   object
#  10  CAIDI w/o Major Events               8494 non-null   float64
#  11  CAIDI w/ Major Events                8494 non-null   float64
#  12  Commercial Generation Rank           8494 non-null   object
#  13  Total Generation Rank                8494 non-null   object
#  14  Purchased Rank                       2076 non-null   object
#  15  City Emissions Level                 3453 non-null   object
#  16  Total MWh Rank                       2076 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 1.3+ MB

# %%
min_features = merged_8[['State','County', 'Risk_Score', 'Risk_Rating', 'IXP_Count','Region','Regional Electricity Demand','State Emissions Level','Utility Annual Energy Savings (MWh)','SAIFI Major Events', 'CAIDI w/o Major Events','CAIDI w/ Major Events','Commercial Generation Rank','Total Generation Rank']]


min_features.dropna(inplace=True)
min_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7455 entries, 60 to 9556
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                7455 non-null   object
#  1   County                               7455 non-null   object
#  2   Risk_Score                           7455 non-null   object
#  3   Risk_Rating                          7455 non-null   object
#  4   IXP_Count                            7455 non-null   float64
#  5   Region                               7455 non-null   object
#  6   Regional Electricity Demand          7455 non-null   object
#  7   State Emissions Level                7455 non-null   object
#  8   Utility Annual Energy Savings (MWh)  7455 non-null   object
#  9   SAIFI Major Events                   7455 non-null   object
#  10  CAIDI w/o Major Events               7455 non-null   float64
#  11  CAIDI w/ Major Events                7455 non-null   float64
#  12  Commercial Generation Rank           7455 non-null   object
#  13  Total Generation Rank                7455 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 873.6+ KB
# /var/folders/rj/3yvmqxnj3d17zpgh8wpywxvr0000gn/T/ipykernel_29673/1836955396.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_features.dropna(inplace=True)

# %%
min_features.to_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Data/Minimum_Features.csv')

# %%
merged_8[merged_8['City'].isna()]
# Out:
#      City State Total Generation Rank Electric Generation Rank  \
# 0     NaN    AK                  None                     None
# 2     NaN    AK                  None                     None
# 4     NaN    AK                  None                     None
# 6     NaN    AK                  None                     None
# 8     NaN    AK                  None                     None
# ...   ...   ...                   ...                      ...
# 9703  NaN    WY                  None                     None
# 9705  NaN    WY                  None                     None
# 9707  NaN    WY                  None                     None
# 9709  NaN    WY                  None                     None
# 9711  NaN    WY                  None                     None
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                          None                   None                    NaN
# 2                          None                   None                    NaN
# 4                          None                   None                    NaN
# 6                          None                   None                    NaN
# 8                          None                   None                    NaN
# ...                         ...                    ...                    ...
# 9703                       None                   None                    NaN
# 9705                       None                   None                    NaN
# 9707                       None                   None                    NaN
# 9709                       None                   None                    NaN
# 9711                       None                   None                    NaN
#
#       CAIDI w/o Major Events SAIFI Major Events BA Code  ... Purchased Rank  \
# 0                        NaN               None    None  ...           None
# 2                        NaN               None    None  ...           None
# 4                        NaN               None    None  ...           None
# 6                        NaN               None    None  ...           None
# 8                        NaN               None    None  ...           None
# ...                      ...                ...     ...  ...            ...
# 9703                     NaN               None    None  ...           None
# 9705                     NaN               None    None  ...           None
# 9707                     NaN               None    None  ...           None
# 9709                     NaN               None    None  ...           None
# 9711                     NaN               None    None  ...           None
#
#               County Zip Code City Emissions Level County Emissions Level  \
# 0     Aleutians East      NaN                 None                    NaN
# 2     Aleutians West      NaN                 None                    NaN
# 4          Anchorage      NaN                 None                    NaN
# 6             Bethel      NaN                 None                    NaN
# 8        Bristol Bay      NaN                 None                    NaN
# ...              ...      ...                  ...                    ...
# 9703      Sweetwater      NaN                 None                    NaN
# 9705           Teton      NaN                 None                    NaN
# 9707           Uinta      NaN                 None                    NaN
# 9709        Washakie      NaN                 None                    NaN
# 9711          Weston      NaN                 None                    NaN
#
#      State Emissions Level Gigabit_Fiber_Coverage  Business_Density  \
# 0                     None                    NaN               NaN
# 2                     None                    NaN               NaN
# 4                     None                    NaN               NaN
# 6                     None                    NaN               NaN
# 8                     None                    NaN               NaN
# ...                    ...                    ...               ...
# 9703                  None                    NaN               NaN
# 9705                  None                    NaN               NaN
# 9707                  None                    NaN               NaN
# 9709                  None                    NaN               NaN
# 9711                  None                    NaN               NaN
#
#      Risk_Score          Risk_Rating
# 0      4.231626             Very Low
# 2     35.221126             Very Low
# 4     94.845689  Relatively Moderate
# 6     16.926503             Very Low
# 8      0.159084             Very Low
# ...         ...                  ...
# 9703   6.617881             Very Low
# 9705  68.501432       Relatively Low
# 9707  21.699014             Very Low
# 9709   2.513522             Very Low
# 9711  16.640153             Very Low
#
# [3136 rows x 30 columns]
