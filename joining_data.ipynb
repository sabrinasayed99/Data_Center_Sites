# %% [markdown]
# # Joining the Data
#
# It is now time for the scary part. But we never back away from a challenge! Let's say a prayer and get ready to join the data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading in Utility Scale Net Generation Data and Reliability of Distribution Systems Date

# %%
net_gen = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Utility_Scale_Net_Generation.csv', index_col=0)

net_gen.head()
# Out:
#   State  % Chg All Facilities Generation Total_Generation_Rank  \
# 0    CT                              9.4              Moderate
# 1    ME                              2.8                   Low
# 2    MA                              6.4                   Low
# 3    NH                             22.9                   Low
# 4    RI                             -0.5                   Low
#
#   Electric_Generation_Rank Independent_Generation_Rank  \
# 0                      Low                        High
# 1                      Low                    Moderate
# 2                      Low                    Moderate
# 3                      Low                    Moderate
# 4                      Low                    Moderate
#
#   Commercial_Generation_Rank Industrial_Generation_Rank Capacity_Growth_Status
# 0                   Moderate                        Low                Growing
# 1                        Low                   Moderate                Growing
# 2                       High                        Low                Growing
# 3                        Low                        Low                Growing
# 4                        Low                        Low              Shrinking

# %%
net_gen = net_gen.drop(columns=['% Chg All Facilities Generation'])

# %%
net_gen.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    CT              Moderate                      Low
# 1    ME                   Low                      Low
# 2    MA                   Low                      Low
# 3    NH                   Low                      Low
# 4    RI                   Low                      Low
#
#   Independent_Generation_Rank Commercial_Generation_Rank  \
# 0                        High                   Moderate
# 1                    Moderate                        Low
# 2                    Moderate                       High
# 3                    Moderate                        Low
# 4                    Moderate                        Low
#
#   Industrial_Generation_Rank Capacity_Growth_Status
# 0                        Low                Growing
# 1                   Moderate                Growing
# 2                        Low                Growing
# 3                        Low                Growing
# 4                        Low              Shrinking

# %%
net_gen['State'].value_counts().sum()
# Out:
# 51

# %%
reliability = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Reliability_Distribution.csv', index_col=0)

reliability.head()
# Out:
#   Census Division State  Percent of Customers Reported w/ Major Events  \
# 0     New England    CT                                          100.6
# 1     New England    ME                                          100.8
# 2     New England    MA                                           88.2
# 3     New England    NH                                           99.3
# 4     New England    RI                                           98.3
#
#    SAIDI w/ Major Events  SAIFI w/ Major Events  CAIDI w/ Major Events  \
# 0                  164.6                    0.9                  188.8
# 1                 1863.0                    3.3                  562.2
# 2                  259.4                    1.1                  245.4
# 3                  645.8                    1.8                  368.5
# 4                  104.6                    0.8                  133.7
#
#    SAIDI w/o Major Events  SAIFI w/o Major Events  CAIDI w/o Major Events
# 0                    70.3                     0.7                   107.3
# 1                   247.4                     2.0                   125.0
# 2                    82.2                     0.8                   105.4
# 3                   124.6                     1.0                   126.1
# 4                    52.2                     0.7                    78.3

# %%
reliability.describe()
# Out:
#        Percent of Customers Reported w/ Major Events  SAIDI w/ Major Events  \
# count                                      51.000000              51.000000
# mean                                       91.984314             358.574510
# std                                         7.457758             346.660787
# min                                        73.600000              71.900000
# 25%                                        88.300000             126.950000
# 50%                                        93.600000             208.600000
# 75%                                        97.750000             473.600000
# max                                       102.700000            1863.000000
#
#        SAIFI w/ Major Events  CAIDI w/ Major Events  SAIDI w/o Major Events  \
# count              51.000000              51.000000               51.000000
# mean                1.386275             226.466667              125.866667
# std                 0.636873             127.799489               68.936497
# min                 0.400000              76.200000               33.300000
# 25%                 0.900000             134.850000               72.900000
# 50%                 1.100000             186.900000              117.100000
# 75%                 1.800000             282.200000              146.000000
# max                 3.300000             723.500000              385.700000
#
#        SAIFI w/o Major Events  CAIDI w/o Major Events
# count               51.000000               51.000000
# mean                 1.054902              116.519608
# std                  0.434656               23.595296
# min                  0.300000               70.800000
# 25%                  0.800000              101.350000
# 50%                  0.900000              118.000000
# 75%                  1.250000              124.950000
# max                  2.400000              206.200000

# %% [markdown]
# The following columns in reliability dataset will be binned based on their wide distributions:
# - 'SAIDI w/ Major Events'     # Wide range: 71.9 to 1863.0 minutes
# - 'SAIFI w/ Major Events'     # Meaningful range: 0.4 to 3.3 interruptions
# - 'SAIDI w/o Major Events'    # Significant spread: 33.3 to 385.7 minutes
# - 'SAIFI w/o Major Events'    # Clear variation: 0.3 to 2.4 interruptions

# %%
# Binning SAIDI (Average Interruption Duration Index) with Major Events
conditions_saidi = [
    reliability['SAIDI w/ Major Events'] >= 473.6,  # 75th percentile
    (reliability['SAIDI w/ Major Events'] >= 208.6) & (reliability['SAIDI w/ Major Events'] < 473.6),  # 50th-75th
    reliability['SAIDI w/ Major Events'] < 208.6  # Below median
]
choices_saidi = ['Long Interruption Duration', 'Moderate Interruption Duration', 'Short Interruption Duration']
reliability['SAIDI Major Events'] = np.select(conditions_saidi, choices_saidi, default='Unknown')

# Bin SAIFI (Average Interruption Frequency Index) w/ Major Events
conditions_saifi = [
    reliability['SAIFI w/ Major Events'] > 1.8,  # 75th percentile
    (reliability['SAIFI w/ Major Events'] >= 1.1) & (reliability['SAIFI w/ Major Events'] <= 1.8),  # 50th-75th
    reliability['SAIFI w/ Major Events'] < 1.1  # Below median
]
choices_saifi = ['High Interruption Frequency', 'Moderate Interruption Frequency', 'Low Interruption Frequency']
reliability['SAIFI Major Events'] = np.select(conditions_saifi, choices_saifi, default='Unknown')

# %%
# Binning SAIDI (Average Interruption Duration Index) without  Major Events
conditions_saidi = [
    reliability['SAIDI w/o Major Events'] >= 146,  
    (reliability['SAIDI w/o Major Events'] >= 117) & (reliability['SAIDI w/o Major Events'] < 146), 
    reliability['SAIDI w/o Major Events'] < 117  
]
choices_saidi = ['Long Interruption Duration', 'Moderate Interruption Duration', 'Short Interruption Duration']
reliability['SAIDI No Major Events'] = np.select(conditions_saidi, choices_saidi, default='Unknown')

# Bin SAIFI (Average Interruption Frequency Index) w/o Major Events
conditions_saifi = [
    reliability['SAIFI w/o Major Events'] > 1.25,  
    (reliability['SAIFI w/o Major Events'] >= .9) & (reliability['SAIFI w/o Major Events'] <= 1.25), 
    reliability['SAIFI w/o Major Events'] < .9
]
choices_saifi = ['High Interruption Frequency', 'Moderate Interruption Frequency', 'Low Interruption Frequency']
reliability['SAIFI No Major Events'] = np.select(conditions_saifi, choices_saifi, default='Unknown')

# %%
reliability.head()
# Out:
#   Census Division State  Percent of Customers Reported w/ Major Events  \
# 0     New England    CT                                          100.6
# 1     New England    ME                                          100.8
# 2     New England    MA                                           88.2
# 3     New England    NH                                           99.3
# 4     New England    RI                                           98.3
#
#    SAIDI w/ Major Events  SAIFI w/ Major Events  CAIDI w/ Major Events  \
# 0                  164.6                    0.9                  188.8
# 1                 1863.0                    3.3                  562.2
# 2                  259.4                    1.1                  245.4
# 3                  645.8                    1.8                  368.5
# 4                  104.6                    0.8                  133.7
#
#    SAIDI w/o Major Events  SAIFI w/o Major Events  CAIDI w/o Major Events  \
# 0                    70.3                     0.7                   107.3
# 1                   247.4                     2.0                   125.0
# 2                    82.2                     0.8                   105.4
# 3                   124.6                     1.0                   126.1
# 4                    52.2                     0.7                    78.3
#
#                SAIDI Major Events               SAIFI Major Events  \
# 0     Short Interruption Duration       Low Interruption Frequency
# 1      Long Interruption Duration      High Interruption Frequency
# 2  Moderate Interruption Duration  Moderate Interruption Frequency
# 3      Long Interruption Duration  Moderate Interruption Frequency
# 4     Short Interruption Duration       Low Interruption Frequency
#
#             SAIDI No Major Events            SAIFI No Major Events
# 0     Short Interruption Duration       Low Interruption Frequency
# 1      Long Interruption Duration      High Interruption Frequency
# 2     Short Interruption Duration       Low Interruption Frequency
# 3  Moderate Interruption Duration  Moderate Interruption Frequency
# 4     Short Interruption Duration       Low Interruption Frequency

# %%
reliability = reliability.drop(columns=['SAIDI w/ Major Events', 'SAIFI w/ Major Events', 'SAIDI w/o Major Events', 'SAIFI w/o Major Events'])
reliability.head()
# Out:
#   Census Division State  Percent of Customers Reported w/ Major Events  \
# 0     New England    CT                                          100.6
# 1     New England    ME                                          100.8
# 2     New England    MA                                           88.2
# 3     New England    NH                                           99.3
# 4     New England    RI                                           98.3
#
#    CAIDI w/ Major Events  CAIDI w/o Major Events  \
# 0                  188.8                   107.3
# 1                  562.2                   125.0
# 2                  245.4                   105.4
# 3                  368.5                   126.1
# 4                  133.7                    78.3
#
#                SAIDI Major Events               SAIFI Major Events  \
# 0     Short Interruption Duration       Low Interruption Frequency
# 1      Long Interruption Duration      High Interruption Frequency
# 2  Moderate Interruption Duration  Moderate Interruption Frequency
# 3      Long Interruption Duration  Moderate Interruption Frequency
# 4     Short Interruption Duration       Low Interruption Frequency
#
#             SAIDI No Major Events            SAIFI No Major Events
# 0     Short Interruption Duration       Low Interruption Frequency
# 1      Long Interruption Duration      High Interruption Frequency
# 2     Short Interruption Duration       Low Interruption Frequency
# 3  Moderate Interruption Duration  Moderate Interruption Frequency
# 4     Short Interruption Duration       Low Interruption Frequency

# %%
reliability['State'].value_counts().sum()
# Out:
# 51

# %%
# Conduct an outer join on the State column
net_gen_reliability = pd.merge(net_gen, reliability, on='State', how='outer')

net_gen_reliability.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AR              Moderate                 Moderate
# 3    AZ                  High                     High
# 4    CA                  High                     High
#
#   Independent_Generation_Rank Commercial_Generation_Rank  \
# 0                         Low                       High
# 1                        High                        Low
# 2                         Low                        Low
# 3                        High                   Moderate
# 4                        High                       High
#
#   Industrial_Generation_Rank Capacity_Growth_Status        Census Division  \
# 0                        Low                Growing  Pacific Noncontiguous
# 1                       High                Growing     East South Central
# 2                   Moderate              Shrinking     West South Central
# 3                        Low                Growing               Mountain
# 4                       High              Shrinking     Pacific Contiguous
#
#    Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  \
# 0                                           84.5                  138.8
# 1                                           80.0                  186.9
# 2                                           89.3                  433.4
# 3                                           96.7                  108.6
# 4                                          100.2                  248.1
#
#    CAIDI w/o Major Events              SAIDI Major Events  \
# 0                   137.6  Moderate Interruption Duration
# 1                   122.8  Moderate Interruption Duration
# 2                   144.0      Long Interruption Duration
# 3                    84.8     Short Interruption Duration
# 4                   140.0  Moderate Interruption Duration
#
#                 SAIFI Major Events           SAIDI No Major Events  \
# 0      High Interruption Frequency      Long Interruption Duration
# 1  Moderate Interruption Frequency  Moderate Interruption Duration
# 2      High Interruption Frequency      Long Interruption Duration
# 3       Low Interruption Frequency     Short Interruption Duration
# 4  Moderate Interruption Frequency      Long Interruption Duration
#
#              SAIFI No Major Events
# 0      High Interruption Frequency
# 1  Moderate Interruption Frequency
# 2      High Interruption Frequency
# 3       Low Interruption Frequency
# 4  Moderate Interruption Frequency

# %%
net_gen_reliability.isna().value_counts()
# Out:
# State  Total_Generation_Rank  Electric_Generation_Rank  Independent_Generation_Rank  Commercial_Generation_Rank  Industrial_Generation_Rank  Capacity_Growth_Status  Census Division  Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIDI Major Events  SAIFI Major Events  SAIDI No Major Events  SAIFI No Major Events
# False  False                  False                     False                        False                       False                       False                   False            False                                          False                  False                   False               False               False                  False                    51
# Name: count, dtype: int64

# %% [markdown]
# ## Load in the Energy Efficiency data

# %%
energy_efficiency = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Efficiency.csv', index_col=0)

energy_efficiency.head()
# Out:
#    Year  Utility Number                   Utility Name State BA Code  \
# 0  2023             162        Aiken Electric Coop Inc    SC      SC
# 1  2023             189  PowerSouth Energy Cooperative    AL    SOCO
# 2  2023             195               Alabama Power Co    AL    SOCO
# 3  2023             207        Alameda Municipal Power    CA    CISO
# 4  2023             295      City of Alexandria - (MN)    MN    MISO
#
#    Commercial Annual Savings (MWh)  Total Annual Savings (MWh)  \
# 0                           1686.0                       206.0
# 1                           1686.0                      2550.0
# 2                            759.0                      5767.0
# 3                            111.0                       146.0
# 4                            673.0                      3306.0
#
#    Commercial Peak Demand Annual Savings (MW)  \
# 0                                         0.4
# 1                                         0.4
# 2                                         0.2
# 3                                         0.0
# 4                                         0.1
#
#    Total Peak Demand Annual Savings (MW)  Commercial Cum Savings (MWh)  ...  \
# 0                                    0.0                       18796.5  ...
# 1                                    2.1                       18796.5  ...
# 2                                   11.9                        3797.0  ...
# 3                                    0.1                        1460.0  ...
# 4                                    0.7                        8564.0  ...
#
#    Total Cum Peak Demand Savings (MWh)  \
# 0                                  0.0
# 1                                  2.1
# 2                                 11.9
# 3                                  0.1
# 4                                  0.7
#
#    Commercial Annual Incent Cost (Thousand $)  \
# 0                                       162.0
# 1                                       162.0
# 2                                        36.0
# 3                                        23.0
# 4                                        36.0
#
#    Total Annual Incent Cost (Thousand $)  \
# 0                                  443.0
# 1                                  848.0
# 2                                 1225.0
# 3                                   70.0
# 4                                  187.0
#
#    Commercial Non-Incentive Annual Costs (Thousand $)  \
# 0                                              118.0
# 1                                              118.0
# 2                                              151.0
# 3                                              146.0
# 4                                               38.0
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 0                                           37.0
# 1                                          526.0
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
#
#    Commercial Incentive Cum Costs (Thousand $)  \
# 0                                        190.0
# 1                                        190.0
# 2                                         36.0
# 3                                         23.0
# 4                                         36.0
#
#    Total Incentive Cum Costs (Thousand $)  \
# 0                                   487.0
# 1                                   848.0
# 2                                  1225.0
# 3                                    70.0
# 4                                   187.0
#
#    Commercial Non-Incentive Cum Costs (Thousand $)  \
# 0                                            145.0
# 1                                            145.0
# 2                                            151.0
# 3                                            146.0
# 4                                             38.0
#
#    Total Non-Incentive Cum Costs (Thousand $)  \
# 0                                       348.0
# 1                                       526.0
# 2                                      1095.0
# 3                                       321.0
# 4                                       194.0
#
#    Commercial Weighted Avg Life (Yrs)
# 0                              12.574
# 1                              12.574
# 2                               5.000
# 3                              13.269
# 4                              12.727
#
# [5 rows x 22 columns]

# %%
energy_efficiency.columns
# Out:
# Index(['Year', 'Utility Number', 'Utility Name', 'State', 'BA Code',
#        'Commercial Annual Savings (MWh)', 'Total Annual Savings (MWh)',
#        'Commercial Peak Demand Annual Savings (MW)',
#        'Total Peak Demand Annual Savings (MW)', 'Commercial Cum Savings (MWh)',
#        'Total Cum Savings (MWh)', 'Commercial Cum Peak Demand Savings (MWh)',
#        'Total Cum Peak Demand Savings (MWh)',
#        'Commercial Annual Incent Cost (Thousand $)',
#        'Total Annual Incent Cost (Thousand $)',
#        'Commercial Non-Incentive Annual Costs (Thousand $)',
#        'Total Non-Incentive Annual Costs (Thousand $)',
#        'Commercial Incentive Cum Costs (Thousand $)',
#        'Total Incentive Cum Costs (Thousand $)',
#        'Commercial Non-Incentive Cum Costs (Thousand $)',
#        'Total Non-Incentive Cum Costs (Thousand $)',
#        'Commercial Weighted Avg Life (Yrs)'],
#       dtype='object')

# %%
# Drop the year and Utility number columns
energy_efficiency = energy_efficiency.drop(columns=['Year'])

energy_efficiency.head()
# Out:
#    Utility Number                   Utility Name State BA Code  \
# 0             162        Aiken Electric Coop Inc    SC      SC
# 1             189  PowerSouth Energy Cooperative    AL    SOCO
# 2             195               Alabama Power Co    AL    SOCO
# 3             207        Alameda Municipal Power    CA    CISO
# 4             295      City of Alexandria - (MN)    MN    MISO
#
#    Commercial Annual Savings (MWh)  Total Annual Savings (MWh)  \
# 0                           1686.0                       206.0
# 1                           1686.0                      2550.0
# 2                            759.0                      5767.0
# 3                            111.0                       146.0
# 4                            673.0                      3306.0
#
#    Commercial Peak Demand Annual Savings (MW)  \
# 0                                         0.4
# 1                                         0.4
# 2                                         0.2
# 3                                         0.0
# 4                                         0.1
#
#    Total Peak Demand Annual Savings (MW)  Commercial Cum Savings (MWh)  \
# 0                                    0.0                       18796.5
# 1                                    2.1                       18796.5
# 2                                   11.9                        3797.0
# 3                                    0.1                        1460.0
# 4                                    0.7                        8564.0
#
#    Total Cum Savings (MWh)  ...  Total Cum Peak Demand Savings (MWh)  \
# 0                  27204.0  ...                                  0.0
# 1                  28552.0  ...                                  2.1
# 2                  45489.0  ...                                 11.9
# 3                   1958.0  ...                                  0.1
# 4                  43191.0  ...                                  0.7
#
#    Commercial Annual Incent Cost (Thousand $)  \
# 0                                       162.0
# 1                                       162.0
# 2                                        36.0
# 3                                        23.0
# 4                                        36.0
#
#    Total Annual Incent Cost (Thousand $)  \
# 0                                  443.0
# 1                                  848.0
# 2                                 1225.0
# 3                                   70.0
# 4                                  187.0
#
#    Commercial Non-Incentive Annual Costs (Thousand $)  \
# 0                                              118.0
# 1                                              118.0
# 2                                              151.0
# 3                                              146.0
# 4                                               38.0
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 0                                           37.0
# 1                                          526.0
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
#
#    Commercial Incentive Cum Costs (Thousand $)  \
# 0                                        190.0
# 1                                        190.0
# 2                                         36.0
# 3                                         23.0
# 4                                         36.0
#
#    Total Incentive Cum Costs (Thousand $)  \
# 0                                   487.0
# 1                                   848.0
# 2                                  1225.0
# 3                                    70.0
# 4                                   187.0
#
#    Commercial Non-Incentive Cum Costs (Thousand $)  \
# 0                                            145.0
# 1                                            145.0
# 2                                            151.0
# 3                                            146.0
# 4                                             38.0
#
#    Total Non-Incentive Cum Costs (Thousand $)  \
# 0                                       348.0
# 1                                       526.0
# 2                                      1095.0
# 3                                       321.0
# 4                                       194.0
#
#    Commercial Weighted Avg Life (Yrs)
# 0                              12.574
# 1                              12.574
# 2                               5.000
# 3                              13.269
# 4                              12.727
#
# [5 rows x 21 columns]

# %%
energy_efficiency.drop(columns=['Utility Number'], inplace=True)

energy_efficiency.head()
# Out:
#                     Utility Name State BA Code  \
# 0        Aiken Electric Coop Inc    SC      SC
# 1  PowerSouth Energy Cooperative    AL    SOCO
# 2               Alabama Power Co    AL    SOCO
# 3        Alameda Municipal Power    CA    CISO
# 4      City of Alexandria - (MN)    MN    MISO
#
#    Commercial Annual Savings (MWh)  Total Annual Savings (MWh)  \
# 0                           1686.0                       206.0
# 1                           1686.0                      2550.0
# 2                            759.0                      5767.0
# 3                            111.0                       146.0
# 4                            673.0                      3306.0
#
#    Commercial Peak Demand Annual Savings (MW)  \
# 0                                         0.4
# 1                                         0.4
# 2                                         0.2
# 3                                         0.0
# 4                                         0.1
#
#    Total Peak Demand Annual Savings (MW)  Commercial Cum Savings (MWh)  \
# 0                                    0.0                       18796.5
# 1                                    2.1                       18796.5
# 2                                   11.9                        3797.0
# 3                                    0.1                        1460.0
# 4                                    0.7                        8564.0
#
#    Total Cum Savings (MWh)  Commercial Cum Peak Demand Savings (MWh)  \
# 0                  27204.0                                       0.4
# 1                  28552.0                                       0.4
# 2                  45489.0                                       0.2
# 3                   1958.0                                       0.0
# 4                  43191.0                                       0.1
#
#    Total Cum Peak Demand Savings (MWh)  \
# 0                                  0.0
# 1                                  2.1
# 2                                 11.9
# 3                                  0.1
# 4                                  0.7
#
#    Commercial Annual Incent Cost (Thousand $)  \
# 0                                       162.0
# 1                                       162.0
# 2                                        36.0
# 3                                        23.0
# 4                                        36.0
#
#    Total Annual Incent Cost (Thousand $)  \
# 0                                  443.0
# 1                                  848.0
# 2                                 1225.0
# 3                                   70.0
# 4                                  187.0
#
#    Commercial Non-Incentive Annual Costs (Thousand $)  \
# 0                                              118.0
# 1                                              118.0
# 2                                              151.0
# 3                                              146.0
# 4                                               38.0
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 0                                           37.0
# 1                                          526.0
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
#
#    Commercial Incentive Cum Costs (Thousand $)  \
# 0                                        190.0
# 1                                        190.0
# 2                                         36.0
# 3                                         23.0
# 4                                         36.0
#
#    Total Incentive Cum Costs (Thousand $)  \
# 0                                   487.0
# 1                                   848.0
# 2                                  1225.0
# 3                                    70.0
# 4                                   187.0
#
#    Commercial Non-Incentive Cum Costs (Thousand $)  \
# 0                                            145.0
# 1                                            145.0
# 2                                            151.0
# 3                                            146.0
# 4                                             38.0
#
#    Total Non-Incentive Cum Costs (Thousand $)  \
# 0                                       348.0
# 1                                       526.0
# 2                                      1095.0
# 3                                       321.0
# 4                                       194.0
#
#    Commercial Weighted Avg Life (Yrs)
# 0                              12.574
# 1                              12.574
# 2                               5.000
# 3                              13.269
# 4                              12.727

# %%
energy_efficiency.describe()
# Out:
#        Commercial Annual Savings (MWh)  Total Annual Savings (MWh)  \
# count                       457.000000                4.570000e+02
# mean                      24441.006565                5.305245e+04
# std                       75413.362690                1.623069e+05
# min                           0.000000                0.000000e+00
# 25%                         337.000000                5.280000e+02
# 50%                        1686.000000                2.631500e+03
# 75%                       10890.000000                2.566200e+04
# max                      756720.000000                1.718664e+06
#
#        Commercial Peak Demand Annual Savings (MW)  \
# count                                  457.000000
# mean                                     7.055142
# std                                     41.803702
# min                                      0.000000
# 25%                                      0.100000
# 50%                                      0.400000
# 75%                                      2.200000
# max                                    804.900000
#
#        Total Peak Demand Annual Savings (MW)  Commercial Cum Savings (MWh)  \
# count                             457.000000                  4.570000e+02
# mean                               12.647155                  3.229917e+05
# std                                53.838307                  1.010679e+06
# min                                 0.000000                  0.000000e+00
# 25%                                 0.200000                  4.491000e+03
# 50%                                 0.750000                  1.879650e+04
# 75%                                 5.900000                  1.419410e+05
# max                               945.000000                  9.244884e+06
#
#        Total Cum Savings (MWh)  Commercial Cum Peak Demand Savings (MWh)  \
# count             4.570000e+02                                457.000000
# mean              5.923291e+05                                  7.107221
# std               1.833131e+06                                 41.896196
# min               0.000000e+00                                  0.000000
# 25%               6.296000e+03                                  0.100000
# 50%               3.037400e+04                                  0.400000
# 75%               3.347900e+05                                  2.100000
# max               1.987582e+07                                804.900000
#
#        Total Cum Peak Demand Savings (MWh)  \
# count                           457.000000
# mean                             12.415536
# std                              53.788817
# min                               0.000000
# 25%                               0.200000
# 50%                               0.800000
# 75%                               5.900000
# max                             945.000000
#
#        Commercial Annual Incent Cost (Thousand $)  \
# count                                  457.000000
# mean                                  3904.929978
# std                                  14333.723818
# min                                      0.000000
# 25%                                     36.000000
# 50%                                    162.000000
# 75%                                   1372.000000
# max                                 180076.000000
#
#        Total Annual Incent Cost (Thousand $)  \
# count                             457.000000
# mean                             8442.730853
# std                             28248.946275
# min                                 0.000000
# 25%                                66.000000
# 50%                               443.000000
# 75%                              3338.000000
# max                            372401.000000
#
#        Commercial Non-Incentive Annual Costs (Thousand $)  \
# count                                         457.000000
# mean                                         2489.074398
# std                                          9763.534472
# min                                             0.000000
# 25%                                            31.000000
# 50%                                           118.000000
# 75%                                           605.000000
# max                                        106954.000000
#
#        Total Non-Incentive Annual Costs (Thousand $)  \
# count                                     457.000000
# mean                                     5583.444201
# std                                     20155.953151
# min                                         0.000000
# 25%                                        58.000000
# 50%                                       240.000000
# 75%                                      1845.000000
# max                                    247704.000000
#
#        Commercial Incentive Cum Costs (Thousand $)  \
# count                                   457.000000
# mean                                   4684.387309
# std                                   20126.649167
# min                                       0.000000
# 25%                                      40.000000
# 50%                                     190.000000
# 75%                                    1430.000000
# max                                  289844.000000
#
#        Total Incentive Cum Costs (Thousand $)  \
# count                              457.000000
# mean                              9676.682713
# std                              36695.365003
# min                                  0.000000
# 25%                                 83.000000
# 50%                                487.000000
# 75%                               3338.000000
# max                             495994.000000
#
#        Commercial Non-Incentive Cum Costs (Thousand $)  \
# count                                       457.000000
# mean                                       2958.343545
# std                                       13411.016916
# min                                           0.000000
# 25%                                          37.000000
# 50%                                         145.000000
# 75%                                         605.000000
# max                                      198028.000000
#
#        Total Non-Incentive Cum Costs (Thousand $)  \
# count                                   457.00000
# mean                                   6423.24070
# std                                   25486.23149
# min                                       0.00000
# 25%                                      62.00000
# 50%                                     282.00000
# 75%                                    1962.00000
# max                                  334853.00000
#
#        Commercial Weighted Avg Life (Yrs)
# count                          457.000000
# mean                            12.400501
# std                              4.104284
# min                              0.000000
# 25%                             11.350000
# 50%                             12.574000
# 75%                             14.000000
# max                             27.630000

# %% [markdown]
# ** Note that MW measures power capacity while MWh measures the amount of electricity delivered overtime

# %%
# Bin Total Annual Savings (MWh)
conditions_savings = [
    energy_efficiency['Total Annual Savings (MWh)'] >= energy_efficiency['Total Annual Savings (MWh)'].quantile(0.75),
    (energy_efficiency['Total Annual Savings (MWh)'] >= energy_efficiency['Total Annual Savings (MWh)'].quantile(0.25)) & 
    (energy_efficiency['Total Annual Savings (MWh)'] < energy_efficiency['Total Annual Savings (MWh)'].quantile(0.75)),
    energy_efficiency['Total Annual Savings (MWh)'] < energy_efficiency['Total Annual Savings (MWh)'].quantile(0.25)
]
choices_savings = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Annual Energy Savings (MWh)'] = np.select(conditions_savings, choices_savings, default='Unknown')

# Bin Peak Demand Savings
conditions_peak = [
    energy_efficiency['Total Peak Demand Annual Savings (MW)'] >= energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.75),
    (energy_efficiency['Total Peak Demand Annual Savings (MW)'] >= energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.25)) & 
    (energy_efficiency['Total Peak Demand Annual Savings (MW)'] < energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.75)),
    energy_efficiency['Total Peak Demand Annual Savings (MW)'] < energy_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.25)
]
choices_peak = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Peak Demand Savings (MW)'] = np.select(conditions_peak, choices_peak, default='Unknown')

# %%
energy_efficiency.head()
# Out:
#                     Utility Name State BA Code  \
# 0        Aiken Electric Coop Inc    SC      SC
# 1  PowerSouth Energy Cooperative    AL    SOCO
# 2               Alabama Power Co    AL    SOCO
# 3        Alameda Municipal Power    CA    CISO
# 4      City of Alexandria - (MN)    MN    MISO
#
#    Commercial Annual Savings (MWh)  Total Annual Savings (MWh)  \
# 0                           1686.0                       206.0
# 1                           1686.0                      2550.0
# 2                            759.0                      5767.0
# 3                            111.0                       146.0
# 4                            673.0                      3306.0
#
#    Commercial Peak Demand Annual Savings (MW)  \
# 0                                         0.4
# 1                                         0.4
# 2                                         0.2
# 3                                         0.0
# 4                                         0.1
#
#    Total Peak Demand Annual Savings (MW)  Commercial Cum Savings (MWh)  \
# 0                                    0.0                       18796.5
# 1                                    2.1                       18796.5
# 2                                   11.9                        3797.0
# 3                                    0.1                        1460.0
# 4                                    0.7                        8564.0
#
#    Total Cum Savings (MWh)  Commercial Cum Peak Demand Savings (MWh)  ...  \
# 0                  27204.0                                       0.4  ...
# 1                  28552.0                                       0.4  ...
# 2                  45489.0                                       0.2  ...
# 3                   1958.0                                       0.0  ...
# 4                  43191.0                                       0.1  ...
#
#    Total Annual Incent Cost (Thousand $)  \
# 0                                  443.0
# 1                                  848.0
# 2                                 1225.0
# 3                                   70.0
# 4                                  187.0
#
#    Commercial Non-Incentive Annual Costs (Thousand $)  \
# 0                                              118.0
# 1                                              118.0
# 2                                              151.0
# 3                                              146.0
# 4                                               38.0
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 0                                           37.0
# 1                                          526.0
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
#
#    Commercial Incentive Cum Costs (Thousand $)  \
# 0                                        190.0
# 1                                        190.0
# 2                                         36.0
# 3                                         23.0
# 4                                         36.0
#
#    Total Incentive Cum Costs (Thousand $)  \
# 0                                   487.0
# 1                                   848.0
# 2                                  1225.0
# 3                                    70.0
# 4                                   187.0
#
#    Commercial Non-Incentive Cum Costs (Thousand $)  \
# 0                                            145.0
# 1                                            145.0
# 2                                            151.0
# 3                                            146.0
# 4                                             38.0
#
#    Total Non-Incentive Cum Costs (Thousand $)  \
# 0                                       348.0
# 1                                       526.0
# 2                                      1095.0
# 3                                       321.0
# 4                                       194.0
#
#    Commercial Weighted Avg Life (Yrs)  Overall Annual Energy Savings (MWh)  \
# 0                              12.574                                  Low
# 1                              12.574                             Moderate
# 2                               5.000                             Moderate
# 3                              13.269                                  Low
# 4                              12.727                             Moderate
#
#    Overall Peak Demand Savings (MW)
# 0                               Low
# 1                          Moderate
# 2                              High
# 3                               Low
# 4                          Moderate
#
# [5 rows x 22 columns]

# %%
energy_efficiency.columns
# Out:
# Index(['Utility Name', 'State', 'BA Code', 'Commercial Annual Savings (MWh)',
#        'Total Annual Savings (MWh)',
#        'Commercial Peak Demand Annual Savings (MW)',
#        'Total Peak Demand Annual Savings (MW)', 'Commercial Cum Savings (MWh)',
#        'Total Cum Savings (MWh)', 'Commercial Cum Peak Demand Savings (MWh)',
#        'Total Cum Peak Demand Savings (MWh)',
#        'Commercial Annual Incent Cost (Thousand $)',
#        'Total Annual Incent Cost (Thousand $)',
#        'Commercial Non-Incentive Annual Costs (Thousand $)',
#        'Total Non-Incentive Annual Costs (Thousand $)',
#        'Commercial Incentive Cum Costs (Thousand $)',
#        'Total Incentive Cum Costs (Thousand $)',
#        'Commercial Non-Incentive Cum Costs (Thousand $)',
#        'Total Non-Incentive Cum Costs (Thousand $)',
#        'Commercial Weighted Avg Life (Yrs)',
#        'Overall Annual Energy Savings (MWh)',
#        'Overall Peak Demand Savings (MW)'],
#       dtype='object')

# %% [markdown]
# Let's aggregate some features to simplify the dataframe

# %%
# Simplified aggregation with total values only
state_efficiency = energy_efficiency.groupby('State').agg({
    'Total Annual Savings (MWh)': 'sum',
    'Total Peak Demand Annual Savings (MW)': 'sum'
}).reset_index()

# Create categories for both metrics
conditions_energy = [
    state_efficiency['Total Annual Savings (MWh)'] >= state_efficiency['Total Annual Savings (MWh)'].quantile(0.75),
    (state_efficiency['Total Annual Savings (MWh)'] >= state_efficiency['Total Annual Savings (MWh)'].quantile(0.25)),
    state_efficiency['Total Annual Savings (MWh)'] < state_efficiency['Total Annual Savings (MWh)'].quantile(0.25)
]
choices = ['High Savings', 'Moderate Savings', 'Low Savings']
state_efficiency['State_Total_Energy_Savings'] = np.select(conditions_energy, choices, default='Unknown')

conditions_peak = [
    state_efficiency['Total Peak Demand Annual Savings (MW)'] >= state_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.75),
    (state_efficiency['Total Peak Demand Annual Savings (MW)'] >= state_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.25)),
    state_efficiency['Total Peak Demand Annual Savings (MW)'] < state_efficiency['Total Peak Demand Annual Savings (MW)'].quantile(0.25)
]
state_efficiency['State_Total_Peak_Savings'] = np.select(conditions_peak, choices, default='Unknown')

# %%
# Merge back to original dataframe
energy_efficiency = pd.merge(energy_efficiency, state_efficiency[['State', 'State_Total_Energy_Savings', 'State_Total_Peak_Savings']], 
                           on='State', how='left')
energy_efficiency.head()
# Out:
#                     Utility Name State BA Code  \
# 0        Aiken Electric Coop Inc    SC      SC
# 1  PowerSouth Energy Cooperative    AL    SOCO
# 2               Alabama Power Co    AL    SOCO
# 3        Alameda Municipal Power    CA    CISO
# 4      City of Alexandria - (MN)    MN    MISO
#
#    Commercial Annual Savings (MWh)  Total Annual Savings (MWh)  \
# 0                           1686.0                       206.0
# 1                           1686.0                      2550.0
# 2                            759.0                      5767.0
# 3                            111.0                       146.0
# 4                            673.0                      3306.0
#
#    Commercial Peak Demand Annual Savings (MW)  \
# 0                                         0.4
# 1                                         0.4
# 2                                         0.2
# 3                                         0.0
# 4                                         0.1
#
#    Total Peak Demand Annual Savings (MW)  Commercial Cum Savings (MWh)  \
# 0                                    0.0                       18796.5
# 1                                    2.1                       18796.5
# 2                                   11.9                        3797.0
# 3                                    0.1                        1460.0
# 4                                    0.7                        8564.0
#
#    Total Cum Savings (MWh)  Commercial Cum Peak Demand Savings (MWh)  ...  \
# 0                  27204.0                                       0.4  ...
# 1                  28552.0                                       0.4  ...
# 2                  45489.0                                       0.2  ...
# 3                   1958.0                                       0.0  ...
# 4                  43191.0                                       0.1  ...
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 0                                           37.0
# 1                                          526.0
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
#
#    Commercial Incentive Cum Costs (Thousand $)  \
# 0                                        190.0
# 1                                        190.0
# 2                                         36.0
# 3                                         23.0
# 4                                         36.0
#
#    Total Incentive Cum Costs (Thousand $)  \
# 0                                   487.0
# 1                                   848.0
# 2                                  1225.0
# 3                                    70.0
# 4                                   187.0
#
#    Commercial Non-Incentive Cum Costs (Thousand $)  \
# 0                                            145.0
# 1                                            145.0
# 2                                            151.0
# 3                                            146.0
# 4                                             38.0
#
#    Total Non-Incentive Cum Costs (Thousand $)  \
# 0                                       348.0
# 1                                       526.0
# 2                                      1095.0
# 3                                       321.0
# 4                                       194.0
#
#    Commercial Weighted Avg Life (Yrs)  Overall Annual Energy Savings (MWh)  \
# 0                              12.574                                  Low
# 1                              12.574                             Moderate
# 2                               5.000                             Moderate
# 3                              13.269                                  Low
# 4                              12.727                             Moderate
#
#    Overall Peak Demand Savings (MW)  State_Total_Energy_Savings  \
# 0                               Low            Moderate Savings
# 1                          Moderate                 Low Savings
# 2                              High                 Low Savings
# 3                               Low                High Savings
# 4                          Moderate                High Savings
#
#    State_Total_Peak_Savings
# 0          Moderate Savings
# 1          Moderate Savings
# 2          Moderate Savings
# 3              High Savings
# 4              High Savings
#
# [5 rows x 24 columns]

# %%
# Keep only relevant columns
energy_efficiency_clean = energy_efficiency[['State', 'Utility Name', 'BA Code', 'Overall Annual Energy Savings (MWh)',
                                            'Overall Peak Demand Savings (MW)',
                                           'State_Total_Energy_Savings', 'State_Total_Peak_Savings']]

energy_efficiency_clean.head()
# Out:
#   State                   Utility Name BA Code  \
# 0    SC        Aiken Electric Coop Inc      SC
# 1    AL  PowerSouth Energy Cooperative    SOCO
# 2    AL               Alabama Power Co    SOCO
# 3    CA        Alameda Municipal Power    CISO
# 4    MN      City of Alexandria - (MN)    MISO
#
#   Overall Annual Energy Savings (MWh) Overall Peak Demand Savings (MW)  \
# 0                                 Low                              Low
# 1                            Moderate                         Moderate
# 2                            Moderate                             High
# 3                                 Low                              Low
# 4                            Moderate                         Moderate
#
#   State_Total_Energy_Savings State_Total_Peak_Savings
# 0           Moderate Savings         Moderate Savings
# 1                Low Savings         Moderate Savings
# 2                Low Savings         Moderate Savings
# 3               High Savings             High Savings
# 4               High Savings             High Savings

# %%
# Rename columns for more clarity
energy_efficiency_clean = energy_efficiency_clean.rename(columns={'Overall Annual Energy Savings (MWh)': 'Utility Annual Energy Savings',
                                                                  'Overall Peak Demand Savings (MW)':'Utility Peak Demand Savings'})
energy_efficiency_clean.head()
# Out:
#   State                   Utility Name BA Code Utility Annual Energy Savings  \
# 0    SC        Aiken Electric Coop Inc      SC                           Low
# 1    AL  PowerSouth Energy Cooperative    SOCO                      Moderate
# 2    AL               Alabama Power Co    SOCO                      Moderate
# 3    CA        Alameda Municipal Power    CISO                           Low
# 4    MN      City of Alexandria - (MN)    MISO                      Moderate
#
#   Utility Peak Demand Savings State_Total_Energy_Savings  \
# 0                         Low           Moderate Savings
# 1                    Moderate                Low Savings
# 2                        High                Low Savings
# 3                         Low               High Savings
# 4                    Moderate               High Savings
#
#   State_Total_Peak_Savings
# 0         Moderate Savings
# 1         Moderate Savings
# 2         Moderate Savings
# 3             High Savings
# 4             High Savings

# %%
energy_efficiency_clean.isna().value_counts()
# Out:
# State  Utility Name  BA Code  Utility Annual Energy Savings  Utility Peak Demand Savings  State_Total_Energy_Savings  State_Total_Peak_Savings
# False  False         False    False                          False                        False                       False                       457
# Name: count, dtype: int64

# %%
len(energy_efficiency_clean['State'].value_counts())
# Out:
# 51

# %%
# Merge net_gen_reliability and energy_efficiency on the State column
merged_2 = pd.merge(net_gen_reliability, energy_efficiency_clean, on='State', how='outer')

merged_2.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AL                  High                     High
# 3    AL                  High                     High
# 4    AL                  High                     High
#
#   Independent_Generation_Rank Commercial_Generation_Rank  \
# 0                         Low                       High
# 1                        High                        Low
# 2                        High                        Low
# 3                        High                        Low
# 4                        High                        Low
#
#   Industrial_Generation_Rank Capacity_Growth_Status        Census Division  \
# 0                        Low                Growing  Pacific Noncontiguous
# 1                       High                Growing     East South Central
# 2                       High                Growing     East South Central
# 3                       High                Growing     East South Central
# 4                       High                Growing     East South Central
#
#    Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  ...  \
# 0                                           84.5                  138.8  ...
# 1                                           80.0                  186.9  ...
# 2                                           80.0                  186.9  ...
# 3                                           80.0                  186.9  ...
# 4                                           80.0                  186.9  ...
#
#                SAIDI Major Events               SAIFI Major Events  \
# 0  Moderate Interruption Duration      High Interruption Frequency
# 1  Moderate Interruption Duration  Moderate Interruption Frequency
# 2  Moderate Interruption Duration  Moderate Interruption Frequency
# 3  Moderate Interruption Duration  Moderate Interruption Frequency
# 4  Moderate Interruption Duration  Moderate Interruption Frequency
#
#             SAIDI No Major Events            SAIFI No Major Events  \
# 0      Long Interruption Duration      High Interruption Frequency
# 1  Moderate Interruption Duration  Moderate Interruption Frequency
# 2  Moderate Interruption Duration  Moderate Interruption Frequency
# 3  Moderate Interruption Duration  Moderate Interruption Frequency
# 4  Moderate Interruption Duration  Moderate Interruption Frequency
#
#                     Utility Name  BA Code Utility Annual Energy Savings  \
# 0    Golden Valley Elec Assn Inc  Unknown                           Low
# 1  PowerSouth Energy Cooperative     SOCO                      Moderate
# 2               Alabama Power Co     SOCO                      Moderate
# 3     Dixie Electric Coop - (AL)     SOCO                           Low
# 4     Tennessee Valley Authority      TVA                      Moderate
#
#   Utility Peak Demand Savings State_Total_Energy_Savings  \
# 0                         Low                Low Savings
# 1                    Moderate                Low Savings
# 2                        High                Low Savings
# 3                    Moderate                Low Savings
# 4                    Moderate                Low Savings
#
#   State_Total_Peak_Savings
# 0              Low Savings
# 1         Moderate Savings
# 2         Moderate Savings
# 3         Moderate Savings
# 4         Moderate Savings
#
# [5 rows x 21 columns]

# %%
merged_2[merged_2['BA Code'] == 'Unknown']
# Out:
#     State Total_Generation_Rank Electric_Generation_Rank  \
# 0      AK                   Low                      Low
# 34     CA                  High                     High
# 86     FL                  High                     High
# 91     FL                  High                     High
# 116    HI                   Low                      Low
# 117    HI                   Low                      Low
#
#     Independent_Generation_Rank Commercial_Generation_Rank  \
# 0                           Low                       High
# 34                         High                       High
# 86                     Moderate                       High
# 91                     Moderate                       High
# 116                         Low                       High
# 117                         Low                       High
#
#     Industrial_Generation_Rank Capacity_Growth_Status        Census Division  \
# 0                          Low                Growing  Pacific Noncontiguous
# 34                        High              Shrinking     Pacific Contiguous
# 86                        High              Shrinking         South Atlantic
# 91                        High              Shrinking         South Atlantic
# 116                        Low                Growing  Pacific Noncontiguous
# 117                        Low                Growing  Pacific Noncontiguous
#
#      Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  \
# 0                                             84.5                  138.8
# 34                                           100.2                  248.1
# 86                                           100.2                  157.7
# 91                                           100.2                  157.7
# 116                                           99.9                  275.1
# 117                                           99.9                  275.1
#
#      ...              SAIDI Major Events               SAIFI Major Events  \
# 0    ...  Moderate Interruption Duration      High Interruption Frequency
# 34   ...  Moderate Interruption Duration  Moderate Interruption Frequency
# 86   ...     Short Interruption Duration       Low Interruption Frequency
# 91   ...     Short Interruption Duration       Low Interruption Frequency
# 116  ...      Long Interruption Duration  Moderate Interruption Frequency
# 117  ...      Long Interruption Duration  Moderate Interruption Frequency
#
#            SAIDI No Major Events            SAIFI No Major Events  \
# 0     Long Interruption Duration      High Interruption Frequency
# 34    Long Interruption Duration  Moderate Interruption Frequency
# 86   Short Interruption Duration       Low Interruption Frequency
# 91   Short Interruption Duration       Low Interruption Frequency
# 116   Long Interruption Duration      High Interruption Frequency
# 117   Long Interruption Duration      High Interruption Frequency
#
#                          Utility Name  BA Code Utility Annual Energy Savings  \
# 0         Golden Valley Elec Assn Inc  Unknown                           Low
# 34             City of Redding - (CA)  Unknown                           Low
# 86    Fort Pierce Utilities Authority  Unknown                           Low
# 91        Kissimmee Utility Authority  Unknown                           Low
# 116  Kauai Island Utility Cooperative  Unknown                      Moderate
# 117  Hawaii Energy Efficiency Program  Unknown                          High
#
#     Utility Peak Demand Savings State_Total_Energy_Savings  \
# 0                           Low                Low Savings
# 34                          Low               High Savings
# 86                          Low           Moderate Savings
# 91                         High           Moderate Savings
# 116                    Moderate                Low Savings
# 117                        High                Low Savings
#
#     State_Total_Peak_Savings
# 0                Low Savings
# 34              High Savings
# 86              High Savings
# 91              High Savings
# 116              Low Savings
# 117              Low Savings
#
# [6 rows x 21 columns]

# %%
merged_2.isna().value_counts()
# Out:
# State  Total_Generation_Rank  Electric_Generation_Rank  Independent_Generation_Rank  Commercial_Generation_Rank  Industrial_Generation_Rank  Capacity_Growth_Status  Census Division  Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIDI Major Events  SAIFI Major Events  SAIDI No Major Events  SAIFI No Major Events  Utility Name  BA Code  Utility Annual Energy Savings  Utility Peak Demand Savings  State_Total_Energy_Savings  State_Total_Peak_Savings
# False  False                  False                     False                        False                       False                       False                   False            False                                          False                  False                   False               False               False                  False                  False         False    False                          False                        False                       False                       457
# Name: count, dtype: int64

# %%
merged_2.isin(['Unknown']).sum()
# Out:
# State                                            0
# Total_Generation_Rank                            0
# Electric_Generation_Rank                         0
# Independent_Generation_Rank                      0
# Commercial_Generation_Rank                       0
# Industrial_Generation_Rank                       0
# Capacity_Growth_Status                           0
# Census Division                                  0
# Percent of Customers Reported w/ Major Events    0
# CAIDI w/ Major Events                            0
# CAIDI w/o Major Events                           0
# SAIDI Major Events                               0
# SAIFI Major Events                               0
# SAIDI No Major Events                            0
# SAIFI No Major Events                            0
# Utility Name                                     0
# BA Code                                          6
# Utility Annual Energy Savings                    0
# Utility Peak Demand Savings                      0
# State_Total_Energy_Savings                       0
# State_Total_Peak_Savings                         0
# dtype: int64

# %% [markdown]
# ### Loading in the regional Demand data for joining

# %%
demand = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Regional_Demand_2023.csv', index_col=0)
demand.head()
# Out:
#   Region State  Annual_Region_Demand_MWh
# 0    CAL    CA             726482.230137
# 1    CAL    CA             726482.230137
# 2    CAL    CA             726482.230137
# 3    CAL    CA             726482.230137
# 4    CAL    CA             726482.230137

# %%
# Merge demand with merged 2

merged_3 = pd.merge(merged_2, demand, on='State', how='outer')
merged_3.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AK                   Low                      Low
# 2    AK                   Low                      Low
# 3    AK                   Low                      Low
# 4    AK                   Low                      Low
#
#   Independent_Generation_Rank Commercial_Generation_Rank  \
# 0                         Low                       High
# 1                         Low                       High
# 2                         Low                       High
# 3                         Low                       High
# 4                         Low                       High
#
#   Industrial_Generation_Rank Capacity_Growth_Status        Census Division  \
# 0                        Low                Growing  Pacific Noncontiguous
# 1                        Low                Growing  Pacific Noncontiguous
# 2                        Low                Growing  Pacific Noncontiguous
# 3                        Low                Growing  Pacific Noncontiguous
# 4                        Low                Growing  Pacific Noncontiguous
#
#    Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  ...  \
# 0                                           84.5                  138.8  ...
# 1                                           84.5                  138.8  ...
# 2                                           84.5                  138.8  ...
# 3                                           84.5                  138.8  ...
# 4                                           84.5                  138.8  ...
#
#         SAIDI No Major Events        SAIFI No Major Events  \
# 0  Long Interruption Duration  High Interruption Frequency
# 1  Long Interruption Duration  High Interruption Frequency
# 2  Long Interruption Duration  High Interruption Frequency
# 3  Long Interruption Duration  High Interruption Frequency
# 4  Long Interruption Duration  High Interruption Frequency
#
#                   Utility Name  BA Code Utility Annual Energy Savings  \
# 0  Golden Valley Elec Assn Inc  Unknown                           Low
# 1  Golden Valley Elec Assn Inc  Unknown                           Low
# 2  Golden Valley Elec Assn Inc  Unknown                           Low
# 3  Golden Valley Elec Assn Inc  Unknown                           Low
# 4  Golden Valley Elec Assn Inc  Unknown                           Low
#
#   Utility Peak Demand Savings State_Total_Energy_Savings  \
# 0                         Low                Low Savings
# 1                         Low                Low Savings
# 2                         Low                Low Savings
# 3                         Low                Low Savings
# 4                         Low                Low Savings
#
#   State_Total_Peak_Savings Region Annual_Region_Demand_MWh
# 0              Low Savings     NW            983874.734247
# 1              Low Savings     NW            983874.734247
# 2              Low Savings     NW            983874.734247
# 3              Low Savings     NW            983874.734247
# 4              Low Savings     NW            983874.734247
#
# [5 rows x 23 columns]

# %%
ixp = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_IXP.csv', index_col=0)
ixp.head()
# Out:
#                                  IXP Name         City State
# 0                                   48 IX      Phoenix    AZ
# 1                                   ABQIX  Albuquerque    NM
# 2                                AlaskaIX    Anchorage    AK
# 3  Amateur Radio Internet Exchange - ARIX      Fremont    CA
# 4  Amateur Radio Internet Exchange - ARIX     Portland    OR

# %%
ixp.isna().value_counts()
# Out:
# IXP Name  City   State
# False     False  False    196
#                  True       3
# Name: count, dtype: int64

# %%
ixp[ixp['State'].isna()]
# Out:
#                                              IXP Name           City State
# 21  BroadBand Internet Exchange US-West - BBIX US-...     West Coast   NaN
# 32                                CoreSite - Any2East  Washington DC   NaN
# 74  Equinix Internet Exchange Seattle - Equinix Se...        Seattle   NaN

# %%
ixp.loc[(ixp['City'] == 'Seattle') & (ixp['State'] == 'Washington'), 'City'] = 'Washington'

# %%
# Fix Seattle, Washington data
ixp.loc[ixp['City'] == 'Seattle', 'State'] = 'WA'

# Fix Washington DC data
ixp.loc[ixp['City'] == 'Washington DC', ['City', 'State']] = ['Washington', 'DC']

#Drop rows where City is West Coast
ixp = ixp[ixp['City'] != 'West Coast']

# %%
ixp[ixp['City'] == 'Seattle']
# Out:
#                                               IXP Name     City State
# 74   Equinix Internet Exchange Seattle - Equinix Se...  Seattle    WA
# 123                            Megaport MegaIX Seattle  Seattle    WA
# 132        Moe Internet Exchange - Seattle - MoeIX SEA  Seattle    WA
# 160                        Pacific Wave Exchange in LA  Seattle    WA
# 171  Seattle Internet Exchange (MTU 1500) - SIX Sea...  Seattle    WA
# 172  Seattle Internet Exchange (MTU 9000) - SIX Sea...  Seattle    WA

# %%
ixp[ixp['City'] == 'Washington']
# Out:
#                 IXP Name        City State
# 32   CoreSite - Any2East  Washington    DC
# 85  Global Peer Exchange  Washington    DC

# %%
ixp['State'].value_counts()
# Out:
# State
# CA       30
# TX       21
# VA       13
# IL       11
# NY       11
# FL       10
# AZ        8
# MO        8
# OR        7
# WA        7
# GA        5
# CO        5
# OH        5
# NV        4
# MA        4
# NC        4
# IA        4
# VT        3
# UT        3
# PA        3
# HI        3
# MI        3
# MN        2
# MD        2
# DC        2
# CT        2
# WI        2
# AL        2
# WV        1
# KY        1
# NE        1
# ME        1
# AK        1
# TN        1
# NM        1
# IN        1
# NJ        1
# KS        1
# OK        1
# ND        1
# Texas     1
# MT        1
# Name: count, dtype: int64

# %%
ixp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198 entries, 0 to 198
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IXP Name  198 non-null    object
#  1   City      198 non-null    object
#  2   State     198 non-null    object
# dtypes: object(3)
# memory usage: 6.2+ KB

# %%
# Merge ixp data
merged_4 = pd.merge(merged_3, ixp, on='State', how='outer')

merged_4.isna().value_counts()
# Out:
# State  Total_Generation_Rank  Electric_Generation_Rank  Independent_Generation_Rank  Commercial_Generation_Rank  Industrial_Generation_Rank  Capacity_Growth_Status  Census Division  Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIDI Major Events  SAIFI Major Events  SAIDI No Major Events  SAIFI No Major Events  Utility Name  BA Code  Utility Annual Energy Savings  Utility Peak Demand Savings  State_Total_Energy_Savings  State_Total_Peak_Savings  Region  Annual_Region_Demand_MWh  IXP Name  City
# False  False                  False                     False                        False                       False                       False                   False            False                                          False                  False                   False               False               False                  False                  False         False    False                          False                        False                       False                     False   False                     False     False    1077115
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      True      True       19710
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    True    True                      False     False        122
#        True                   True                      True                         True                        True                        True                    True             True                                           True                   True                    True                True                True                   True                   True          True     True                           True                         True                        True                      True    True                      False     False          1
# Name: count, dtype: int64

# %%
merged_4.head(10)
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AK                   Low                      Low
# 2    AK                   Low                      Low
# 3    AK                   Low                      Low
# 4    AK                   Low                      Low
# 5    AK                   Low                      Low
# 6    AK                   Low                      Low
# 7    AK                   Low                      Low
# 8    AK                   Low                      Low
# 9    AK                   Low                      Low
#
#   Independent_Generation_Rank Commercial_Generation_Rank  \
# 0                         Low                       High
# 1                         Low                       High
# 2                         Low                       High
# 3                         Low                       High
# 4                         Low                       High
# 5                         Low                       High
# 6                         Low                       High
# 7                         Low                       High
# 8                         Low                       High
# 9                         Low                       High
#
#   Industrial_Generation_Rank Capacity_Growth_Status        Census Division  \
# 0                        Low                Growing  Pacific Noncontiguous
# 1                        Low                Growing  Pacific Noncontiguous
# 2                        Low                Growing  Pacific Noncontiguous
# 3                        Low                Growing  Pacific Noncontiguous
# 4                        Low                Growing  Pacific Noncontiguous
# 5                        Low                Growing  Pacific Noncontiguous
# 6                        Low                Growing  Pacific Noncontiguous
# 7                        Low                Growing  Pacific Noncontiguous
# 8                        Low                Growing  Pacific Noncontiguous
# 9                        Low                Growing  Pacific Noncontiguous
#
#    Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  ...  \
# 0                                           84.5                  138.8  ...
# 1                                           84.5                  138.8  ...
# 2                                           84.5                  138.8  ...
# 3                                           84.5                  138.8  ...
# 4                                           84.5                  138.8  ...
# 5                                           84.5                  138.8  ...
# 6                                           84.5                  138.8  ...
# 7                                           84.5                  138.8  ...
# 8                                           84.5                  138.8  ...
# 9                                           84.5                  138.8  ...
#
#                   Utility Name  BA Code Utility Annual Energy Savings  \
# 0  Golden Valley Elec Assn Inc  Unknown                           Low
# 1  Golden Valley Elec Assn Inc  Unknown                           Low
# 2  Golden Valley Elec Assn Inc  Unknown                           Low
# 3  Golden Valley Elec Assn Inc  Unknown                           Low
# 4  Golden Valley Elec Assn Inc  Unknown                           Low
# 5  Golden Valley Elec Assn Inc  Unknown                           Low
# 6  Golden Valley Elec Assn Inc  Unknown                           Low
# 7  Golden Valley Elec Assn Inc  Unknown                           Low
# 8  Golden Valley Elec Assn Inc  Unknown                           Low
# 9  Golden Valley Elec Assn Inc  Unknown                           Low
#
#   Utility Peak Demand Savings State_Total_Energy_Savings  \
# 0                         Low                Low Savings
# 1                         Low                Low Savings
# 2                         Low                Low Savings
# 3                         Low                Low Savings
# 4                         Low                Low Savings
# 5                         Low                Low Savings
# 6                         Low                Low Savings
# 7                         Low                Low Savings
# 8                         Low                Low Savings
# 9                         Low                Low Savings
#
#   State_Total_Peak_Savings Region Annual_Region_Demand_MWh  IXP Name  \
# 0              Low Savings     NW            983874.734247  AlaskaIX
# 1              Low Savings     NW            983874.734247  AlaskaIX
# 2              Low Savings     NW            983874.734247  AlaskaIX
# 3              Low Savings     NW            983874.734247  AlaskaIX
# 4              Low Savings     NW            983874.734247  AlaskaIX
# 5              Low Savings     NW            983874.734247  AlaskaIX
# 6              Low Savings     NW            983874.734247  AlaskaIX
# 7              Low Savings     NW            983874.734247  AlaskaIX
# 8              Low Savings     NW            983874.734247  AlaskaIX
# 9              Low Savings     NW            983874.734247  AlaskaIX
#
#         City
# 0  Anchorage
# 1  Anchorage
# 2  Anchorage
# 3  Anchorage
# 4  Anchorage
# 5  Anchorage
# 6  Anchorage
# 7  Anchorage
# 8  Anchorage
# 9  Anchorage
#
# [10 rows x 25 columns]

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096948 entries, 0 to 1096947
# Data columns (total 25 columns):
#  #   Column                                         Non-Null Count    Dtype
# ---  ------                                         --------------    -----
#  0   State                                          1096948 non-null  object
#  1   Total_Generation_Rank                          1096947 non-null  object
#  2   Electric_Generation_Rank                       1096947 non-null  object
#  3   Independent_Generation_Rank                    1096947 non-null  object
#  4   Commercial_Generation_Rank                     1096947 non-null  object
#  5   Industrial_Generation_Rank                     1096947 non-null  object
#  6   Capacity_Growth_Status                         1096947 non-null  object
#  7   Census Division                                1096947 non-null  object
#  8   Percent of Customers Reported w/ Major Events  1096947 non-null  float64
#  9   CAIDI w/ Major Events                          1096947 non-null  float64
#  10  CAIDI w/o Major Events                         1096947 non-null  float64
#  11  SAIDI Major Events                             1096947 non-null  object
#  12  SAIFI Major Events                             1096947 non-null  object
#  13  SAIDI No Major Events                          1096947 non-null  object
#  14  SAIFI No Major Events                          1096947 non-null  object
#  15  Utility Name                                   1096947 non-null  object
#  16  BA Code                                        1096947 non-null  object
#  17  Utility Annual Energy Savings                  1096947 non-null  object
#  18  Utility Peak Demand Savings                    1096947 non-null  object
#  19  State_Total_Energy_Savings                     1096947 non-null  object
#  20  State_Total_Peak_Savings                       1096947 non-null  object
#  21  Region                                         1096825 non-null  object
#  22  Annual_Region_Demand_MWh                       1096825 non-null  float64
#  23  IXP Name                                       1077238 non-null  object
#  24  City                                           1077238 non-null  object
# dtypes: float64(4), object(21)
# memory usage: 209.2+ MB

# %%
missing_states = merged_4[merged_4.isna().any(axis=1)]['State'].unique()
missing_states
# Out:
# array(['AR', 'CO', 'DE', 'HI', 'ID', 'KY', 'LA', 'MS', 'MT', 'NH', 'RI',
#        'SC', 'SD', 'TN', 'Texas', 'WV', 'WY'], dtype=object)

# %%
# Group by state to get IXP count per state
ixp_counts = merged_4.groupby('State')['IXP Name'].nunique().reset_index()
ixp_counts.columns = ['State', 'IXP_Count']

# Merge back the IXP counts
merged_4 = merged_4.merge(ixp_counts, on='State', how='left')

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096948 entries, 0 to 1096947
# Data columns (total 27 columns):
#  #   Column                                         Non-Null Count    Dtype
# ---  ------                                         --------------    -----
#  0   State                                          1096948 non-null  object
#  1   Total_Generation_Rank                          1096947 non-null  object
#  2   Electric_Generation_Rank                       1096947 non-null  object
#  3   Independent_Generation_Rank                    1096947 non-null  object
#  4   Commercial_Generation_Rank                     1096947 non-null  object
#  5   Industrial_Generation_Rank                     1096947 non-null  object
#  6   Capacity_Growth_Status                         1096947 non-null  object
#  7   Census Division                                1096947 non-null  object
#  8   Percent of Customers Reported w/ Major Events  1096947 non-null  float64
#  9   CAIDI w/ Major Events                          1096947 non-null  float64
#  10  CAIDI w/o Major Events                         1096947 non-null  float64
#  11  SAIDI Major Events                             1096947 non-null  object
#  12  SAIFI Major Events                             1096947 non-null  object
#  13  SAIDI No Major Events                          1096947 non-null  object
#  14  SAIFI No Major Events                          1096947 non-null  object
#  15  Utility Name                                   1096947 non-null  object
#  16  BA Code                                        1096947 non-null  object
#  17  Utility Annual Energy Savings                  1096947 non-null  object
#  18  Utility Peak Demand Savings                    1096947 non-null  object
#  19  State_Total_Energy_Savings                     1096947 non-null  object
#  20  State_Total_Peak_Savings                       1096947 non-null  object
#  21  Region                                         1096825 non-null  object
#  22  Annual_Region_Demand_MWh                       1096825 non-null  float64
#  23  IXP Name                                       1077238 non-null  object
#  24  City                                           1077238 non-null  object
#  25  IXP_Name                                       1096948 non-null  object
#  26  IXP_Count                                      1096948 non-null  int64
# dtypes: float64(4), int64(1), object(22)
# memory usage: 226.0+ MB

# %%
merged_4['IXP_Count'].value_counts()
# Out:
# IXP_Count
# 27    350400
# 18    160965
# 7     120085
# 11     99280
# 4      87600
# 10     83950
# 8      49640
# 3      36141
# 5      32950
# 2      32120
# 1      24107
# 0      19710
# Name: count, dtype: int64

# %%
merged_4['IXP Name'] = merged_4['IXP Name'].fillna('No IXP')
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096948 entries, 0 to 1096947
# Data columns (total 27 columns):
#  #   Column                                         Non-Null Count    Dtype
# ---  ------                                         --------------    -----
#  0   State                                          1096948 non-null  object
#  1   Total_Generation_Rank                          1096947 non-null  object
#  2   Electric_Generation_Rank                       1096947 non-null  object
#  3   Independent_Generation_Rank                    1096947 non-null  object
#  4   Commercial_Generation_Rank                     1096947 non-null  object
#  5   Industrial_Generation_Rank                     1096947 non-null  object
#  6   Capacity_Growth_Status                         1096947 non-null  object
#  7   Census Division                                1096947 non-null  object
#  8   Percent of Customers Reported w/ Major Events  1096947 non-null  float64
#  9   CAIDI w/ Major Events                          1096947 non-null  float64
#  10  CAIDI w/o Major Events                         1096947 non-null  float64
#  11  SAIDI Major Events                             1096947 non-null  object
#  12  SAIFI Major Events                             1096947 non-null  object
#  13  SAIDI No Major Events                          1096947 non-null  object
#  14  SAIFI No Major Events                          1096947 non-null  object
#  15  Utility Name                                   1096947 non-null  object
#  16  BA Code                                        1096947 non-null  object
#  17  Utility Annual Energy Savings                  1096947 non-null  object
#  18  Utility Peak Demand Savings                    1096947 non-null  object
#  19  State_Total_Energy_Savings                     1096947 non-null  object
#  20  State_Total_Peak_Savings                       1096947 non-null  object
#  21  Region                                         1096825 non-null  object
#  22  Annual_Region_Demand_MWh                       1096825 non-null  float64
#  23  IXP Name                                       1096948 non-null  object
#  24  City                                           1077238 non-null  object
#  25  IXP_Name                                       1096948 non-null  object
#  26  IXP_Count                                      1096948 non-null  int64
# dtypes: float64(4), int64(1), object(22)
# memory usage: 226.0+ MB

# %%
merged_4[merged_4['City'].isna() == True]
# Out:
#         State Total_Generation_Rank Electric_Generation_Rank  \
# 4015       AR              Moderate                 Moderate
# 4016       AR              Moderate                 Moderate
# 4017       AR              Moderate                 Moderate
# 4018       AR              Moderate                 Moderate
# 4019       AR              Moderate                 Moderate
# ...       ...                   ...                      ...
# 1096943    WY                   Low                 Moderate
# 1096944    WY                   Low                 Moderate
# 1096945    WY                   Low                 Moderate
# 1096946    WY                   Low                 Moderate
# 1096947    WY                   Low                 Moderate
#
#         Independent_Generation_Rank Commercial_Generation_Rank  \
# 4015                            Low                        Low
# 4016                            Low                        Low
# 4017                            Low                        Low
# 4018                            Low                        Low
# 4019                            Low                        Low
# ...                             ...                        ...
# 1096943                         Low                        Low
# 1096944                         Low                        Low
# 1096945                         Low                        Low
# 1096946                         Low                        Low
# 1096947                         Low                        Low
#
#         Industrial_Generation_Rank Capacity_Growth_Status     Census Division  \
# 4015                      Moderate              Shrinking  West South Central
# 4016                      Moderate              Shrinking  West South Central
# 4017                      Moderate              Shrinking  West South Central
# 4018                      Moderate              Shrinking  West South Central
# 4019                      Moderate              Shrinking  West South Central
# ...                            ...                    ...                 ...
# 1096943                   Moderate              Shrinking            Mountain
# 1096944                   Moderate              Shrinking            Mountain
# 1096945                   Moderate              Shrinking            Mountain
# 1096946                   Moderate              Shrinking            Mountain
# 1096947                   Moderate              Shrinking            Mountain
#
#          Percent of Customers Reported w/ Major Events  CAIDI w/ Major Events  \
# 4015                                              89.3                  433.4
# 4016                                              89.3                  433.4
# 4017                                              89.3                  433.4
# 4018                                              89.3                  433.4
# 4019                                              89.3                  433.4
# ...                                                ...                    ...
# 1096943                                           75.9                  127.8
# 1096944                                           75.9                  127.8
# 1096945                                           75.9                  127.8
# 1096946                                           75.9                  127.8
# 1096947                                           75.9                  127.8
#
#          ...  Utility Annual Energy Savings Utility Peak Demand Savings  \
# 4015     ...                           High                        High
# 4016     ...                           High                        High
# 4017     ...                           High                        High
# 4018     ...                           High                        High
# 4019     ...                           High                        High
# ...      ...                            ...                         ...
# 1096943  ...                       Moderate                    Moderate
# 1096944  ...                       Moderate                    Moderate
# 1096945  ...                       Moderate                    Moderate
# 1096946  ...                       Moderate                    Moderate
# 1096947  ...                       Moderate                    Moderate
#
#         State_Total_Energy_Savings State_Total_Peak_Savings Region  \
# 4015              Moderate Savings         Moderate Savings     SE
# 4016              Moderate Savings         Moderate Savings     SE
# 4017              Moderate Savings         Moderate Savings     SE
# 4018              Moderate Savings         Moderate Savings     SE
# 4019              Moderate Savings         Moderate Savings     SE
# ...                            ...                      ...    ...
# 1096943                Low Savings              Low Savings     NW
# 1096944                Low Savings              Low Savings     NW
# 1096945                Low Savings              Low Savings     NW
# 1096946                Low Savings              Low Savings     NW
# 1096947                Low Savings              Low Savings     NW
#
#         Annual_Region_Demand_MWh IXP Name City IXP_Name IXP_Count
# 4015               628665.969863   No IXP  NaN   No IXP         0
# 4016               628665.969863   No IXP  NaN   No IXP         0
# 4017               628665.969863   No IXP  NaN   No IXP         0
# 4018               628665.969863   No IXP  NaN   No IXP         0
# 4019               628665.969863   No IXP  NaN   No IXP         0
# ...                          ...      ...  ...      ...       ...
# 1096943            983874.734247   No IXP  NaN   No IXP         0
# 1096944            983874.734247   No IXP  NaN   No IXP         0
# 1096945            983874.734247   No IXP  NaN   No IXP         0
# 1096946            983874.734247   No IXP  NaN   No IXP         0
# 1096947            983874.734247   No IXP  NaN   No IXP         0
#
# [19710 rows x 27 columns]

# %% [markdown]
# There's 19,710 rows with no city level data for IXPs. For now I'll keep them as NaNs until after I've merged all the other city-level data.

# %% [markdown]
# ### Loading Retail Demand
