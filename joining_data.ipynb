# %% [markdown]
# # Joining the Data
#
# It is now time for the scary part. But we never back away from a challenge! Let's say a prayer and get ready to join the data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Merge 1

# %% [markdown]
# ### Loading in Utility Scale Net Generation Data and Reliability of Distribution Systems Date

# %%
net_gen = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Utility_Scale_Net_Generation.csv', index_col=0)

net_gen.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    CT              Moderate                      Low
# 2    MA                   Low                      Low
# 4    RI                   Low                      Low
# 5    VT                   Low                      Low
# 6    NJ              Moderate                      Low
#
#   Commercial_Generation_Rank Capacity_Growth_Status
# 0                   Moderate                Growing
# 2                       High                Growing
# 4                        Low              Shrinking
# 5                        Low              Shrinking
# 6                       High              Shrinking

# %%
net_gen['State'].value_counts().sum()
# Out:
# 39

# %%
reliability = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Reliability_Distribution.csv', index_col=0)

reliability.head()
# Out:
#   Census Division State  Percent of Customers Reported w/ Major Events  \
# 0     New England    CT                                          100.6
# 1     New England    ME                                          100.8
# 2     New England    MA                                           88.2
# 3     New England    NH                                           99.3
# 4     New England    RI                                           98.3
#
#    SAIDI w/ Major Events  SAIFI w/ Major Events  CAIDI w/ Major Events  \
# 0                  164.6                    0.9                  188.8
# 1                 1863.0                    3.3                  562.2
# 2                  259.4                    1.1                  245.4
# 3                  645.8                    1.8                  368.5
# 4                  104.6                    0.8                  133.7
#
#    SAIDI w/o Major Events  SAIFI w/o Major Events  CAIDI w/o Major Events
# 0                    70.3                     0.7                   107.3
# 1                   247.4                     2.0                   125.0
# 2                    82.2                     0.8                   105.4
# 3                   124.6                     1.0                   126.1
# 4                    52.2                     0.7                    78.3

# %%
reliability.corr(numeric_only=True)
# Out:
#                                                Percent of Customers Reported w/ Major Events  \
# Percent of Customers Reported w/ Major Events                                       1.000000
# SAIDI w/ Major Events                                                               0.155055
# SAIFI w/ Major Events                                                              -0.011626
# CAIDI w/ Major Events                                                               0.245667
# SAIDI w/o Major Events                                                              0.005549
# SAIFI w/o Major Events                                                             -0.077099
# CAIDI w/o Major Events                                                              0.106543
#
#                                                SAIDI w/ Major Events  \
# Percent of Customers Reported w/ Major Events               0.155055
# SAIDI w/ Major Events                                       1.000000
# SAIFI w/ Major Events                                       0.832496
# CAIDI w/ Major Events                                       0.887799
# SAIDI w/o Major Events                                      0.652470
# SAIFI w/o Major Events                                      0.644317
# CAIDI w/o Major Events                                      0.427449
#
#                                                SAIFI w/ Major Events  \
# Percent of Customers Reported w/ Major Events              -0.011626
# SAIDI w/ Major Events                                       0.832496
# SAIFI w/ Major Events                                       1.000000
# CAIDI w/ Major Events                                       0.573910
# SAIDI w/o Major Events                                      0.859044
# SAIFI w/o Major Events                                      0.939123
# CAIDI w/o Major Events                                      0.365608
#
#                                                CAIDI w/ Major Events  \
# Percent of Customers Reported w/ Major Events               0.245667
# SAIDI w/ Major Events                                       0.887799
# SAIFI w/ Major Events                                       0.573910
# CAIDI w/ Major Events                                       1.000000
# SAIDI w/o Major Events                                      0.438757
# SAIFI w/o Major Events                                      0.340570
# CAIDI w/o Major Events                                      0.490745
#
#                                                SAIDI w/o Major Events  \
# Percent of Customers Reported w/ Major Events                0.005549
# SAIDI w/ Major Events                                        0.652470
# SAIFI w/ Major Events                                        0.859044
# CAIDI w/ Major Events                                        0.438757
# SAIDI w/o Major Events                                       1.000000
# SAIFI w/o Major Events                                       0.911040
# CAIDI w/o Major Events                                       0.678920
#
#                                                SAIFI w/o Major Events  \
# Percent of Customers Reported w/ Major Events               -0.077099
# SAIDI w/ Major Events                                        0.644317
# SAIFI w/ Major Events                                        0.939123
# CAIDI w/ Major Events                                        0.340570
# SAIDI w/o Major Events                                       0.911040
# SAIFI w/o Major Events                                       1.000000
# CAIDI w/o Major Events                                       0.357660
#
#                                                CAIDI w/o Major Events
# Percent of Customers Reported w/ Major Events                0.106543
# SAIDI w/ Major Events                                        0.427449
# SAIFI w/ Major Events                                        0.365608
# CAIDI w/ Major Events                                        0.490745
# SAIDI w/o Major Events                                       0.678920
# SAIFI w/o Major Events                                       0.357660
# CAIDI w/o Major Events                                       1.000000

# %%
# Drop highly correlated metrics
reliability = reliability.drop(columns=['SAIDI w/ Major Events', 'SAIDI w/o Major Events', 'SAIFI w/o Major Events', 'Percent of Customers Reported w/ Major Events', 'Census Division'])
reliability.head()
# Out:
#   State  SAIFI w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events
# 0    CT                    0.9                  188.8                   107.3
# 1    ME                    3.3                  562.2                   125.0
# 2    MA                    1.1                  245.4                   105.4
# 3    NH                    1.8                  368.5                   126.1
# 4    RI                    0.8                  133.7                    78.3

# %%
reliability.describe()
# Out:
#        SAIFI w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events
# count              51.000000              51.000000               51.000000
# mean                1.386275             226.466667              116.519608
# std                 0.636873             127.799489               23.595296
# min                 0.400000              76.200000               70.800000
# 25%                 0.900000             134.850000              101.350000
# 50%                 1.100000             186.900000              118.000000
# 75%                 1.800000             282.200000              124.950000
# max                 3.300000             723.500000              206.200000

# %%
# Bin SAIFI (Average Interruption Frequency Index) w/ Major Events based on industry standards
conditions_saifi = [
    reliability['SAIFI w/ Major Events'] > 2.0,  # Poor reliability: More than 2 interruptions per year
    (reliability['SAIFI w/ Major Events'] >= 1.0) & (reliability['SAIFI w/ Major Events'] <= 2.0),  # Average reliability: 1-2 interruptions
    reliability['SAIFI w/ Major Events'] < 1.0  # Good reliability: Less than 1 interruption per year
]
choices_saifi = ['High', 'Moderate', 'Low']
reliability['SAIFI Major Events'] = np.select(conditions_saifi, choices_saifi, default='Unknown')

# %%
reliability.head()
# Out:
#   State  SAIFI w/ Major Events  CAIDI w/ Major Events  CAIDI w/o Major Events  \
# 0    CT                    0.9                  188.8                   107.3
# 1    ME                    3.3                  562.2                   125.0
# 2    MA                    1.1                  245.4                   105.4
# 3    NH                    1.8                  368.5                   126.1
# 4    RI                    0.8                  133.7                    78.3
#
#   SAIFI Major Events
# 0                Low
# 1               High
# 2           Moderate
# 3           Moderate
# 4                Low

# %%
reliability = reliability.drop(columns=['SAIFI w/ Major Events'])
reliability.head()
# Out:
#   State  CAIDI w/ Major Events  CAIDI w/o Major Events SAIFI Major Events
# 0    CT                  188.8                   107.3                Low
# 1    ME                  562.2                   125.0               High
# 2    MA                  245.4                   105.4           Moderate
# 3    NH                  368.5                   126.1           Moderate
# 4    RI                  133.7                    78.3                Low

# %%
# Count duplicates of State
reliability['State'].value_counts().sum()
# Out:
# 51

# %%
# Conduct an outer join on the State column
net_gen_reliability = pd.merge(net_gen, reliability, on='State', how='outer')

net_gen_reliability.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AR                   NaN                      NaN
# 3    AZ                  High                     High
# 4    CA                  High                     High
#
#   Commercial_Generation_Rank Capacity_Growth_Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                        NaN                    NaN                  433.4
# 3                   Moderate                Growing                  108.6
# 4                       High              Shrinking                  248.1
#
#    CAIDI w/o Major Events SAIFI Major Events
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   144.0               High
# 3                    84.8           Moderate
# 4                   140.0           Moderate

# %%
net_gen_reliability.isna().value_counts()
# Out:
# State  Total_Generation_Rank  Electric_Generation_Rank  Commercial_Generation_Rank  Capacity_Growth_Status  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIFI Major Events
# False  False                  False                     False                       False                   False                  False                   False                 39
#        True                   True                      True                        True                    False                  False                   False                 12
# Name: count, dtype: int64

# %%
net_gen_reliability.fillna('Unknown', inplace=True)
net_gen_reliability.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AR               Unknown                  Unknown
# 3    AZ                  High                     High
# 4    CA                  High                     High
#
#   Commercial_Generation_Rank Capacity_Growth_Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                    Unknown                Unknown                  433.4
# 3                   Moderate                Growing                  108.6
# 4                       High              Shrinking                  248.1
#
#    CAIDI w/o Major Events SAIFI Major Events
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   144.0               High
# 3                    84.8           Moderate
# 4                   140.0           Moderate

# %% [markdown]
# ## Load in the Energy Efficiency data

# %%
energy_efficiency = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Efficiency.csv', index_col=0)

energy_efficiency.head()
# Out:
#    Utility Number               Utility Name State BA Code  \
# 2             195           Alabama Power Co    AL    SOCO
# 3             207    Alameda Municipal Power    CA    CISO
# 4             295  City of Alexandria - (MN)    MN    MISO
# 5             554        City of Ames - (IA)    IA    MISO
# 6             590     City of Anaheim - (CA)    CA    CISO
#
#    Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# 2                      5767.0                                   11.9
# 3                       146.0                                    0.1
# 4                      3306.0                                    0.7
# 5                       189.0                                    0.1
# 6                      7242.0                                    1.5
#
#    Total Annual Incent Cost (Thousand $)  \
# 2                                 1225.0
# 3                                   70.0
# 4                                  187.0
# 5                                  197.0
# 6                                 3338.0
#
#    Total Non-Incentive Annual Costs (Thousand $)  \
# 2                                         1095.0
# 3                                          321.0
# 4                                          194.0
# 5                                           54.0
# 6                                          804.0
#
#    Commercial Weighted Avg Life (Yrs)
# 2                               5.000
# 3                              13.269
# 4                              12.727
# 5                              10.000
# 6                              11.437

# %%
energy_efficiency.columns
# Out:
# Index(['Utility Number', 'Utility Name', 'State', 'BA Code',
#        'Total Annual Savings (MWh)', 'Total Peak Demand Annual Savings (MW)',
#        'Total Annual Incent Cost (Thousand $)',
#        'Total Non-Incentive Annual Costs (Thousand $)',
#        'Commercial Weighted Avg Life (Yrs)'],
#       dtype='object')

# %%
energy_efficiency.corr(numeric_only=True)
# Out:
#                                                Utility Number  \
# Utility Number                                       1.000000
# Total Annual Savings (MWh)                           0.021878
# Total Peak Demand Annual Savings (MW)                0.025283
# Total Annual Incent Cost (Thousand $)                0.148453
# Total Non-Incentive Annual Costs (Thousand $)        0.083285
# Commercial Weighted Avg Life (Yrs)                   0.001019
#
#                                                Total Annual Savings (MWh)  \
# Utility Number                                                   0.021878
# Total Annual Savings (MWh)                                       1.000000
# Total Peak Demand Annual Savings (MW)                            0.473292
# Total Annual Incent Cost (Thousand $)                            0.639695
# Total Non-Incentive Annual Costs (Thousand $)                    0.812012
# Commercial Weighted Avg Life (Yrs)                               0.112121
#
#                                                Total Peak Demand Annual Savings (MW)  \
# Utility Number                                                              0.025283
# Total Annual Savings (MWh)                                                  0.473292
# Total Peak Demand Annual Savings (MW)                                       1.000000
# Total Annual Incent Cost (Thousand $)                                       0.278101
# Total Non-Incentive Annual Costs (Thousand $)                               0.402326
# Commercial Weighted Avg Life (Yrs)                                          0.037236
#
#                                                Total Annual Incent Cost (Thousand $)  \
# Utility Number                                                              0.148453
# Total Annual Savings (MWh)                                                  0.639695
# Total Peak Demand Annual Savings (MW)                                       0.278101
# Total Annual Incent Cost (Thousand $)                                       1.000000
# Total Non-Incentive Annual Costs (Thousand $)                               0.600819
# Commercial Weighted Avg Life (Yrs)                                          0.024366
#
#                                                Total Non-Incentive Annual Costs (Thousand $)  \
# Utility Number                                                                      0.083285
# Total Annual Savings (MWh)                                                          0.812012
# Total Peak Demand Annual Savings (MW)                                               0.402326
# Total Annual Incent Cost (Thousand $)                                               0.600819
# Total Non-Incentive Annual Costs (Thousand $)                                       1.000000
# Commercial Weighted Avg Life (Yrs)                                                  0.018572
#
#                                                Commercial Weighted Avg Life (Yrs)
# Utility Number                                                           0.001019
# Total Annual Savings (MWh)                                               0.112121
# Total Peak Demand Annual Savings (MW)                                    0.037236
# Total Annual Incent Cost (Thousand $)                                    0.024366
# Total Non-Incentive Annual Costs (Thousand $)                            0.018572
# Commercial Weighted Avg Life (Yrs)                                       1.000000

# %%
# Drop the year and Utility number columns
energy_efficiency = energy_efficiency.drop(columns=['Utility Number', 'Utility Name','Total Non-Incentive Annual Costs (Thousand $)', 'BA Code'])

energy_efficiency.head()
# Out:
#   State  Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# 2    AL                      5767.0                                   11.9
# 3    CA                       146.0                                    0.1
# 4    MN                      3306.0                                    0.7
# 5    IA                       189.0                                    0.1
# 6    CA                      7242.0                                    1.5
#
#    Total Annual Incent Cost (Thousand $)  Commercial Weighted Avg Life (Yrs)
# 2                                 1225.0                               5.000
# 3                                   70.0                              13.269
# 4                                  187.0                              12.727
# 5                                  197.0                              10.000
# 6                                 3338.0                              11.437

# %%
energy_efficiency.describe()
# Out:
#        Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# count                3.280000e+02                             328.000000
# mean                 7.298820e+04                              17.305183
# std                  1.879049e+05                              62.953090
# min                  1.200000e+01                               0.000000
# 25%                  1.214500e+03                               0.200000
# 50%                  5.769500e+03                               1.500000
# 75%                  5.768900e+04                              11.450000
# max                  1.718664e+06                             945.000000
#
#        Total Annual Incent Cost (Thousand $)  \
# count                             328.000000
# mean                            11393.076220
# std                             32636.461121
# min                                 0.000000
# 25%                               190.250000
# 50%                              1109.000000
# 75%                              7041.750000
# max                            372401.000000
#
#        Commercial Weighted Avg Life (Yrs)
# count                          328.000000
# mean                            12.505122
# std                              4.285681
# min                              0.000000
# 25%                             11.000000
# 50%                             12.700000
# 75%                             14.312500
# max                             27.525000

# %% [markdown]
# ** Note that MW measures power capacity while MWh measures the amount of electricity delivered overtime

# %%
# Bin Total Annual Savings (MWh) based on DOE program size classifications
conditions_savings = [
    energy_efficiency['Total Annual Savings (MWh)'] >= 100000,  # Large utility programs (>100 GWh)
    (energy_efficiency['Total Annual Savings (MWh)'] >= 25000) & 
    (energy_efficiency['Total Annual Savings (MWh)'] < 100000),  # Medium programs (25-100 GWh)
    energy_efficiency['Total Annual Savings (MWh)'] < 25000  # Small programs (<25 GWh)
]
choices_savings = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Annual Energy Savings (MWh)'] = np.select(conditions_savings, choices_savings, default='Unknown')

# Bin Peak Demand Savings based on utility demand response program standards
conditions_peak = [
    energy_efficiency['Total Peak Demand Annual Savings (MW)'] >= 50,  # Large DR programs (>50 MW)
    (energy_efficiency['Total Peak Demand Annual Savings (MW)'] >= 10) & 
    (energy_efficiency['Total Peak Demand Annual Savings (MW)'] < 50),  # Medium DR programs (10-50 MW)
    energy_efficiency['Total Peak Demand Annual Savings (MW)'] < 10  # Small DR programs (<10 MW)
]
choices_peak = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Peak Demand Savings (MW)'] = np.select(conditions_peak, choices_peak, default='Unknown')

# %%
energy_efficiency.describe()
# Out:
#        Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# count                3.280000e+02                             328.000000
# mean                 7.298820e+04                              17.305183
# std                  1.879049e+05                              62.953090
# min                  1.200000e+01                               0.000000
# 25%                  1.214500e+03                               0.200000
# 50%                  5.769500e+03                               1.500000
# 75%                  5.768900e+04                              11.450000
# max                  1.718664e+06                             945.000000
#
#        Total Annual Incent Cost (Thousand $)  \
# count                             328.000000
# mean                            11393.076220
# std                             32636.461121
# min                                 0.000000
# 25%                               190.250000
# 50%                              1109.000000
# 75%                              7041.750000
# max                            372401.000000
#
#        Commercial Weighted Avg Life (Yrs)
# count                          328.000000
# mean                            12.505122
# std                              4.285681
# min                              0.000000
# 25%                             11.000000
# 50%                             12.700000
# 75%                             14.312500
# max                             27.525000

# %%
# Bin Total Annual Incent Cost using fixed thresholds (in thousands of dollars)
conditions_incent = [
    energy_efficiency['Total Annual Incent Cost (Thousand $)'] >= 10000,  # Very large programs (>$10M)
    (energy_efficiency['Total Annual Incent Cost (Thousand $)'] >= 2000) & 
    (energy_efficiency['Total Annual Incent Cost (Thousand $)'] < 10000),  # Mid-size programs ($2-10M) 
    energy_efficiency['Total Annual Incent Cost (Thousand $)'] < 2000  # Smaller programs (<$2M)
]
choices_incent = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Annual Incentive Cost'] = np.select(conditions_incent, choices_incent, default='Unknown')

# Bin Commercial Weighted Avg Life using fixed thresholds (in years)
conditions_life = [
    energy_efficiency['Commercial Weighted Avg Life (Yrs)'] >= 20,  # Long-life equipment (HVAC, building shell)
    (energy_efficiency['Commercial Weighted Avg Life (Yrs)'] >= 12) & 
    (energy_efficiency['Commercial Weighted Avg Life (Yrs)'] < 20),  # Medium-life equipment (lighting, motors)
    energy_efficiency['Commercial Weighted Avg Life (Yrs)'] < 12  # Short-life equipment (controls, maintenance)
]
choices_life = ['High', 'Moderate', 'Low']
energy_efficiency['Overall Commercial Avg Life (Yrs)'] = np.select(conditions_life, choices_life, default='Unknown')

# %%
energy_efficiency.head()
# Out:
#   State  Total Annual Savings (MWh)  Total Peak Demand Annual Savings (MW)  \
# 2    AL                      5767.0                                   11.9
# 3    CA                       146.0                                    0.1
# 4    MN                      3306.0                                    0.7
# 5    IA                       189.0                                    0.1
# 6    CA                      7242.0                                    1.5
#
#    Total Annual Incent Cost (Thousand $)  Commercial Weighted Avg Life (Yrs)  \
# 2                                 1225.0                               5.000
# 3                                   70.0                              13.269
# 4                                  187.0                              12.727
# 5                                  197.0                              10.000
# 6                                 3338.0                              11.437
#
#   Overall Annual Energy Savings (MWh) Overall Peak Demand Savings (MW)  \
# 2                                 Low                         Moderate
# 3                                 Low                              Low
# 4                                 Low                              Low
# 5                                 Low                              Low
# 6                                 Low                              Low
#
#   Overall Annual Incentive Cost Overall Commercial Avg Life (Yrs)
# 2                           Low                               Low
# 3                           Low                          Moderate
# 4                           Low                          Moderate
# 5                           Low                               Low
# 6                      Moderate                               Low

# %%
# Keep only relevant columns
energy_efficiency_clean = energy_efficiency[['State', 'Overall Annual Energy Savings (MWh)',
                                            'Overall Peak Demand Savings (MW)', 'Overall Annual Incentive Cost', 'Overall Commercial Avg Life (Yrs)']]

energy_efficiency_clean.head()
# Out:
#   State Overall Annual Energy Savings (MWh) Overall Peak Demand Savings (MW)  \
# 2    AL                                 Low                         Moderate
# 3    CA                                 Low                              Low
# 4    MN                                 Low                              Low
# 5    IA                                 Low                              Low
# 6    CA                                 Low                              Low
#
#   Overall Annual Incentive Cost Overall Commercial Avg Life (Yrs)
# 2                           Low                               Low
# 3                           Low                          Moderate
# 4                           Low                          Moderate
# 5                           Low                               Low
# 6                      Moderate                               Low

# %%
# Rename columns for more clarity
energy_efficiency_clean = energy_efficiency_clean.rename(columns={'Overall Annual Energy Savings (MWh)': 'Utility Annual Energy Savings (MWh)',
                                                                  'Overall Peak Demand Savings (MW)':'Utility Peak Demand Savings (MW)',
                                                                  'Overall Annual Incentive Cost': 'Utility Annual Incentive Cost ($)',
                                                                  'Overall Commercial Avg Life (Yrs)': 'Utility Commercial Avg Life (Yrs)'})
energy_efficiency_clean.head()
# Out:
#   State Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 2    AL                                 Low                         Moderate
# 3    CA                                 Low                              Low
# 4    MN                                 Low                              Low
# 5    IA                                 Low                              Low
# 6    CA                                 Low                              Low
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)
# 2                               Low                               Low
# 3                               Low                          Moderate
# 4                               Low                          Moderate
# 5                               Low                               Low
# 6                          Moderate                               Low

# %%
energy_efficiency_clean.isna().value_counts()
# Out:
# State  Utility Annual Energy Savings (MWh)  Utility Peak Demand Savings (MW)  Utility Annual Incentive Cost ($)  Utility Commercial Avg Life (Yrs)
# False  False                                False                             False                              False                                328
# Name: count, dtype: int64

# %%
len(energy_efficiency_clean['State'].value_counts())
# Out:
# 48

# %%
# Merge net_gen_reliability and energy_efficiency on the State column
merged_2 = pd.merge(net_gen_reliability, energy_efficiency_clean, on='State', how='outer')

merged_2.head()
# Out:
#   State Total_Generation_Rank Electric_Generation_Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AL                  High                     High
# 3    AR               Unknown                  Unknown
# 4    AR               Unknown                  Unknown
#
#   Commercial_Generation_Rank Capacity_Growth_Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                        Low                Growing                  186.9
# 3                    Unknown                Unknown                  433.4
# 4                    Unknown                Unknown                  433.4
#
#    CAIDI w/o Major Events SAIFI Major Events  \
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   122.8           Moderate
# 3                   144.0               High
# 4                   144.0               High
#
#   Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                                 NaN                              NaN
# 1                                 Low                         Moderate
# 2                                 Low                              Low
# 3                                High                         Moderate
# 4                            Moderate                              Low
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)
# 0                               NaN                               NaN
# 1                               Low                               Low
# 2                               Low                          Moderate
# 3                              High                          Moderate
# 4                          Moderate                          Moderate

# %%
merged_2.rename(columns={'Total_Generation_Rank': 'Total Generation Rank', 'Electric_Generation_Rank': 'Electric Generation Rank', 
                         'Commercial_Generation_Rank': 'Commercial Generation Rank','Capacity_Growth_Status': 'Capacity Growth Status'}, inplace=True)

# %%
merged_2.isna().value_counts()
# Out:
# State  Total Generation Rank  Electric Generation Rank  Commercial Generation Rank  Capacity Growth Status  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIFI Major Events  Utility Annual Energy Savings (MWh)  Utility Peak Demand Savings (MW)  Utility Annual Incentive Cost ($)  Utility Commercial Avg Life (Yrs)
# False  False                  False                     False                       False                   False                  False                   False               False                                False                             False                              False                                328
#                                                                                                                                                                                True                                 True                              True                               True                                   3
# Name: count, dtype: int64

# %%
merged_2.isin(['Unknown']).sum()
# Out:
# State                                   0
# Total Generation Rank                  52
# Electric Generation Rank               52
# Commercial Generation Rank             52
# Capacity Growth Status                 52
# CAIDI w/ Major Events                   0
# CAIDI w/o Major Events                  0
# SAIFI Major Events                      0
# Utility Annual Energy Savings (MWh)     0
# Utility Peak Demand Savings (MW)        0
# Utility Annual Incentive Cost ($)       0
# Utility Commercial Avg Life (Yrs)       0
# dtype: int64

# %% [markdown]
# ### Loading in the regional Demand data for joining

# %%
demand = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Regional_Demand_2023.csv', index_col=0)
demand.head()
# Out:
#   Region State  Annual_Region_Demand_MWh
# 0    CAL    CA             726482.230137
# 1    CAL    CA             726482.230137
# 2    CAL    CA             726482.230137
# 3    CAL    CA             726482.230137
# 4    CAL    CA             726482.230137

# %%
demand.describe()
# Out:
#        Annual_Region_Demand_MWh
# count              1.679000e+04
# mean               1.029680e+06
# std                6.637723e+05
# min                3.068565e+05
# 25%                5.984282e+05
# 50%                7.698936e+05
# 75%                1.920122e+06
# max                2.150311e+06

# %%
# Bin Annual Region Demand using fixed thresholds (in MWh)
conditions_demand = [
    demand['Annual_Region_Demand_MWh'] >= 1500000,  # Very large regions (>1.5M MWh) like PJM, ERCOT
    (demand['Annual_Region_Demand_MWh'] >= 750000) & 
    (demand['Annual_Region_Demand_MWh'] < 1500000),  # Mid-size regions (750k-1.5M MWh) like NYISO, CAISO
    demand['Annual_Region_Demand_MWh'] < 750000  # Smaller regions (<750k MWh) like ISO-NE, SPP
]
choices_demand = ['High', 'Moderate', 'Low']
demand['Regional Electricity Demand'] = np.select(conditions_demand, choices_demand, default='Unknown')

# %%
demand = demand.drop(columns=['Annual_Region_Demand_MWh'])

# %%
demand.shape
# Out:
# (16790, 3)

# %%
demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16790 entries, 0 to 16789
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       16790 non-null  object
#  1   State                        16790 non-null  object
#  2   Regional Electricity Demand  16790 non-null  object
# dtypes: object(3)
# memory usage: 524.7+ KB

# %%
demand[demand.duplicated(subset=['Region', 'State'])]
# Out:
#       Region State Regional Electricity Demand
# 1        CAL    CA                         Low
# 2        CAL    CA                         Low
# 3        CAL    CA                         Low
# 4        CAL    CA                         Low
# 5        CAL    CA                         Low
# ...      ...   ...                         ...
# 16785    TEX    TX                    Moderate
# 16786    TEX    TX                    Moderate
# 16787    TEX    TX                    Moderate
# 16788    TEX    TX                    Moderate
# 16789    TEX    TX                    Moderate
#
# [16744 rows x 3 columns]

# %%
# Drop duplicates of region and state
demand = demand.drop_duplicates(subset=['Region', 'State'])

# Verify the result
print(demand.shape)
demand.info()
# Out:
# (46, 3)
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 16425
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       46 non-null     object
#  1   State                        46 non-null     object
#  2   Regional Electricity Demand  46 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %%
demand.drop(columns=['Region'], inplace=True)

# %%
# Merge demand with merged 2

merged_3 = pd.merge(merged_2, demand, on='State', how='outer')
merged_3.head()
# Out:
#   State Total Generation Rank Electric Generation Rank  \
# 0    AK                   Low                      Low
# 1    AL                  High                     High
# 2    AL                  High                     High
# 3    AR               Unknown                  Unknown
# 4    AR               Unknown                  Unknown
#
#   Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                        Low                Growing                  186.9
# 3                    Unknown                Unknown                  433.4
# 4                    Unknown                Unknown                  433.4
#
#    CAIDI w/o Major Events SAIFI Major Events  \
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   122.8           Moderate
# 3                   144.0               High
# 4                   144.0               High
#
#   Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                                 NaN                              NaN
# 1                                 Low                         Moderate
# 2                                 Low                              Low
# 3                                High                         Moderate
# 4                            Moderate                              Low
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 0                               NaN                               NaN
# 1                               Low                               Low
# 2                               Low                          Moderate
# 3                              High                          Moderate
# 4                          Moderate                          Moderate
#
#   Regional Electricity Demand
# 0                    Moderate
# 1                         Low
# 2                         Low
# 3                         Low
# 4                         Low

# %%
merged_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                339 non-null    object
#  1   Total Generation Rank                339 non-null    object
#  2   Electric Generation Rank             339 non-null    object
#  3   Commercial Generation Rank           339 non-null    object
#  4   Capacity Growth Status               339 non-null    object
#  5   CAIDI w/ Major Events                339 non-null    float64
#  6   CAIDI w/o Major Events               339 non-null    float64
#  7   SAIFI Major Events                   339 non-null    object
#  8   Utility Annual Energy Savings (MWh)  336 non-null    object
#  9   Utility Peak Demand Savings (MW)     336 non-null    object
#  10  Utility Annual Incentive Cost ($)    336 non-null    object
#  11  Utility Commercial Avg Life (Yrs)    336 non-null    object
#  12  Regional Electricity Demand          315 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 34.6+ KB

# %%
merged_3[merged_3['Regional Electricity Demand'].isna()]
# Out:
#     State Total Generation Rank Electric Generation Rank  \
# 37     CO              Moderate                 Moderate
# 38     CO              Moderate                 Moderate
# 39     CO              Moderate                 Moderate
# 40     CO              Moderate                 Moderate
# 41     CO              Moderate                 Moderate
# 42     CO              Moderate                 Moderate
# 43     CO              Moderate                 Moderate
# 44     CO              Moderate                 Moderate
# 45     CO              Moderate                 Moderate
# 46     CO              Moderate                 Moderate
# 47     CO              Moderate                 Moderate
# 48     CO              Moderate                 Moderate
# 49     CO              Moderate                 Moderate
# 77     HI                   Low                      Low
# 78     HI                   Low                      Low
# 111    KY               Unknown                  Unknown
# 112    KY               Unknown                  Unknown
# 113    KY               Unknown                  Unknown
# 114    KY               Unknown                  Unknown
# 115    KY               Unknown                  Unknown
# 194    MT               Unknown                  Unknown
# 195    MT               Unknown                  Unknown
# 288    TN              Moderate                 Moderate
# 335    WV              Moderate                 Moderate
#
#     Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 37                         Low              Shrinking                  108.3
# 38                         Low              Shrinking                  108.3
# 39                         Low              Shrinking                  108.3
# 40                         Low              Shrinking                  108.3
# 41                         Low              Shrinking                  108.3
# 42                         Low              Shrinking                  108.3
# 43                         Low              Shrinking                  108.3
# 44                         Low              Shrinking                  108.3
# 45                         Low              Shrinking                  108.3
# 46                         Low              Shrinking                  108.3
# 47                         Low              Shrinking                  108.3
# 48                         Low              Shrinking                  108.3
# 49                         Low              Shrinking                  108.3
# 77                        High                Growing                  275.1
# 78                        High                Growing                  275.1
# 111                    Unknown                Unknown                  456.3
# 112                    Unknown                Unknown                  456.3
# 113                    Unknown                Unknown                  456.3
# 114                    Unknown                Unknown                  456.3
# 115                    Unknown                Unknown                  456.3
# 194                    Unknown                Unknown                  111.1
# 195                    Unknown                Unknown                  111.1
# 288                   Moderate              Shrinking                  305.1
# 335                        Low                Growing                  319.4
#
#      CAIDI w/o Major Events SAIFI Major Events  \
# 37                    102.2                Low
# 38                    102.2                Low
# 39                    102.2                Low
# 40                    102.2                Low
# 41                    102.2                Low
# 42                    102.2                Low
# 43                    102.2                Low
# 44                    102.2                Low
# 45                    102.2                Low
# 46                    102.2                Low
# 47                    102.2                Low
# 48                    102.2                Low
# 49                    102.2                Low
# 77                    106.3           Moderate
# 78                    106.3           Moderate
# 111                   122.9           Moderate
# 112                   122.9           Moderate
# 113                   122.9           Moderate
# 114                   122.9           Moderate
# 115                   122.9           Moderate
# 194                   111.0           Moderate
# 195                   111.0           Moderate
# 288                    98.1               High
# 335                   206.2               High
#
#     Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 37                                  Low                              Low
# 38                                  Low                              Low
# 39                             Moderate                              Low
# 40                                  Low                              Low
# 41                                  Low                              Low
# 42                                  Low                              Low
# 43                                  Low                              Low
# 44                                  Low                              Low
# 45                                  Low                              Low
# 46                                  Low                              Low
# 47                                 High                             High
# 48                                  Low                              Low
# 49                                  Low                              Low
# 77                                  Low                              Low
# 78                             Moderate                              Low
# 111                                 Low                              Low
# 112                                 Low                              Low
# 113                            Moderate                              Low
# 114                                 Low                              Low
# 115                                 Low                              Low
# 194                                 Low                              Low
# 195                            Moderate                              Low
# 288                            Moderate                         Moderate
# 335                                 NaN                              NaN
#
#     Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 37                                Low                          Moderate
# 38                                Low                          Moderate
# 39                           Moderate                               Low
# 40                                Low                          Moderate
# 41                                Low                          Moderate
# 42                                Low                          Moderate
# 43                                Low                          Moderate
# 44                                Low                          Moderate
# 45                                Low                          Moderate
# 46                                Low                          Moderate
# 47                               High                              High
# 48                                Low                               Low
# 49                           Moderate                          Moderate
# 77                                Low                          Moderate
# 78                               High                          Moderate
# 111                               Low                               Low
# 112                               Low                              High
# 113                               Low                              High
# 114                               Low                               Low
# 115                               Low                          Moderate
# 194                               Low                          Moderate
# 195                          Moderate                          Moderate
# 288                          Moderate                          Moderate
# 335                               NaN                               NaN
#
#     Regional Electricity Demand
# 37                          NaN
# 38                          NaN
# 39                          NaN
# 40                          NaN
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                          NaN
# 77                          NaN
# 78                          NaN
# 111                         NaN
# 112                         NaN
# 113                         NaN
# 114                         NaN
# 115                         NaN
# 194                         NaN
# 195                         NaN
# 288                         NaN
# 335                         NaN

# %%
merged_3['Regional Electricity Demand'].fillna('Unknown', inplace=True)
merged_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                339 non-null    object
#  1   Total Generation Rank                339 non-null    object
#  2   Electric Generation Rank             339 non-null    object
#  3   Commercial Generation Rank           339 non-null    object
#  4   Capacity Growth Status               339 non-null    object
#  5   CAIDI w/ Major Events                339 non-null    float64
#  6   CAIDI w/o Major Events               339 non-null    float64
#  7   SAIFI Major Events                   339 non-null    object
#  8   Utility Annual Energy Savings (MWh)  336 non-null    object
#  9   Utility Peak Demand Savings (MW)     336 non-null    object
#  10  Utility Annual Incentive Cost ($)    336 non-null    object
#  11  Utility Commercial Avg Life (Yrs)    336 non-null    object
#  12  Regional Electricity Demand          339 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 34.6+ KB
# /var/folders/rj/3yvmqxnj3d17zpgh8wpywxvr0000gn/T/ipykernel_11476/1737813523.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_3['Regional Electricity Demand'].fillna('Unknown', inplace=True)

# %%
merged_3.fillna('Unknown', inplace=True)
merged_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                339 non-null    object
#  1   Total Generation Rank                339 non-null    object
#  2   Electric Generation Rank             339 non-null    object
#  3   Commercial Generation Rank           339 non-null    object
#  4   Capacity Growth Status               339 non-null    object
#  5   CAIDI w/ Major Events                339 non-null    float64
#  6   CAIDI w/o Major Events               339 non-null    float64
#  7   SAIFI Major Events                   339 non-null    object
#  8   Utility Annual Energy Savings (MWh)  339 non-null    object
#  9   Utility Peak Demand Savings (MW)     339 non-null    object
#  10  Utility Annual Incentive Cost ($)    339 non-null    object
#  11  Utility Commercial Avg Life (Yrs)    339 non-null    object
#  12  Regional Electricity Demand          339 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 34.6+ KB

# %%
ixp = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_IXP.csv', index_col=0)
ixp.head()
# Out:
#                                  IXP Name         City State
# 0                                   48 IX      Phoenix    AZ
# 1                                   ABQIX  Albuquerque    NM
# 2                                AlaskaIX    Anchorage    AK
# 3  Amateur Radio Internet Exchange - ARIX      Fremont    CA
# 4  Amateur Radio Internet Exchange - ARIX     Portland    OR

# %%
ixp.isna().value_counts()
# Out:
# IXP Name  City   State
# False     False  False    196
#                  True       3
# Name: count, dtype: int64

# %%
ixp[ixp['State'].isna()]
# Out:
#                                              IXP Name           City State
# 21  BroadBand Internet Exchange US-West - BBIX US-...     West Coast   NaN
# 32                                CoreSite - Any2East  Washington DC   NaN
# 74  Equinix Internet Exchange Seattle - Equinix Se...        Seattle   NaN

# %%
ixp.loc[(ixp['City'] == 'Seattle') & (ixp['State'] == 'Washington'), 'City'] = 'Washington'

# %%
# Fix Seattle, Washington data
ixp.loc[ixp['City'] == 'Seattle', 'State'] = 'WA'

# Fix Washington DC data
ixp.loc[ixp['City'] == 'Washington DC', ['City', 'State']] = ['Washington', 'DC']

#Drop rows where City is West Coast
ixp = ixp[ixp['City'] != 'West Coast']

# %%
ixp[ixp['City'] == 'Seattle']
# Out:
#                                               IXP Name     City State
# 74   Equinix Internet Exchange Seattle - Equinix Se...  Seattle    WA
# 123                            Megaport MegaIX Seattle  Seattle    WA
# 132        Moe Internet Exchange - Seattle - MoeIX SEA  Seattle    WA
# 160                        Pacific Wave Exchange in LA  Seattle    WA
# 171  Seattle Internet Exchange (MTU 1500) - SIX Sea...  Seattle    WA
# 172  Seattle Internet Exchange (MTU 9000) - SIX Sea...  Seattle    WA

# %%
ixp[ixp['City'] == 'Washington']
# Out:
#                 IXP Name        City State
# 32   CoreSite - Any2East  Washington    DC
# 85  Global Peer Exchange  Washington    DC

# %%
len(ixp['State'].value_counts())
# Out:
# 42

# %%
len(ixp['City'].value_counts())
# Out:
# 92

# %%
ixp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 198 entries, 0 to 198
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IXP Name  198 non-null    object
#  1   City      198 non-null    object
#  2   State     198 non-null    object
# dtypes: object(3)
# memory usage: 6.2+ KB

# %%
# Merge ixp data
merged_4 = pd.merge(merged_3, ixp, on='State', how='outer')

merged_4.isna().value_counts()
# Out:
# State  Total Generation Rank  Electric Generation Rank  Commercial Generation Rank  Capacity Growth Status  CAIDI w/ Major Events  CAIDI w/o Major Events  SAIFI Major Events  Utility Annual Energy Savings (MWh)  Utility Peak Demand Savings (MW)  Utility Annual Incentive Cost ($)  Utility Commercial Avg Life (Yrs)  Regional Electricity Demand  IXP Name  City
# False  False                  False                     False                       False                   False                  False                   False               False                                False                             False                              False                              False                        False     False    2251
#                                                                                                                                                                                                                                                                                                                                                          True      True       39
#        True                   True                      True                        True                    True                   True                    True                True                                 True                              True                               True                               True                         False     False       1
# Name: count, dtype: int64

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2291 non-null   object
#  1   Total Generation Rank                2290 non-null   object
#  2   Electric Generation Rank             2290 non-null   object
#  3   Commercial Generation Rank           2290 non-null   object
#  4   Capacity Growth Status               2290 non-null   object
#  5   CAIDI w/ Major Events                2290 non-null   float64
#  6   CAIDI w/o Major Events               2290 non-null   float64
#  7   SAIFI Major Events                   2290 non-null   object
#  8   Utility Annual Energy Savings (MWh)  2290 non-null   object
#  9   Utility Peak Demand Savings (MW)     2290 non-null   object
#  10  Utility Annual Incentive Cost ($)    2290 non-null   object
#  11  Utility Commercial Avg Life (Yrs)    2290 non-null   object
#  12  Regional Electricity Demand          2290 non-null   object
#  13  IXP Name                             2252 non-null   object
#  14  City                                 2252 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 268.6+ KB

# %%
merged_4[merged_4['City'].isna()]
# Out:
#      State Total Generation Rank Electric Generation Rank  \
# 5       AR               Unknown                  Unknown
# 6       AR               Unknown                  Unknown
# 7       AR               Unknown                  Unknown
# 903     DE               Unknown                  Unknown
# 904     DE               Unknown                  Unknown
# 1129    ID                   Low                 Moderate
# 1130    ID                   Low                 Moderate
# 1131    ID                   Low                 Moderate
# 1132    ID                   Low                 Moderate
# 1133    ID                   Low                 Moderate
# 1134    ID                   Low                 Moderate
# 1204    LA               Unknown                  Unknown
# 1205    LA               Unknown                  Unknown
# 1206    LA               Unknown                  Unknown
# 1207    LA               Unknown                  Unknown
# 1446    MS              Moderate                     High
# 1447    MS              Moderate                     High
# 1448    MS              Moderate                     High
# 1449    MS              Moderate                     High
# 1499    NH               Unknown                  Unknown
# 1500    NH               Unknown                  Unknown
# 1501    NH               Unknown                  Unknown
# 1502    NH               Unknown                  Unknown
# 1791    RI                   Low                      Low
# 1792    RI                   Low                      Low
# 1793    SC              Moderate                     High
# 1794    SC              Moderate                     High
# 1795    SC              Moderate                     High
# 1796    SC              Moderate                     High
# 1797    SC              Moderate                     High
# 1798    SD               Unknown                  Unknown
# 1799    SD               Unknown                  Unknown
# 1800    SD               Unknown                  Unknown
# 1801    SD               Unknown                  Unknown
# 1802    SD               Unknown                  Unknown
# 1803    SD               Unknown                  Unknown
# 2288    WY                   Low                 Moderate
# 2289    WY                   Low                 Moderate
# 2290    WY                   Low                 Moderate
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 5                       Unknown                Unknown                  433.4
# 6                       Unknown                Unknown                  433.4
# 7                       Unknown                Unknown                  433.4
# 903                     Unknown                Unknown                  130.3
# 904                     Unknown                Unknown                  130.3
# 1129                        Low              Shrinking                  128.4
# 1130                        Low              Shrinking                  128.4
# 1131                        Low              Shrinking                  128.4
# 1132                        Low              Shrinking                  128.4
# 1133                        Low              Shrinking                  128.4
# 1134                        Low              Shrinking                  128.4
# 1204                    Unknown                Unknown                  275.1
# 1205                    Unknown                Unknown                  275.1
# 1206                    Unknown                Unknown                  275.1
# 1207                    Unknown                Unknown                  275.1
# 1446                        Low              Shrinking                  295.2
# 1447                        Low              Shrinking                  295.2
# 1448                        Low              Shrinking                  295.2
# 1449                        Low              Shrinking                  295.2
# 1499                    Unknown                Unknown                  368.5
# 1500                    Unknown                Unknown                  368.5
# 1501                    Unknown                Unknown                  368.5
# 1502                    Unknown                Unknown                  368.5
# 1791                        Low              Shrinking                  133.7
# 1792                        Low              Shrinking                  133.7
# 1793                        Low              Shrinking                  110.9
# 1794                        Low              Shrinking                  110.9
# 1795                        Low              Shrinking                  110.9
# 1796                        Low              Shrinking                  110.9
# 1797                        Low              Shrinking                  110.9
# 1798                    Unknown                Unknown                   76.2
# 1799                    Unknown                Unknown                   76.2
# 1800                    Unknown                Unknown                   76.2
# 1801                    Unknown                Unknown                   76.2
# 1802                    Unknown                Unknown                   76.2
# 1803                    Unknown                Unknown                   76.2
# 2288                        Low              Shrinking                  127.8
# 2289                        Low              Shrinking                  127.8
# 2290                        Low              Shrinking                  127.8
#
#       CAIDI w/o Major Events SAIFI Major Events  \
# 5                      144.0               High
# 6                      144.0               High
# 7                      144.0               High
# 903                     87.3                Low
# 904                     87.3                Low
# 1129                   121.2           Moderate
# 1130                   121.2           Moderate
# 1131                   121.2           Moderate
# 1132                   121.2           Moderate
# 1133                   121.2           Moderate
# 1134                   121.2           Moderate
# 1204                   118.8               High
# 1205                   118.8               High
# 1206                   118.8               High
# 1207                   118.8               High
# 1446                   118.0               High
# 1447                   118.0               High
# 1448                   118.0               High
# 1449                   118.0               High
# 1499                   126.1           Moderate
# 1500                   126.1           Moderate
# 1501                   126.1           Moderate
# 1502                   126.1           Moderate
# 1791                    78.3                Low
# 1792                    78.3                Low
# 1793                    97.7           Moderate
# 1794                    97.7           Moderate
# 1795                    97.7           Moderate
# 1796                    97.7           Moderate
# 1797                    97.7           Moderate
# 1798                    70.8           Moderate
# 1799                    70.8           Moderate
# 1800                    70.8           Moderate
# 1801                    70.8           Moderate
# 1802                    70.8           Moderate
# 1803                    70.8           Moderate
# 2288                   124.7           Moderate
# 2289                   124.7           Moderate
# 2290                   124.7           Moderate
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 5                                   High                         Moderate
# 6                               Moderate                              Low
# 7                               Moderate                         Moderate
# 903                                  Low                         Moderate
# 904                                  Low                              Low
# 1129                                 Low                              Low
# 1130                                 Low                              Low
# 1131                                High                         Moderate
# 1132                                 Low                              Low
# 1133                                 Low                              Low
# 1134                                 Low                             High
# 1204                            Moderate                              Low
# 1205                            Moderate                         Moderate
# 1206                            Moderate                         Moderate
# 1207                                 Low                              Low
# 1446                                 Low                              Low
# 1447                            Moderate                         Moderate
# 1448                            Moderate                              Low
# 1449                                 Low                              Low
# 1499                                 Low                              Low
# 1500                            Moderate                              Low
# 1501                                 Low                              Low
# 1502                                 Low                              Low
# 1791                                High                         Moderate
# 1792                                 Low                              Low
# 1793                                 Low                              Low
# 1794                            Moderate                         Moderate
# 1795                                High                         Moderate
# 1796                                High                         Moderate
# 1797                                 Low                              Low
# 1798                                 Low                              Low
# 1799                                 Low                              Low
# 1800                                 Low                              Low
# 1801                                 Low                              Low
# 1802                                 Low                              Low
# 1803                                 Low                              Low
# 2288                                 Low                              Low
# 2289                                 Low                              Low
# 2290                            Moderate                              Low
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 5                                 High                          Moderate
# 6                             Moderate                          Moderate
# 7                             Moderate                          Moderate
# 903                                Low                               Low
# 904                                Low                          Moderate
# 1129                               Low                               Low
# 1130                               Low                               Low
# 1131                              High                          Moderate
# 1132                               Low                          Moderate
# 1133                               Low                          Moderate
# 1134                          Moderate                               Low
# 1204                          Moderate                          Moderate
# 1205                          Moderate                          Moderate
# 1206                          Moderate                          Moderate
# 1207                          Moderate                              High
# 1446                               Low                          Moderate
# 1447                              High                          Moderate
# 1448                          Moderate                               Low
# 1449                               Low                          Moderate
# 1499                          Moderate                               Low
# 1500                              High                               Low
# 1501                          Moderate                               Low
# 1502                          Moderate                               Low
# 1791                              High                               Low
# 1792                               Low                          Moderate
# 1793                               Low                               Low
# 1794                          Moderate                          Moderate
# 1795                              High                               Low
# 1796                              High                          Moderate
# 1797                               Low                               Low
# 1798                               Low                          Moderate
# 1799                               Low                          Moderate
# 1800                               Low                          Moderate
# 1801                               Low                              High
# 1802                               Low                          Moderate
# 1803                               Low                          Moderate
# 2288                               Low                          Moderate
# 2289                               Low                          Moderate
# 2290                          Moderate                          Moderate
#
#      Regional Electricity Demand IXP Name City
# 5                            Low      NaN  NaN
# 6                            Low      NaN  NaN
# 7                            Low      NaN  NaN
# 903                         High      NaN  NaN
# 904                         High      NaN  NaN
# 1129                    Moderate      NaN  NaN
# 1130                    Moderate      NaN  NaN
# 1131                    Moderate      NaN  NaN
# 1132                    Moderate      NaN  NaN
# 1133                    Moderate      NaN  NaN
# 1134                    Moderate      NaN  NaN
# 1204                         Low      NaN  NaN
# 1205                         Low      NaN  NaN
# 1206                         Low      NaN  NaN
# 1207                         Low      NaN  NaN
# 1446                         Low      NaN  NaN
# 1447                         Low      NaN  NaN
# 1448                         Low      NaN  NaN
# 1449                         Low      NaN  NaN
# 1499                         Low      NaN  NaN
# 1500                         Low      NaN  NaN
# 1501                         Low      NaN  NaN
# 1502                         Low      NaN  NaN
# 1791                         Low      NaN  NaN
# 1792                         Low      NaN  NaN
# 1793                         Low      NaN  NaN
# 1794                         Low      NaN  NaN
# 1795                         Low      NaN  NaN
# 1796                         Low      NaN  NaN
# 1797                         Low      NaN  NaN
# 1798                    Moderate      NaN  NaN
# 1799                    Moderate      NaN  NaN
# 1800                    Moderate      NaN  NaN
# 1801                    Moderate      NaN  NaN
# 1802                    Moderate      NaN  NaN
# 1803                    Moderate      NaN  NaN
# 2288                    Moderate      NaN  NaN
# 2289                    Moderate      NaN  NaN
# 2290                    Moderate      NaN  NaN

# %%
merged_4['IXP Name'] = merged_4['IXP Name'].fillna('No IXP')

# %%
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2291 non-null   object
#  1   Total Generation Rank                2290 non-null   object
#  2   Electric Generation Rank             2290 non-null   object
#  3   Commercial Generation Rank           2290 non-null   object
#  4   Capacity Growth Status               2290 non-null   object
#  5   CAIDI w/ Major Events                2290 non-null   float64
#  6   CAIDI w/o Major Events               2290 non-null   float64
#  7   SAIFI Major Events                   2290 non-null   object
#  8   Utility Annual Energy Savings (MWh)  2290 non-null   object
#  9   Utility Peak Demand Savings (MW)     2290 non-null   object
#  10  Utility Annual Incentive Cost ($)    2290 non-null   object
#  11  Utility Commercial Avg Life (Yrs)    2290 non-null   object
#  12  Regional Electricity Demand          2290 non-null   object
#  13  IXP Name                             2291 non-null   object
#  14  City                                 2252 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 268.6+ KB

# %%
merged_4[merged_4['Total Generation Rank'].isna()]
# Out:
#       State Total Generation Rank Electric Generation Rank  \
# 2099  Texas                   NaN                      NaN
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 2099                        NaN                    NaN                    NaN
#
#       CAIDI w/o Major Events SAIFI Major Events  \
# 2099                     NaN                NaN
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 2099                                 NaN                              NaN
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 2099                               NaN                               NaN
#
#      Regional Electricity Demand                               IXP Name  \
# 2099                         NaN  DartNode IXP - DartNode IXP - Houston
#
#          City
# 2099  Houston

# %%
# Drop rows where Total Generation Rank is NaN
merged_4 = merged_4.dropna(subset=['Total Generation Rank'])
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2290 entries, 0 to 2290
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2290 non-null   object
#  1   Total Generation Rank                2290 non-null   object
#  2   Electric Generation Rank             2290 non-null   object
#  3   Commercial Generation Rank           2290 non-null   object
#  4   Capacity Growth Status               2290 non-null   object
#  5   CAIDI w/ Major Events                2290 non-null   float64
#  6   CAIDI w/o Major Events               2290 non-null   float64
#  7   SAIFI Major Events                   2290 non-null   object
#  8   Utility Annual Energy Savings (MWh)  2290 non-null   object
#  9   Utility Peak Demand Savings (MW)     2290 non-null   object
#  10  Utility Annual Incentive Cost ($)    2290 non-null   object
#  11  Utility Commercial Avg Life (Yrs)    2290 non-null   object
#  12  Regional Electricity Demand          2290 non-null   object
#  13  IXP Name                             2290 non-null   object
#  14  City                                 2251 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 286.2+ KB

# %%
merged_4.loc[merged_4['State'] == 'Texas', 'State'] = 'TX'

merged_4['State'].value_counts()
# Out:
# State
# CA    780
# TX    294
# FL    140
# WA    119
# NY    110
# OR    105
# CO     65
# MO     64
# MA     64
# MI     57
# IL     55
# IA     48
# MN     42
# AZ     40
# VA     39
# NC     32
# OH     30
# GA     30
# PA     24
# WI     14
# NE     14
# MD     10
# UT      9
# IN      8
# NV      8
# CT      8
# SD      6
# VT      6
# ID      6
# HI      6
# NJ      5
# KY      5
# SC      5
# AL      4
# LA      4
# NH      4
# NM      4
# MS      4
# WY      3
# AR      3
# RI      2
# OK      2
# MT      2
# DE      2
# DC      2
# ND      1
# TN      1
# ME      1
# KS      1
# WV      1
# AK      1
# Name: count, dtype: int64

# %%
merged_4[merged_4['City'].isna()]
# Out:
#      State Total Generation Rank Electric Generation Rank  \
# 5       AR               Unknown                  Unknown
# 6       AR               Unknown                  Unknown
# 7       AR               Unknown                  Unknown
# 903     DE               Unknown                  Unknown
# 904     DE               Unknown                  Unknown
# 1129    ID                   Low                 Moderate
# 1130    ID                   Low                 Moderate
# 1131    ID                   Low                 Moderate
# 1132    ID                   Low                 Moderate
# 1133    ID                   Low                 Moderate
# 1134    ID                   Low                 Moderate
# 1204    LA               Unknown                  Unknown
# 1205    LA               Unknown                  Unknown
# 1206    LA               Unknown                  Unknown
# 1207    LA               Unknown                  Unknown
# 1446    MS              Moderate                     High
# 1447    MS              Moderate                     High
# 1448    MS              Moderate                     High
# 1449    MS              Moderate                     High
# 1499    NH               Unknown                  Unknown
# 1500    NH               Unknown                  Unknown
# 1501    NH               Unknown                  Unknown
# 1502    NH               Unknown                  Unknown
# 1791    RI                   Low                      Low
# 1792    RI                   Low                      Low
# 1793    SC              Moderate                     High
# 1794    SC              Moderate                     High
# 1795    SC              Moderate                     High
# 1796    SC              Moderate                     High
# 1797    SC              Moderate                     High
# 1798    SD               Unknown                  Unknown
# 1799    SD               Unknown                  Unknown
# 1800    SD               Unknown                  Unknown
# 1801    SD               Unknown                  Unknown
# 1802    SD               Unknown                  Unknown
# 1803    SD               Unknown                  Unknown
# 2288    WY                   Low                 Moderate
# 2289    WY                   Low                 Moderate
# 2290    WY                   Low                 Moderate
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 5                       Unknown                Unknown                  433.4
# 6                       Unknown                Unknown                  433.4
# 7                       Unknown                Unknown                  433.4
# 903                     Unknown                Unknown                  130.3
# 904                     Unknown                Unknown                  130.3
# 1129                        Low              Shrinking                  128.4
# 1130                        Low              Shrinking                  128.4
# 1131                        Low              Shrinking                  128.4
# 1132                        Low              Shrinking                  128.4
# 1133                        Low              Shrinking                  128.4
# 1134                        Low              Shrinking                  128.4
# 1204                    Unknown                Unknown                  275.1
# 1205                    Unknown                Unknown                  275.1
# 1206                    Unknown                Unknown                  275.1
# 1207                    Unknown                Unknown                  275.1
# 1446                        Low              Shrinking                  295.2
# 1447                        Low              Shrinking                  295.2
# 1448                        Low              Shrinking                  295.2
# 1449                        Low              Shrinking                  295.2
# 1499                    Unknown                Unknown                  368.5
# 1500                    Unknown                Unknown                  368.5
# 1501                    Unknown                Unknown                  368.5
# 1502                    Unknown                Unknown                  368.5
# 1791                        Low              Shrinking                  133.7
# 1792                        Low              Shrinking                  133.7
# 1793                        Low              Shrinking                  110.9
# 1794                        Low              Shrinking                  110.9
# 1795                        Low              Shrinking                  110.9
# 1796                        Low              Shrinking                  110.9
# 1797                        Low              Shrinking                  110.9
# 1798                    Unknown                Unknown                   76.2
# 1799                    Unknown                Unknown                   76.2
# 1800                    Unknown                Unknown                   76.2
# 1801                    Unknown                Unknown                   76.2
# 1802                    Unknown                Unknown                   76.2
# 1803                    Unknown                Unknown                   76.2
# 2288                        Low              Shrinking                  127.8
# 2289                        Low              Shrinking                  127.8
# 2290                        Low              Shrinking                  127.8
#
#       CAIDI w/o Major Events SAIFI Major Events  \
# 5                      144.0               High
# 6                      144.0               High
# 7                      144.0               High
# 903                     87.3                Low
# 904                     87.3                Low
# 1129                   121.2           Moderate
# 1130                   121.2           Moderate
# 1131                   121.2           Moderate
# 1132                   121.2           Moderate
# 1133                   121.2           Moderate
# 1134                   121.2           Moderate
# 1204                   118.8               High
# 1205                   118.8               High
# 1206                   118.8               High
# 1207                   118.8               High
# 1446                   118.0               High
# 1447                   118.0               High
# 1448                   118.0               High
# 1449                   118.0               High
# 1499                   126.1           Moderate
# 1500                   126.1           Moderate
# 1501                   126.1           Moderate
# 1502                   126.1           Moderate
# 1791                    78.3                Low
# 1792                    78.3                Low
# 1793                    97.7           Moderate
# 1794                    97.7           Moderate
# 1795                    97.7           Moderate
# 1796                    97.7           Moderate
# 1797                    97.7           Moderate
# 1798                    70.8           Moderate
# 1799                    70.8           Moderate
# 1800                    70.8           Moderate
# 1801                    70.8           Moderate
# 1802                    70.8           Moderate
# 1803                    70.8           Moderate
# 2288                   124.7           Moderate
# 2289                   124.7           Moderate
# 2290                   124.7           Moderate
#
#      Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 5                                   High                         Moderate
# 6                               Moderate                              Low
# 7                               Moderate                         Moderate
# 903                                  Low                         Moderate
# 904                                  Low                              Low
# 1129                                 Low                              Low
# 1130                                 Low                              Low
# 1131                                High                         Moderate
# 1132                                 Low                              Low
# 1133                                 Low                              Low
# 1134                                 Low                             High
# 1204                            Moderate                              Low
# 1205                            Moderate                         Moderate
# 1206                            Moderate                         Moderate
# 1207                                 Low                              Low
# 1446                                 Low                              Low
# 1447                            Moderate                         Moderate
# 1448                            Moderate                              Low
# 1449                                 Low                              Low
# 1499                                 Low                              Low
# 1500                            Moderate                              Low
# 1501                                 Low                              Low
# 1502                                 Low                              Low
# 1791                                High                         Moderate
# 1792                                 Low                              Low
# 1793                                 Low                              Low
# 1794                            Moderate                         Moderate
# 1795                                High                         Moderate
# 1796                                High                         Moderate
# 1797                                 Low                              Low
# 1798                                 Low                              Low
# 1799                                 Low                              Low
# 1800                                 Low                              Low
# 1801                                 Low                              Low
# 1802                                 Low                              Low
# 1803                                 Low                              Low
# 2288                                 Low                              Low
# 2289                                 Low                              Low
# 2290                            Moderate                              Low
#
#      Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 5                                 High                          Moderate
# 6                             Moderate                          Moderate
# 7                             Moderate                          Moderate
# 903                                Low                               Low
# 904                                Low                          Moderate
# 1129                               Low                               Low
# 1130                               Low                               Low
# 1131                              High                          Moderate
# 1132                               Low                          Moderate
# 1133                               Low                          Moderate
# 1134                          Moderate                               Low
# 1204                          Moderate                          Moderate
# 1205                          Moderate                          Moderate
# 1206                          Moderate                          Moderate
# 1207                          Moderate                              High
# 1446                               Low                          Moderate
# 1447                              High                          Moderate
# 1448                          Moderate                               Low
# 1449                               Low                          Moderate
# 1499                          Moderate                               Low
# 1500                              High                               Low
# 1501                          Moderate                               Low
# 1502                          Moderate                               Low
# 1791                              High                               Low
# 1792                               Low                          Moderate
# 1793                               Low                               Low
# 1794                          Moderate                          Moderate
# 1795                              High                               Low
# 1796                              High                          Moderate
# 1797                               Low                               Low
# 1798                               Low                          Moderate
# 1799                               Low                          Moderate
# 1800                               Low                          Moderate
# 1801                               Low                              High
# 1802                               Low                          Moderate
# 1803                               Low                          Moderate
# 2288                               Low                          Moderate
# 2289                               Low                          Moderate
# 2290                          Moderate                          Moderate
#
#      Regional Electricity Demand IXP Name City
# 5                            Low   No IXP  NaN
# 6                            Low   No IXP  NaN
# 7                            Low   No IXP  NaN
# 903                         High   No IXP  NaN
# 904                         High   No IXP  NaN
# 1129                    Moderate   No IXP  NaN
# 1130                    Moderate   No IXP  NaN
# 1131                    Moderate   No IXP  NaN
# 1132                    Moderate   No IXP  NaN
# 1133                    Moderate   No IXP  NaN
# 1134                    Moderate   No IXP  NaN
# 1204                         Low   No IXP  NaN
# 1205                         Low   No IXP  NaN
# 1206                         Low   No IXP  NaN
# 1207                         Low   No IXP  NaN
# 1446                         Low   No IXP  NaN
# 1447                         Low   No IXP  NaN
# 1448                         Low   No IXP  NaN
# 1449                         Low   No IXP  NaN
# 1499                         Low   No IXP  NaN
# 1500                         Low   No IXP  NaN
# 1501                         Low   No IXP  NaN
# 1502                         Low   No IXP  NaN
# 1791                         Low   No IXP  NaN
# 1792                         Low   No IXP  NaN
# 1793                         Low   No IXP  NaN
# 1794                         Low   No IXP  NaN
# 1795                         Low   No IXP  NaN
# 1796                         Low   No IXP  NaN
# 1797                         Low   No IXP  NaN
# 1798                    Moderate   No IXP  NaN
# 1799                    Moderate   No IXP  NaN
# 1800                    Moderate   No IXP  NaN
# 1801                    Moderate   No IXP  NaN
# 1802                    Moderate   No IXP  NaN
# 1803                    Moderate   No IXP  NaN
# 2288                    Moderate   No IXP  NaN
# 2289                    Moderate   No IXP  NaN
# 2290                    Moderate   No IXP  NaN

# %%
merged_4 = merged_4.dropna(subset=['City'])
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2251 entries, 0 to 2287
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2251 non-null   object
#  1   Total Generation Rank                2251 non-null   object
#  2   Electric Generation Rank             2251 non-null   object
#  3   Commercial Generation Rank           2251 non-null   object
#  4   Capacity Growth Status               2251 non-null   object
#  5   CAIDI w/ Major Events                2251 non-null   float64
#  6   CAIDI w/o Major Events               2251 non-null   float64
#  7   SAIFI Major Events                   2251 non-null   object
#  8   Utility Annual Energy Savings (MWh)  2251 non-null   object
#  9   Utility Peak Demand Savings (MW)     2251 non-null   object
#  10  Utility Annual Incentive Cost ($)    2251 non-null   object
#  11  Utility Commercial Avg Life (Yrs)    2251 non-null   object
#  12  Regional Electricity Demand          2251 non-null   object
#  13  IXP Name                             2251 non-null   object
#  14  City                                 2251 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 281.4+ KB

# %%
# Replace 'No IXP' with NaN to exclude it from the count
merged_4['IXP Name'] = merged_4['IXP Name'].replace('No IXP', np.nan)

# Group by 'State' and count unique 'IXP Name' values, then reset index
ixp_counts = merged_4.groupby('State')['IXP Name'].nunique().reset_index()


# Rename the column to 'IXP_Count'
ixp_counts = ixp_counts.rename(columns={'IXP Name': 'IXP_Count'})

# Merge the counts back into the original DataFrame
merged_4 = merged_4.merge(ixp_counts, on='State', how='left')

# Fill NaN values in 'IXP Name' back with 'No IXP'
merged_4['IXP Name'] = merged_4['IXP Name'].fillna('No IXP')

# %%
merged_4['IXP_Count'].value_counts()
# Out:
# IXP_Count
# 27    780
# 18    294
# 7     224
# 11    204
# 4     152
# 10    140
# 5     125
# 8     104
# 3      96
# 2      72
# 1      60
# Name: count, dtype: int64

# %%
merged_4.drop(columns=['IXP Name'], inplace=True)
merged_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2251 entries, 0 to 2250
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2251 non-null   object
#  1   Total Generation Rank                2251 non-null   object
#  2   Electric Generation Rank             2251 non-null   object
#  3   Commercial Generation Rank           2251 non-null   object
#  4   Capacity Growth Status               2251 non-null   object
#  5   CAIDI w/ Major Events                2251 non-null   float64
#  6   CAIDI w/o Major Events               2251 non-null   float64
#  7   SAIFI Major Events                   2251 non-null   object
#  8   Utility Annual Energy Savings (MWh)  2251 non-null   object
#  9   Utility Peak Demand Savings (MW)     2251 non-null   object
#  10  Utility Annual Incentive Cost ($)    2251 non-null   object
#  11  Utility Commercial Avg Life (Yrs)    2251 non-null   object
#  12  Regional Electricity Demand          2251 non-null   object
#  13  City                                 2251 non-null   object
#  14  IXP_Count                            2251 non-null   int64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 263.9+ KB

# %%
merged_4.head().sort_values(by='State', ascending=False)
# Out:
#          City State Total Generation Rank Electric Generation Rank  \
# 1  Montgomery    AL                  High                     High
# 2      Auburn    AL                  High                     High
# 3  Montgomery    AL                  High                     High
# 4      Auburn    AL                  High                     High
# 0   Anchorage    AK                   Low                      Low
#
#   Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 1                        Low                Growing                  186.9
# 2                        Low                Growing                  186.9
# 3                        Low                Growing                  186.9
# 4                        Low                Growing                  186.9
# 0                       High                Growing                  138.8
#
#    CAIDI w/o Major Events SAIFI Major Events  \
# 1                   122.8           Moderate
# 2                   122.8           Moderate
# 3                   122.8           Moderate
# 4                   122.8           Moderate
# 0                   137.6               High
#
#   Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 1                                 Low                         Moderate
# 2                                 Low                         Moderate
# 3                                 Low                              Low
# 4                                 Low                              Low
# 0                             Unknown                          Unknown
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 1                               Low                               Low
# 2                               Low                               Low
# 3                               Low                          Moderate
# 4                               Low                          Moderate
# 0                           Unknown                           Unknown
#
#   Regional Electricity Demand  IXP_Count
# 1                         Low          2
# 2                         Low          2
# 3                         Low          2
# 4                         Low          2
# 0                    Moderate          1

# %%
# Move City column to beginning of dataframe

cols = merged_4.columns.tolist()

# Remove 'City' from current position and add to beginning
cols.remove('City')
cols = ['City'] + cols

# Reorder the DataFrame
merged_4 = merged_4[cols]

# Verify the new column order
print(merged_4.columns)
# Out:
# Index(['City', 'State', 'Total Generation Rank', 'Electric Generation Rank',
#        'Commercial Generation Rank', 'Capacity Growth Status',
#        'CAIDI w/ Major Events', 'CAIDI w/o Major Events', 'SAIFI Major Events',
#        'Utility Annual Energy Savings (MWh)',
#        'Utility Peak Demand Savings (MW)', 'Utility Annual Incentive Cost ($)',
#        'Utility Commercial Avg Life (Yrs)', 'Regional Electricity Demand',
#        'IXP_Count'],
#       dtype='object')

# %% [markdown]
# ### Loading Retail Costs

# %%
retail_costs = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Retail_Costs.csv', index_col=0)
retail_costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1218 entries, 0 to 1238
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            1218 non-null   object
#  1   CITY            1218 non-null   object
#  2   STATE           1218 non-null   object
#  3   Total_MWh_Rank  1218 non-null   object
#  4   Purchased_Rank  1218 non-null   object
# dtypes: object(5)
# memory usage: 57.1+ KB

# %%
retail_costs.head()
# Out:
#                        NAME         CITY STATE Total_MWh_Rank Purchased_Rank
# 0              EVERGY METRO  KANSAS CITY    KS           High           High
# 1  EVERGY KANSAS SOUTH, INC       TOPEKA    KS           High           High
# 2  KARNES ELECTRIC COOP INC  KARNES CITY    TX           High           High
# 3         KAY ELECTRIC COOP    BLACKWELL    OK       Moderate       Moderate
# 4   FREESTATE ELECTRIC COOP      MCLOUTH    KS            Low            Low

# %%
retail_costs = retail_costs.rename(columns={'STATE': 'State', 'NAME': 'Name', 'CITY':'City',
                                'Purchased_Rank': 'Purchased Rank', 'Total_MWh_Rank': 'Total MWh Rank'})
retail_costs['City'].value_counts()
# Out:
# City
# COLUMBUS          12
# JACKSON            6
# AKRON              6
# MADISON            5
# LEBANON            5
#                   ..
# MONTE VISTA        1
# KINGSTREE          1
# SAN DIEGO          1
# MOUNT PLEASANT     1
# COLDWATER          1
# Name: count, Length: 994, dtype: int64

# %%
# Check number of states in retail
len(retail_costs['State'].value_counts())
# Out:
# 52

# %%
retail_costs['State'].value_counts()

# Drop US territories
retail_costs = retail_costs[~retail_costs['State'].isin(['PR', 'GU', 'VI', 'AS', 'CNMI'])]
retail_costs['State'].value_counts()
# Out:
# State
# TN    82
# TX    75
# WI    64
# GA    55
# NC    47
# OH    47
# AL    43
# IN    43
# MN    41
# KY    41
# MO    41
# MS    40
# FL    37
# WA    37
# CA    30
# CO    29
# OK    29
# SC    28
# MI    28
# AR    26
# IL    22
# KS    21
# LA    21
# MA    21
# IA    21
# NE    20
# OR    20
# PA    20
# AZ    17
# VA    17
# NY    16
# ND    15
# SD    15
# NM    14
# UT    12
# ID     9
# NV     9
# AK     7
# MT     7
# DE     6
# WY     6
# CT     6
# MD     5
# ME     5
# NH     5
# HI     4
# NJ     4
# VT     4
# RI     3
# DC     1
# WV     1
# Name: count, dtype: int64

# %%
len(retail_costs['State'].value_counts())
# Out:
# 51

# %%
# Check number of states in merged 4

len(merged_4['State'].value_counts())
# Out:
# 41

# %%
#Lowercase City column
retail_costs['City'] = retail_costs['City'].str.title()
retail_costs['City'].value_counts()
# Out:
# City
# Columbus          12
# Jackson            6
# Akron              6
# Madison            5
# Lebanon            5
#                   ..
# Kingstree          1
# San Diego          1
# Mount Pleasant     1
# Livingston         1
# Coldwater          1
# Name: count, Length: 993, dtype: int64

# %%
retail_costs[retail_costs['City'] == 'Columbus']
# Out:
#                                 Name      City State Total MWh Rank  \
# 79      LOUP RIVER PUBLIC POWER DIST  Columbus    NE           High
# 170   BARTHOLOMEW COUNTY RURAL E M C  Columbus    IN       Moderate
# 205   NEBRASKA PUBLIC POWER DISTRICT  Columbus    NE           High
# 269                    OHIO POWER CO  Columbus    OH           High
# 671                WHEELING POWER CO  Columbus    OH           High
# 713                KENTUCKY POWER CO  Columbus    OH           High
# 866          CITY OF COLUMBUS - (MS)  Columbus    MS       Moderate
# 868          CITY OF COLUMBUS - (WI)  Columbus    WI            Low
# 888     CORNHUSKER PUBLIC POWER DIST  Columbus    NE       Moderate
# 1031    4-COUNTY ELECTRIC POWER ASSN  Columbus    MS           High
# 1066            APPALACHIAN POWER CO  Columbus    OH           High
# 1211         CITY OF COLUMBUS - (OH)  Columbus    OH       Moderate
#
#      Purchased Rank
# 79             High
# 170        Moderate
# 205            High
# 269            High
# 671            High
# 713            High
# 866        Moderate
# 868             Low
# 888        Moderate
# 1031           High
# 1066           High
# 1211       Moderate

# %%
# Aggregate retail data at city level before merging
retail_costs_agg = retail_costs.groupby(['State', 'City']).agg({
    'Total MWh Rank': lambda x: x.mode().iloc[0] if not x.mode().empty else 'Unknown',  # Most common rank
    'Purchased Rank': lambda x: x.mode().iloc[0] if not x.mode().empty else 'Unknown',  # Most common rank
    # Add any other columns that need aggregation
}).reset_index()

retail_costs_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1123 entries, 0 to 1122
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           1123 non-null   object
#  1   City            1123 non-null   object
#  2   Total MWh Rank  1123 non-null   object
#  3   Purchased Rank  1123 non-null   object
# dtypes: object(4)
# memory usage: 35.2+ KB

# %%
retail_costs_agg.groupby(['State', 'City']).size().sort_values(ascending=False).head(30)
# Out:
# State  City
# AK     Anchorage        1
# OK     Edmond           1
#        Marietta         1
#        Lindsay          1
#        Kingfisher       1
#        Hulbert          1
#        Hugo             1
#        Hooker           1
#        Durant           1
#        Oklahoma City    1
#        Collinsville     1
#        Cleveland        1
#        Claremore        1
#        Blackwell        1
#        Binger           1
#        Ada              1
#        Norman           1
#        Okmulgee         1
# TN     Alcoa            1
# OK     Woodward         1
# OR     Florence         1
#        Eugene           1
#        Deer Island      1
#        Coquille         1
#        Clatskanie       1
#        Baker City       1
# OK     Wilburton        1
#        Ponca City       1
#        Walters          1
#        Vinita           1
# dtype: int64

# %%
# Merge on both State and City
merged_5 = pd.merge(
    merged_4,
    retail_costs_agg,
    on=['State', 'City'],
    how='left'
)

merged_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2251 entries, 0 to 2250
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2251 non-null   object
#  1   State                                2251 non-null   object
#  2   Total Generation Rank                2251 non-null   object
#  3   Electric Generation Rank             2251 non-null   object
#  4   Commercial Generation Rank           2251 non-null   object
#  5   Capacity Growth Status               2251 non-null   object
#  6   CAIDI w/ Major Events                2251 non-null   float64
#  7   CAIDI w/o Major Events               2251 non-null   float64
#  8   SAIFI Major Events                   2251 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2251 non-null   object
#  10  Utility Peak Demand Savings (MW)     2251 non-null   object
#  11  Utility Annual Incentive Cost ($)    2251 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2251 non-null   object
#  13  Regional Electricity Demand          2251 non-null   object
#  14  IXP_Count                            2251 non-null   int64
#  15  Total MWh Rank                       1296 non-null   object
#  16  Purchased Rank                       1296 non-null   object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 299.1+ KB

# %%
merged_5[merged_5['Total MWh Rank'].isna()]
# Out:
#                       City State Total Generation Rank  \
# 1               Montgomery    AL                  High
# 2                   Auburn    AL                  High
# 3               Montgomery    AL                  High
# 4                   Auburn    AL                  High
# 6                Flagstaff    AZ                  High
# ...                    ...   ...                   ...
# 2112            Montpelier    VT                   Low
# 2113  White River Junction    VT                   Low
# 2115            Montpelier    VT                   Low
# 2116  White River Junction    VT                   Low
# 2250      South Charleston    WV              Moderate
#
#      Electric Generation Rank Commercial Generation Rank  \
# 1                        High                        Low
# 2                        High                        Low
# 3                        High                        Low
# 4                        High                        Low
# 6                        High                   Moderate
# ...                       ...                        ...
# 2112                      Low                        Low
# 2113                      Low                        Low
# 2115                      Low                        Low
# 2116                      Low                        Low
# 2250                 Moderate                        Low
#
#      Capacity Growth Status  CAIDI w/ Major Events  CAIDI w/o Major Events  \
# 1                   Growing                  186.9                   122.8
# 2                   Growing                  186.9                   122.8
# 3                   Growing                  186.9                   122.8
# 4                   Growing                  186.9                   122.8
# 6                   Growing                  108.6                    84.8
# ...                     ...                    ...                     ...
# 2112              Shrinking                  316.5                   140.0
# 2113              Shrinking                  316.5                   140.0
# 2115              Shrinking                  316.5                   140.0
# 2116              Shrinking                  316.5                   140.0
# 2250                Growing                  319.4                   206.2
#
#      SAIFI Major Events Utility Annual Energy Savings (MWh)  \
# 1              Moderate                                 Low
# 2              Moderate                                 Low
# 3              Moderate                                 Low
# 4              Moderate                                 Low
# 6              Moderate                                High
# ...                 ...                                 ...
# 2112               High                                 Low
# 2113               High                                 Low
# 2115               High                            Moderate
# 2116               High                            Moderate
# 2250               High                             Unknown
#
#      Utility Peak Demand Savings (MW) Utility Annual Incentive Cost ($)  \
# 1                            Moderate                               Low
# 2                            Moderate                               Low
# 3                                 Low                               Low
# 4                                 Low                               Low
# 6                                High                              High
# ...                               ...                               ...
# 2112                              Low                               Low
# 2113                              Low                               Low
# 2115                              Low                              High
# 2116                              Low                              High
# 2250                          Unknown                           Unknown
#
#      Utility Commercial Avg Life (Yrs) Regional Electricity Demand  IXP_Count  \
# 1                                  Low                         Low          2
# 2                                  Low                         Low          2
# 3                             Moderate                         Low          2
# 4                             Moderate                         Low          2
# 6                             Moderate                         Low          8
# ...                                ...                         ...        ...
# 2112                          Moderate                         Low          1
# 2113                          Moderate                         Low          1
# 2115                          Moderate                         Low          1
# 2116                          Moderate                         Low          1
# 2250                           Unknown                     Unknown          1
#
#      Total MWh Rank Purchased Rank
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# 6               NaN            NaN
# ...             ...            ...
# 2112            NaN            NaN
# 2113            NaN            NaN
# 2115            NaN            NaN
# 2116            NaN            NaN
# 2250            NaN            NaN
#
# [955 rows x 17 columns]

# %%
merged_5.isna().sum()
# Out:
# City                                     0
# State                                    0
# Total Generation Rank                    0
# Electric Generation Rank                 0
# Commercial Generation Rank               0
# Capacity Growth Status                   0
# CAIDI w/ Major Events                    0
# CAIDI w/o Major Events                   0
# SAIFI Major Events                       0
# Utility Annual Energy Savings (MWh)      0
# Utility Peak Demand Savings (MW)         0
# Utility Annual Incentive Cost ($)        0
# Utility Commercial Avg Life (Yrs)        0
# Regional Electricity Demand              0
# IXP_Count                                0
# Total MWh Rank                         955
# Purchased Rank                         955
# dtype: int64

# %% [markdown]
# ## Loading in Emissions Data

# %%
emissions = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Emissions.csv', index_col=0)

emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7511 entries, 0 to 7510
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   REPORTING YEAR                   7511 non-null   int64
#  1   FACILITY NAME                    7511 non-null   object
#  2   LATITUDE                         7511 non-null   float64
#  3   LONGITUDE                        7511 non-null   float64
#  4   CITY                             7511 non-null   object
#  5   COUNTY                           7511 non-null   object
#  6   STATE                            7511 non-null   object
#  7   ZIP CODE                         7511 non-null   int64
#  8   PARENT COMPANIES                 7511 non-null   object
#  9   GHG QUANTITY (METRIC TONS CO2e)  7511 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 645.5+ KB

# %%
emissions.head()
# Out:
#    REPORTING YEAR                                FACILITY NAME   LATITUDE  \
# 0            2023      (430) Civitas Resources - Permian Basin  39.745220
# 1            2023       (540) Civitas Resources - Denver Basin  39.744310
# 2            2023  (540) Civitas Resources - GB - Denver Basin  39.745822
# 3            2023               121 REGIONAL DISPOSAL FACILITY  33.298570
# 4            2023                            15-18565/15-18662  37.274127
#
#     LONGITUDE     CITY         COUNTY STATE  ZIP CODE  \
# 0 -104.989197   Denver        Unknown    CO     80202
# 1 -104.988580   Denver        Unknown    CO     80202
# 2 -104.989243   Denver        Unknown    CO     80202
# 3  -96.535860  MELISSA  COLLIN COUNTY    TX     75454
# 4  -83.239034   Hazard   PERRY COUNTY    KY     40701
#
#                        PARENT COMPANIES  GHG QUANTITY (METRIC TONS CO2e)
# 0                 CIVITAS RESOURCES INC                           844548
# 1                 CIVITAS RESOURCES INC                           887487
# 2                 CIVITAS RESOURCES INC                           110747
# 3  NORTH TEXAS MUNICIPAL WATER DISTRICT                           288302
# 4                     CAMBRIAN COAL LLC                           122327

# %%
# Standardize column names
emissions = emissions.rename(columns={'LATITUDE': 'Latitude',
                                      'LONGITUDE': 'Longitude',
                                      'CITY':'City',
                                      'COUNTY':'County',
                                      'STATE':'State',
                                      'ZIP CODE':'Zip Code',
                                      'GHG QUANTITY (METRIC TONS CO2e)':'GHG (MTCO2)'})


#Drop unnecessary columns
emissions =emissions.drop(columns=['REPORTING YEAR', 'FACILITY NAME', 'PARENT COMPANIES'])

# %%
emissions.head()
# Out:
#     Latitude   Longitude     City         County State  Zip Code  GHG (MTCO2)
# 0  39.745220 -104.989197   Denver        Unknown    CO     80202       844548
# 1  39.744310 -104.988580   Denver        Unknown    CO     80202       887487
# 2  39.745822 -104.989243   Denver        Unknown    CO     80202       110747
# 3  33.298570  -96.535860  MELISSA  COLLIN COUNTY    TX     75454       288302
# 4  37.274127  -83.239034   Hazard   PERRY COUNTY    KY     40701       122327

# %%
# Standardize  City and County values as title case
emissions['City'] = emissions['City'].str.title()
emissions['County'] = emissions['County'].str.title()
emissions.head()
# Out:
#     Latitude   Longitude     City         County State  Zip Code  GHG (MTCO2)
# 0  39.745220 -104.989197   Denver        Unknown    CO     80202       844548
# 1  39.744310 -104.988580   Denver        Unknown    CO     80202       887487
# 2  39.745822 -104.989243   Denver        Unknown    CO     80202       110747
# 3  33.298570  -96.535860  Melissa  Collin County    TX     75454       288302
# 4  37.274127  -83.239034   Hazard   Perry County    KY     40701       122327

# %%
emissions.isna().value_counts()
# Out:
# Latitude  Longitude  City   County  State  Zip Code  GHG (MTCO2)
# False     False      False  False   False  False     False          7511
# Name: count, dtype: int64

# %%
# Group by city and state and take the sum of GHG emissions to create a new column called City Emissions
emissions['City Emissions'] = emissions.groupby(['State', 'City'])['GHG (MTCO2)'].transform('sum')

# Group by state and take the sum of GHG emissions to create a new column called State Emissions
emissions['State Emissions'] = emissions.groupby(['State'])['GHG (MTCO2)'].transform('sum')
emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7511 entries, 0 to 7510
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Latitude         7511 non-null   float64
#  1   Longitude        7511 non-null   float64
#  2   City             7511 non-null   object
#  3   County           7511 non-null   object
#  4   State            7511 non-null   object
#  5   Zip Code         7511 non-null   int64
#  6   GHG (MTCO2)      7511 non-null   int64
#  7   City Emissions   7511 non-null   int64
#  8   State Emissions  7511 non-null   int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 586.8+ KB

# %%
# Drop Longitude and Latitude columns since we do not need facility locations
emissions = emissions.drop(columns=['Longitude', 'Latitude'])
emissions.head()
# Out:
#       City         County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 0   Denver        Unknown    CO     80202       844548        21738141
# 1   Denver        Unknown    CO     80202       887487        21738141
# 2   Denver        Unknown    CO     80202       110747        21738141
# 3  Melissa  Collin County    TX     75454       288302          288302
# 4   Hazard   Perry County    KY     40701       122327          164154
#
#    State Emissions
# 0         62456744
# 1         62456744
# 2         62456744
# 3        485547330
# 4         65132445

# %%
# Group by county and state and take the sum of GHG emissions to create a County Emissions columns
emissions['County Emissions'] = emissions.groupby(['State', 'County'])['GHG (MTCO2)'].transform('sum')
emissions.head()
# Out:
#       City         County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 0   Denver        Unknown    CO     80202       844548        21738141
# 1   Denver        Unknown    CO     80202       887487        21738141
# 2   Denver        Unknown    CO     80202       110747        21738141
# 3  Melissa  Collin County    TX     75454       288302          288302
# 4   Hazard   Perry County    KY     40701       122327          164154
#
#    State Emissions  County Emissions
# 0         62456744          12704001
# 1         62456744          12704001
# 2         62456744          12704001
# 3        485547330           1381024
# 4         65132445            164154

# %%
emissions[emissions['Zip Code'] == 0]
# Out:
#           City   County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 63    Offshore  Unknown    TX         0       180279          349404
# 504   Offshore  Unknown    LA         0       134118         5733285
# 539   Offshore  Unknown    LA         0       256468         5733285
# 623   Offshore  Unknown    CA         0        35125           35125
# 893   Offshore  Unknown    TX         0        38935          349404
# ...        ...      ...   ...       ...          ...             ...
# 7268  Offshore  Unknown    LA         0       194726         5733285
# 7269  Offshore  Unknown    LA         0        53572         5733285
# 7322  Offshore  Unknown    LA         0        12452         5733285
# 7323  Offshore  Unknown    LA         0         8883         5733285
# 7390  Offshore  Unknown    LA         0        64602         5733285
#
#       State Emissions  County Emissions
# 63          485547330          66853798
# 504         145975918           7986796
# 539         145975918           7986796
# 623          99305182           6791172
# 893         485547330          66853798
# ...               ...               ...
# 7268        145975918           7986796
# 7269        145975918           7986796
# 7322        145975918           7986796
# 7323        145975918           7986796
# 7390        145975918           7986796
#
# [102 rows x 8 columns]

# %%
# Drop rows where Zip Code is 0
emissions = emissions[emissions['Zip Code'] != 0]

# %%
emissions[emissions['County'] == 'Unknown'].head(50)
# Out:
#               City   County State  Zip Code  GHG (MTCO2)  City Emissions  \
# 0           Denver  Unknown    CO     80202       844548        21738141
# 1           Denver  Unknown    CO     80202       887487        21738141
# 2           Denver  Unknown    CO     80202       110747        21738141
# 6           Denver  Unknown    CO     80203        27277        21738141
# 7           Denver  Unknown    CO     80203        27277        21738141
# 9    Oklahoma City  Unknown    OK     73102      1166132        13403543
# 11         Houston  Unknown    TX     77079        13382        57927547
# 16   Oklahoma City  Unknown    OK     73142       182531        13403543
# 18   Oklahoma City  Unknown    OK     73102       310278        13403543
# 19          Denver  Unknown    CO     80202       125092        21738141
# 22   Oklahoma City  Unknown    OK     73102        26472        13403543
# 33         Moncure  Unknown    NC     27559        27051          110044
# 34      Fort Worth  Unknown    TX     76106       163140         5341634
# 35      Fort Worth  Unknown    TX     76106       600459         5341634
# 37      Fort Worth  Unknown    TX     76106        27713         5341634
# 38      Bridgeport  Unknown    TX     76426       664355         1427501
# 40         Houston  Unknown    TX     77079       116847        57927547
# 41   Oklahoma City  Unknown    OK     73102       219519        13403543
# 44   Oklahoma City  Unknown    OK     73102        55787        13403543
# 47   Oklahoma City  Unknown    OK     73102       207646        13403543
# 48         Durango  Unknown    CO     81301       252801         2573657
# 49         Durango  Unknown    CO     81301       969987         2573657
# 56          Pelkie  Unknown    MI     49958       106545          106545
# 131        Wheeler  Unknown    TX     79014        38739          126807
# 157         Denver  Unknown    CO     80202        86654        21738141
# 158         Denver  Unknown    CO     80202       170182        21738141
# 248        Midland  Unknown    TX     79701        40854        19885494
# 271        Houston  Unknown    TX     77002        42517        57927547
# 280        Houston  Unknown    TX     77002        31349        57927547
# 281        Houston  Unknown    TX     77002       128789        57927547
# 311       Aberdeen  Unknown    SD     57401        22998          134093
# 314    San Antonio  Unknown    TX     78258        13060         9941065
# 327          Ceres  Unknown    CA     95307        40569           40569
# 342    Bakersfield  Unknown    CA     93311        14138         4637586
# 345         Dallas  Unknown    TX     75251       208603        18887520
# 346         Dallas  Unknown    TX     75251       306010        18887520
# 355       Robstown  Unknown    TX     78380       253109          490203
# 373       Martinez  Unknown    CA     94553       446432         4345635
# 375       Martinez  Unknown    CA     94553       322459         4345635
# 383         Akutan  Unknown    AK     99553        46061           46061
# 414       Rayville  Unknown    LA     71269        45031           45031
# 417        Midland  Unknown    TX     79705       262437        19885494
# 419         Austin  Unknown    TX     78746        38291         3679795
# 432        Houston  Unknown    TX     77002       120000        57927547
# 433        Houston  Unknown    TX     77002        14148        57927547
# 448        Houston  Unknown    TX     77002       142319        57927547
# 452         Denver  Unknown    CO     80202       334610        21738141
# 458         Denver  Unknown    CO     80202        20739        21738141
# 459         Denver  Unknown    CO     80202       200323        21738141
# 461        Houston  Unknown    TX     77056       756504        57927547
#
#      State Emissions  County Emissions
# 0           62456744          12704001
# 1           62456744          12704001
# 2           62456744          12704001
# 6           62456744          12704001
# 7           62456744          12704001
# 9           70166208          11908297
# 11         485547330          66853798
# 16          70166208          11908297
# 18          70166208          11908297
# 19          62456744          12704001
# 22          70166208          11908297
# 33          44658028             49533
# 34         485547330          66853798
# 35         485547330          66853798
# 37         485547330          66853798
# 38         485547330          66853798
# 40         485547330          66853798
# 41          70166208          11908297
# 44          70166208          11908297
# 47          70166208          11908297
# 48          62456744          12704001
# 49          62456744          12704001
# 56          69044087            957310
# 131        485547330          66853798
# 157         62456744          12704001
# 158         62456744          12704001
# 248        485547330          66853798
# 271        485547330          66853798
# 280        485547330          66853798
# 281        485547330          66853798
# 311          6299963            250931
# 314        485547330          66853798
# 327         99305182           6791172
# 342         99305182           6791172
# 345        485547330          66853798
# 346        485547330          66853798
# 355        485547330          66853798
# 373         99305182           6791172
# 375         99305182           6791172
# 383         19581674            958847
# 414        145975918           7986796
# 417        485547330          66853798
# 419        485547330          66853798
# 432        485547330          66853798
# 433        485547330          66853798
# 448        485547330          66853798
# 452         62456744          12704001
# 458         62456744          12704001
# 459         62456744          12704001
# 461        485547330          66853798

# %%
pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: requests in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pgeocode) (2.32.3)
# Requirement already satisfied: numpy in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pgeocode) (1.26.4)
# Requirement already satisfied: pandas in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pgeocode) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pandas->pgeocode) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pandas->pgeocode) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from pandas->pgeocode) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from requests->pgeocode) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/sabrinasayed/Documents/Flatiron/Phase 5/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pgeocode) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Map the zip codes to their counties
import pgeocode

# %%
# Convert zip codes to strings first and create the mapping
emissions['Zip Code'] = emissions['Zip Code'].astype(str)

# Create a clean mapping dictionary
zip_to_county = {}
nomi = pgeocode.Nominatim('us')

# Loop through unique zip codes only
for zip_code in emissions['Zip Code'].unique():
    try:
        location = nomi.query_postal_code(zip_code)
        if location is not None and not pd.isna(location['county_name']):
            county = location['county_name'] + ' County'
            zip_to_county[zip_code] = county
    except:
        continue

# Apply the mapping with a safe approach
emissions.loc[emissions['County'] == 'Unknown', 'County'] = \
    emissions.loc[emissions['County'] == 'Unknown', 'Zip Code'].map(zip_to_county).fillna('Unknown')

# %%
emissions[emissions['County'].isna()]
# Out:
# Empty DataFrame
# Columns: [City, County, State, Zip Code, GHG (MTCO2), City Emissions, State Emissions, County Emissions]
# Index: []

# %%
emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7409 entries, 0 to 7510
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              7409 non-null   object
#  1   County            7409 non-null   object
#  2   State             7409 non-null   object
#  3   Zip Code          7409 non-null   object
#  4   GHG (MTCO2)       7409 non-null   int64
#  5   City Emissions    7409 non-null   int64
#  6   State Emissions   7409 non-null   int64
#  7   County Emissions  7409 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 520.9+ KB

# %%
emissions['County'].value_counts()
# Out:
# County
# Harris County       295
# Dallas County       107
# Jefferson County    106
# Denver County        82
# Oklahoma County      67
#                    ...
# Kearney County        1
# Buffalo County        1
# Riley County          1
# Karnes                1
# Gratiot County        1
# Name: count, Length: 1799, dtype: int64

# %%
# Standardize County names
# Function to standardize county names
def standardize_county_name(county):
    # Remove any trailing/leading whitespace
    county = county.strip()
    
    # If it already ends with 'County', return as is
    if county.endswith('County'):
        return county
    # If it ends with 'Parish', return as is (for Louisiana)
    elif county.endswith('Parish'):
        return county
    # If it's not 'Unknown', append 'County'
    elif county != 'Unknown':
        return f"{county} County"
    return county

# Apply the standardization
emissions['County'] = emissions['County'].apply(standardize_county_name)

# Verify the results
print("After standardization:")
print(emissions.groupby(['State', 'County']).size().sort_values(ascending=False).head(30))
# Out:
# After standardization:
# State  County
# TX     Harris County            302
#        Dallas County            104
# CO     Denver County             81
# OK     Oklahoma County           69
# CA     Los Angeles County        65
#        Kern County               58
# OK     Tulsa County              44
# TX     Midland County            42
# CO     Weld County               34
# TX     Tarrant County            33
# NV     Clark County              31
# TX     Jefferson County          30
# MI     Wayne County              30
# AZ     Maricopa County           30
# PA     Allegheny County          29
# TX     Travis County             27
# CA     San Bernardino County     27
# LA     Calcasieu Parish          27
# TX     Collin County             26
# CA     Contra Costa County       26
# AL     Mobile County             25
# IL     Cook County               24
# TX     Bexar County              24
#        Nueces County             23
# NM     Lea County                22
# CA     San Diego County          21
# IL     Will County               20
# KY     Jefferson County          20
# TX     Brazoria County           20
# LA     Ascension Parish          19
# dtype: int64

# %%
# Drop duplicate Counties
emissions = emissions.drop_duplicates(subset=['State', 'City', 'County'])
emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4131 entries, 0 to 7510
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              4131 non-null   object
#  1   County            4131 non-null   object
#  2   State             4131 non-null   object
#  3   Zip Code          4131 non-null   object
#  4   GHG (MTCO2)       4131 non-null   int64
#  5   City Emissions    4131 non-null   int64
#  6   State Emissions   4131 non-null   int64
#  7   County Emissions  4131 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 290.5+ KB

# %%
# Drop VI, Guam from dataframe
emissions = emissions[~emissions['State'].isin(['VI', 'GU'])]

emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4122 entries, 0 to 7510
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              4122 non-null   object
#  1   County            4122 non-null   object
#  2   State             4122 non-null   object
#  3   Zip Code          4122 non-null   object
#  4   GHG (MTCO2)       4122 non-null   int64
#  5   City Emissions    4122 non-null   int64
#  6   State Emissions   4122 non-null   int64
#  7   County Emissions  4122 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 289.8+ KB

# %%
# Bin GHG quantity based on EPA and international standards for city-level emissions
def categorize_city_ghg(value):
    if value <= 50000:                    # Small city emitter (<50k MT CO2e/year)
        return 'Low'
    elif value <= 200000:                 # Medium city emitter (50k-200k MT CO2e/year)
        return 'Moderate'
    elif value <= 1000000:                # Large city emitter (200k-1M MT CO2e/year)
        return 'High'            
    else:                                 # Major city emitter (>1M MT CO2e/year)
        return 'Very High'

# Bin GHG quantity based on EPA thresholds for county-level emissions
def categorize_county_ghg(value):
    if value <= 250000:                   # Small county (<250k MT CO2e/year)
        return 'Low'
    elif value <= 1000000:                # Medium county (250k-1M MT CO2e/year)
        return 'Moderate'
    elif value <= 5000000:                # Large county (1M-5M MT CO2e/year)
        return 'High'
    else:                                 # Major county (>5M MT CO2e/year)
        return 'Very High'

# Bin GHG quantity based on state-level emissions standards
def categorize_state_ghg(value):
    if value <= 50000000:                 # Low-emitting state (<50M MT CO2e/year)
        return 'Low'
    elif value <= 100000000:              # Moderate-emitting state (50M-100M MT CO2e/year)
        return 'Moderate'
    elif value <= 200000000:              # High-emitting state (100M-200M MT CO2e/year)
        return 'High'
    else:                                 # Very high-emitting state (>200M MT CO2e/year)
        return 'Very High'

# Apply the categorization
emissions['City Emissions Level'] = emissions['City Emissions'].apply(categorize_city_ghg)
emissions['County Emissions Level'] = emissions['County Emissions'].apply(categorize_county_ghg)
emissions['State Emissions Level'] = emissions['State Emissions'].apply(categorize_state_ghg)

# %%
emissions.head()
# Out:
#            City         County State Zip Code  GHG (MTCO2)  City Emissions  \
# 0        Denver  Denver County    CO    80202       844548        21738141
# 3       Melissa  Collin County    TX    75454       288302          288302
# 4        Hazard   Perry County    KY    40701       122327          164154
# 5  Indianapolis  Marion County    IN    46242        64807         2783481
# 8       Houston  Harris County    TX    77002       286498        57927547
#
#    State Emissions  County Emissions City Emissions Level  \
# 0         62456744          12704001            Very High
# 3        485547330           1381024                 High
# 4         65132445            164154             Moderate
# 5        108605519            707549            Very High
# 8        485547330          55445613            Very High
#
#   County Emissions Level State Emissions Level
# 0              Very High              Moderate
# 3                   High             Very High
# 4                    Low              Moderate
# 5               Moderate                  High
# 8              Very High             Very High

# %%
# Drop the original numeric columns
emissions = emissions.drop(columns=['City Emissions', 'County Emissions', 'State Emissions', 'GHG (MTCO2)'])
emissions.head()
# Out:
#            City         County State Zip Code City Emissions Level  \
# 0        Denver  Denver County    CO    80202            Very High
# 3       Melissa  Collin County    TX    75454                 High
# 4        Hazard   Perry County    KY    40701             Moderate
# 5  Indianapolis  Marion County    IN    46242            Very High
# 8       Houston  Harris County    TX    77002            Very High
#
#   County Emissions Level State Emissions Level
# 0              Very High              Moderate
# 3                   High             Very High
# 4                    Low              Moderate
# 5               Moderate                  High
# 8              Very High             Very High

# %%
# Verify the results

emissions.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  City          County
# AK     Akutan        Aleutians East County    1
# OH     Toronto       Jefferson County         1
# OK     Blackwell     Kay County               1
#        Bradley       Grady County             1
#        Broken Arrow  Wagoner County           1
#        Broken Bow    Mccurtain County         1
#        Butler        Custer County            1
#        Byars         Mcclain County           1
#        Calumet       Canadian County          1
#        Calvin        Hughes County            1
#        Canute        Washita County           1
#        Cashion       Kingfisher County        1
#                      Logan County             1
#        Chouteau      Mayes County             1
#        Claremore     Rogers County            1
#        Coalgate      Coal County              1
#        Cogar         Caddo County             1
#        Countyline    Stephens County          1
#        Crawford      Roger Mills County       1
#        Custer City   Custer County            1
#        Depew         Creek County             1
#        Dover         Kingfisher County        1
#        Drummond      Garfield County          1
#        Duke          Jackson County           1
#        Durant        Bryan County             1
#        Edmond        Logan County             1
#                      Oklahoma County          1
#        Elmwood       Beaver County            1
#        Enid          Garfield County          1
#        Fletcher      Comanche County          1
# dtype: int64

# %%
merged_5.head()
# Out:
#          City State Total Generation Rank Electric Generation Rank  \
# 0   Anchorage    AK                   Low                      Low
# 1  Montgomery    AL                  High                     High
# 2      Auburn    AL                  High                     High
# 3  Montgomery    AL                  High                     High
# 4      Auburn    AL                  High                     High
#
#   Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                        Low                Growing                  186.9
# 2                        Low                Growing                  186.9
# 3                        Low                Growing                  186.9
# 4                        Low                Growing                  186.9
#
#    CAIDI w/o Major Events SAIFI Major Events  \
# 0                   137.6               High
# 1                   122.8           Moderate
# 2                   122.8           Moderate
# 3                   122.8           Moderate
# 4                   122.8           Moderate
#
#   Utility Annual Energy Savings (MWh) Utility Peak Demand Savings (MW)  \
# 0                             Unknown                          Unknown
# 1                                 Low                         Moderate
# 2                                 Low                         Moderate
# 3                                 Low                              Low
# 4                                 Low                              Low
#
#   Utility Annual Incentive Cost ($) Utility Commercial Avg Life (Yrs)  \
# 0                           Unknown                           Unknown
# 1                               Low                               Low
# 2                               Low                               Low
# 3                               Low                          Moderate
# 4                               Low                          Moderate
#
#   Regional Electricity Demand  IXP_Count Total MWh Rank Purchased Rank
# 0                    Moderate          1           High       Moderate
# 1                         Low          2            NaN            NaN
# 2                         Low          2            NaN            NaN
# 3                         Low          2            NaN            NaN
# 4                         Low          2            NaN            NaN

# %%
# Merge emissions with merged 5
merged_6 = pd.merge(merged_5, emissions, on=['State', 'City'], how='left')

merged_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Zip Code                             2757 non-null   object
#  19  City Emissions Level                 2757 non-null   object
#  20  County Emissions Level               2757 non-null   object
#  21  State Emissions Level                2757 non-null   object
# dtypes: float64(2), int64(1), object(19)
# memory usage: 512.1+ KB

# %%
# Emissions related data that is missing will be filled with unknown
emissions_cols = ['City Emissions Level', 'County Emissions Level', 'State Emissions Level']
merged_6[emissions_cols] = merged_6[emissions_cols].fillna('Unknown')

merged_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Zip Code                             2757 non-null   object
#  19  City Emissions Level                 2979 non-null   object
#  20  County Emissions Level               2979 non-null   object
#  21  State Emissions Level                2979 non-null   object
# dtypes: float64(2), int64(1), object(19)
# memory usage: 512.1+ KB

# %%
merged_6[merged_6.duplicated()]
# Out:
#            City State Total Generation Rank Electric Generation Rank  \
# 9       Phoenix    AZ                  High                     High
# 10      Phoenix    AZ                  High                     High
# 11      Phoenix    AZ                  High                     High
# 12      Phoenix    AZ                  High                     High
# 13      Phoenix    AZ                  High                     High
# ...         ...   ...                   ...                      ...
# 2971  Milwaukee    WI              Moderate                 Moderate
# 2972    Madison    WI              Moderate                 Moderate
# 2973  Milwaukee    WI              Moderate                 Moderate
# 2974    Madison    WI              Moderate                 Moderate
# 2975  Milwaukee    WI              Moderate                 Moderate
#
#      Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 9                      Moderate                Growing                  108.6
# 10                     Moderate                Growing                  108.6
# 11                     Moderate                Growing                  108.6
# 12                     Moderate                Growing                  108.6
# 13                     Moderate                Growing                  108.6
# ...                         ...                    ...                    ...
# 2971                   Moderate              Shrinking                  208.6
# 2972                   Moderate              Shrinking                  208.6
# 2973                   Moderate              Shrinking                  208.6
# 2974                   Moderate              Shrinking                  208.6
# 2975                   Moderate              Shrinking                  208.6
#
#       CAIDI w/o Major Events SAIFI Major Events  \
# 9                       84.8           Moderate
# 10                      84.8           Moderate
# 11                      84.8           Moderate
# 12                      84.8           Moderate
# 13                      84.8           Moderate
# ...                      ...                ...
# 2971                   114.7                Low
# 2972                   114.7                Low
# 2973                   114.7                Low
# 2974                   114.7                Low
# 2975                   114.7                Low
#
#      Utility Annual Energy Savings (MWh)  ...  \
# 9                                   High  ...
# 10                                  High  ...
# 11                                  High  ...
# 12                                  High  ...
# 13                                  High  ...
# ...                                  ...  ...
# 2971                                 Low  ...
# 2972                                 Low  ...
# 2973                                 Low  ...
# 2974                                 Low  ...
# 2975                                 Low  ...
#
#      Utility Commercial Avg Life (Yrs) Regional Electricity Demand IXP_Count  \
# 9                             Moderate                         Low         8
# 10                            Moderate                         Low         8
# 11                            Moderate                         Low         8
# 12                            Moderate                         Low         8
# 13                            Moderate                         Low         8
# ...                                ...                         ...       ...
# 2971                          Moderate                        High         2
# 2972                               Low                        High         2
# 2973                               Low                        High         2
# 2974                          Moderate                        High         2
# 2975                          Moderate                        High         2
#
#      Total MWh Rank  Purchased Rank            County Zip Code  \
# 9              High            High   Maricopa County    85043
# 10             High            High   Maricopa County    85043
# 11             High            High   Maricopa County    85043
# 12             High            High   Maricopa County    85043
# 13             High            High   Maricopa County    85043
# ...             ...             ...               ...      ...
# 2971           High            High  Milwaukee County    53226
# 2972           High            High       Dane County    53703
# 2973           High            High  Milwaukee County    53226
# 2974           High            High       Dane County    53703
# 2975           High            High  Milwaukee County    53226
#
#      City Emissions Level County Emissions Level State Emissions Level
# 9               Very High              Very High                   Low
# 10              Very High              Very High                   Low
# 11              Very High              Very High                   Low
# 12              Very High              Very High                   Low
# 13              Very High              Very High                   Low
# ...                   ...                    ...                   ...
# 2971                 High               Moderate                   Low
# 2972                 High               Moderate                   Low
# 2973                 High               Moderate                   Low
# 2974                 High               Moderate                   Low
# 2975                 High               Moderate                   Low
#
# [2403 rows x 22 columns]

# %% [markdown]
# # Loading in Broadband Data

# %%
broadband = pd.read_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Cleaned Data/Cleaned_Broadband_Data.csv', index_col=0)

broadband.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11385 entries, 25125 to 580965
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   County                  11385 non-null  object
#  1   City                    11385 non-null  object
#  2   State                   11385 non-null  object
#  3   Geog_Area_Type          11385 non-null  object
#  4   Gigabit_Fiber_Coverage  11385 non-null  object
#  5   Business_Density        11385 non-null  object
# dtypes: object(6)
# memory usage: 622.6+ KB

# %%
broadband.head()
# Out:
#                County     City State Geog_Area_Type Gigabit_Fiber_Coverage  \
# 25125  Autauga County  Autauga    AL          Total                   Good
# 25155  Baldwin County  Baldwin    AL          Total               Moderate
# 25185  Barbour County  Barbour    AL          Total                Limited
# 25215     Bibb County     Bibb    AL          Total               Moderate
# 25245   Blount County   Blount    AL          Total                Limited
#
#       Business_Density
# 25125         Moderate
# 25155             High
# 25185         Moderate
# 25215              Low
# 25245         Moderate

# %%
broadband = broadband[broadband['Geog_Area_Type'] == 'Total']

# Drop Geog Area Type
broadband = broadband.drop(columns=['Geog_Area_Type'])

# %%
# Count duplicates of City County State
broadband.groupby(['State', 'City', 'County']).size().sort_values(ascending=False).head(30)
# Out:
# State  City                    County
# AK     Aleutians East Borough  Aleutians East Borough    1
# OH     Lake                    Lake County               1
#        Licking                 Licking County            1
#        Logan                   Logan County              1
#        Lorain                  Lorain County             1
#        Lucas                   Lucas County              1
#        Madison                 Madison County            1
#        Mahoning                Mahoning County           1
#        Marion                  Marion County             1
#        Medina                  Medina County             1
#        Meigs                   Meigs County              1
#        Mercer                  Mercer County             1
#        Miami                   Miami County              1
#        Monroe                  Monroe County             1
#        Montgomery              Montgomery County         1
#        Morgan                  Morgan County             1
#        Morrow                  Morrow County             1
#        Muskingum               Muskingum County          1
#        Noble                   Noble County              1
#        Ottawa                  Ottawa County             1
#        Paulding                Paulding County           1
#        Perry                   Perry County              1
#        Pickaway                Pickaway County           1
#        Lawrence                Lawrence County           1
#        Knox                    Knox County               1
# OK     Greer                   Greer County              1
# OH     Jefferson               Jefferson County          1
#        Defiance                Defiance County           1
#        Delaware                Delaware County           1
#        Erie                    Erie County               1
# dtype: int64

# %%
# Merge Broadband with merged_6
merged_7 = pd.merge(merged_6, broadband, on=['State', 'City', 'County'], how='left')

merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Zip Code                             2757 non-null   object
#  19  City Emissions Level                 2979 non-null   object
#  20  County Emissions Level               2979 non-null   object
#  21  State Emissions Level                2979 non-null   object
#  22  Gigabit_Fiber_Coverage               643 non-null    object
#  23  Business_Density                     643 non-null    object
# dtypes: float64(2), int64(1), object(21)
# memory usage: 558.7+ KB

# %%
merged_7.head()
# Out:
#          City State Total Generation Rank Electric Generation Rank  \
# 0   Anchorage    AK                   Low                      Low
# 1   Anchorage    AK                   Low                      Low
# 2   Anchorage    AK                   Low                      Low
# 3  Montgomery    AL                  High                     High
# 4      Auburn    AL                  High                     High
#
#   Commercial Generation Rank Capacity Growth Status  CAIDI w/ Major Events  \
# 0                       High                Growing                  138.8
# 1                       High                Growing                  138.8
# 2                       High                Growing                  138.8
# 3                        Low                Growing                  186.9
# 4                        Low                Growing                  186.9
#
#    CAIDI w/o Major Events SAIFI Major Events  \
# 0                   137.6               High
# 1                   137.6               High
# 2                   137.6               High
# 3                   122.8           Moderate
# 4                   122.8           Moderate
#
#   Utility Annual Energy Savings (MWh)  ... IXP_Count Total MWh Rank  \
# 0                             Unknown  ...         1           High
# 1                             Unknown  ...         1           High
# 2                             Unknown  ...         1           High
# 3                                 Low  ...         2            NaN
# 4                                 Low  ...         2            NaN
#
#   Purchased Rank                          County  Zip Code  \
# 0       Moderate   Anchorage Municipality County     99503
# 1       Moderate          Kenai Peninsula County     99503
# 2       Moderate  Kenai Peninsula Borough County     99503
# 3            NaN               Montgomery County     36105
# 4            NaN                      Lee County     36830
#
#   City Emissions Level County Emissions Level State Emissions Level  \
# 0            Very High                   High                   Low
# 1            Very High               Moderate                   Low
# 2            Very High                   High                   Low
# 3             Moderate                    Low              Moderate
# 4                  Low                    Low              Moderate
#
#   Gigabit_Fiber_Coverage Business_Density
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3               Moderate             High
# 4                    NaN              NaN
#
# [5 rows x 24 columns]

# %%
merged_7.drop(columns=['City Emissions Level', 'County Emissions Level', 'State Emissions Level'], inplace=True)
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Zip Code                             2757 non-null   object
#  19  Gigabit_Fiber_Coverage               643 non-null    object
#  20  Business_Density                     643 non-null    object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 488.9+ KB

# %%
# Drop any remaining US territories if they exist
territories = ['PR', 'GU', 'VI', 'AS', 'MP', 'CNMI']
merged_7= merged_7[~merged_7['State'].isin(territories)]

len(merged_7['State'].value_counts())
# Out:
# 41

# %% [markdown]
# There are 51 states because i included District of Columbia as a state

# %%
merged_7.columns
# Out:
# Index(['City', 'State', 'Total Generation Rank', 'Electric Generation Rank',
#        'Commercial Generation Rank', 'Capacity Growth Status',
#        'CAIDI w/ Major Events', 'CAIDI w/o Major Events', 'SAIFI Major Events',
#        'Utility Annual Energy Savings (MWh)',
#        'Utility Peak Demand Savings (MW)', 'Utility Annual Incentive Cost ($)',
#        'Utility Commercial Avg Life (Yrs)', 'Regional Electricity Demand',
#        'IXP_Count', 'Total MWh Rank', 'Purchased Rank', 'County', 'Zip Code',
#        'Gigabit_Fiber_Coverage', 'Business_Density'],
#       dtype='object')

# %%
merged_7 = merged_7.replace('None', 'Unknown')

# %%
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Zip Code                             2757 non-null   object
#  19  Gigabit_Fiber_Coverage               643 non-null    object
#  20  Business_Density                     643 non-null    object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 488.9+ KB

# %% [markdown]
# # Propagating the city level data

# %%
# City level columns: 
# Total MWh Rank, Purchased Rank, City Emissions Level

# City-level mappings
city_mappings = {
    'Total MWh Rank': merged_7.groupby(['State', 'City'])['Total MWh Rank'].first(),
    'Purchased Rank': merged_7.groupby(['State', 'City'])['Purchased Rank'].first(),
    'Gigabit_Fiber_Coverage': merged_7.groupby(['State', 'City'])['Gigabit_Fiber_Coverage'].first(),
    'Business_Density': merged_7.groupby(['State', 'City'])['Business_Density'].first()
}

# Fill NaN values using city mappings
for col, mapping in city_mappings.items():
    merged_7[col] = merged_7.apply(
        lambda row: mapping.get((row['State'], row['City'])) if pd.isna(row[col]) or row[col] == 'Unknown' else row[col],
        axis=1
    )

# Verify the results
print("Number of unique cities:", len(merged_7.groupby(['State', 'City'])))
for col in city_mappings.keys():
    print(f"{col}: {len(merged_7[merged_7[col].isna()].groupby(['State', 'City']))} city combinations with NA values")
# Out:
# Number of unique cities: 95
# Total MWh Rank: 38 city combinations with NA values
# Purchased Rank: 38 city combinations with NA values
# Gigabit_Fiber_Coverage: 79 city combinations with NA values
# Business_Density: 79 city combinations with NA values

# %%
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Zip Code                             2757 non-null   object
#  19  Gigabit_Fiber_Coverage               1116 non-null   object
#  20  Business_Density                     1116 non-null   object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 488.9+ KB

# %%
# Drop Zip codes
merged_7.drop(columns=['Zip Code'], inplace=True)
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Gigabit_Fiber_Coverage               1116 non-null   object
#  19  Business_Density                     1116 non-null   object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 465.6+ KB

# %% [markdown]
# ## Propagate the county level data

# %%
# Create county-level mappings for emissions, broadband, and disaster data
county_mappings = {
    # Broadband data
    'Gigabit_Fiber_Coverage': merged_7.groupby(['State', 'City', 'County'])['Gigabit_Fiber_Coverage'].first(),
    'Business_Density': merged_7.groupby(['State', 'City', 'County'])['Business_Density'].first()
}

# Fill NaN values using county mappings
for col, mapping in county_mappings.items():
    merged_7[col] = merged_7.apply(
        lambda row: mapping.get((row['State'], row['County'])) 
        if pd.isna(row[col]) or row[col] == 'Unknown' else row[col],
        axis=1
    )

# Verify the results
print("Number of unique counties:", len(merged_7.groupby(['State', 'County'])))
for col in county_mappings.keys():
    print(f"{col}: {len(merged_7[merged_7[col].isna()].groupby(['State', 'County']))} county combinations with NA values")
# Out:
# Number of unique counties: 111
# Gigabit_Fiber_Coverage: 89 county combinations with NA values
# Business_Density: 89 county combinations with NA values

# %%
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       1602 non-null   object
#  16  Purchased Rank                       1602 non-null   object
#  17  County                               2757 non-null   object
#  18  Gigabit_Fiber_Coverage               1116 non-null   object
#  19  Business_Density                     1116 non-null   object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 465.6+ KB

# %%
merged_7.fillna('Unknown', inplace=True)
merged_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   City                                 2979 non-null   object
#  1   State                                2979 non-null   object
#  2   Total Generation Rank                2979 non-null   object
#  3   Electric Generation Rank             2979 non-null   object
#  4   Commercial Generation Rank           2979 non-null   object
#  5   Capacity Growth Status               2979 non-null   object
#  6   CAIDI w/ Major Events                2979 non-null   float64
#  7   CAIDI w/o Major Events               2979 non-null   float64
#  8   SAIFI Major Events                   2979 non-null   object
#  9   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  10  Utility Peak Demand Savings (MW)     2979 non-null   object
#  11  Utility Annual Incentive Cost ($)    2979 non-null   object
#  12  Utility Commercial Avg Life (Yrs)    2979 non-null   object
#  13  Regional Electricity Demand          2979 non-null   object
#  14  IXP_Count                            2979 non-null   int64
#  15  Total MWh Rank                       2979 non-null   object
#  16  Purchased Rank                       2979 non-null   object
#  17  County                               2979 non-null   object
#  18  Gigabit_Fiber_Coverage               2979 non-null   object
#  19  Business_Density                     2979 non-null   object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 465.6+ KB

# %% [markdown]
# # Saved merged dataframe

# %%
# Save merged_7
merged_7.to_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Data/Merged_Data.csv')

# %%
cleaned_df = merged_7.copy()

# %%
min_features = cleaned_df[['State','County','IXP_Count','Regional Electricity Demand','Utility Annual Energy Savings (MWh)','SAIFI Major Events', 'CAIDI w/o Major Events','CAIDI w/ Major Events','Commercial Generation Rank','Total Generation Rank']]

min_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2979 non-null   object
#  1   County                               2979 non-null   object
#  2   IXP_Count                            2979 non-null   int64
#  3   Regional Electricity Demand          2979 non-null   object
#  4   Utility Annual Energy Savings (MWh)  2979 non-null   object
#  5   SAIFI Major Events                   2979 non-null   object
#  6   CAIDI w/o Major Events               2979 non-null   float64
#  7   CAIDI w/ Major Events                2979 non-null   float64
#  8   Commercial Generation Rank           2979 non-null   object
#  9   Total Generation Rank                2979 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 232.9+ KB

# %%
min_features.to_csv('/Users/sabrinasayed/Documents/GitHub/Data_Center_Sites/Data/Minimum_Features.csv')
